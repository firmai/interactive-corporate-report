# %%
import pandas as pd
import numpy as np 
import json
import os
from datetime import *

# %%
my_path = os.path.abspath(os.path.dirname('__file__'))
path_in_ngrams = os.path.join(my_path, "../data/cpickle/")

path_in_pos = os.path.join(my_path, "../data/pos/")

my_path = os.path.abspath(os.path.dirname('__file__'))
path = os.path.join(my_path, "../input_fields.csv")

input_fields = pd.read_csv(path)

code = input_fields["code_or_ticker"]


from os import listdir
from os.path import isfile, join


code = input_fields["code_or_ticker"]
full_dict = {}

#code = code.iloc[0] 
#for coy in code:
coy = code[0]

# %%
service = ["waitress",
 "service",
 "time","staff",
 "waiter",
 "manager",
 "servers",
 "check",
 "price",
 "hostess"
 "waiting",
 "bill",
 "management"
]

food = [
    "chicken",
    "pizza",
    "steak",
    "salad",
    "burger",
    "fries",
    "dessert",
    "cheese",
    "bread",
    "sandwich",
    "pasta",
    "sauce"
]

preparation = [
    "food",
    "dish",
    "lunch",
    "portion",
    "menu",
    "meal",
    "order",
    "dinner",
    "appetizer",
    "drinks",
    "bar",
    "beer",
    "drink",
    "water",
    "plates",
    "kitchen"
]

location = ["place",
    "restaurant",
    "experience",
    "location",
    "night",
    "visit",
    "family",
    "friends",
    "kids",
    "birthday",
    "area",
    "atmosphere",
    "outside",
    "parking"
]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

big_pro_g = pd.read_csv(path_in_pos +"big_ass_q1_"+code[0]+"_bad_good.csv")
coll_df = pd.DataFrame(columns=big_pro_g.columns)
#code = code.iloc[0] 
types_df = {}
for ar, aes in zip([service,food,preparation,location],["service","food","preparation","location"]):
    types_df[aes] = {}
    for qr, des in zip(["q1_","q2_",""],["q1","q2","all"]):
        all_fir = pd.DataFrame()
        for coy in code:

            coll_df = pd.read_csv(path_in_pos +"big_ass_"+qr+coy+"_good_bad.csv")
            
            len(coll_df)

            coll_df["good"] = coll_df["good"].astype(float)

            rat = coll_df.groupby("name").sum()

            rat.sort_values("good",ascending=False).iloc[:-1,:]

            dar = rat[rat.index.isin(ar)]
            dar = dar["good"]/dar["bad"]
            all_fir[coy] = dar
            all_t = all_fir.T
        for col in all_t.columns:
    
            all_t[col] = all_t[col].map(lambda x : None if (x == 0.000) else x)
        all_t = all_t.replace([np.inf, -np.inf], np.nan)
        
        all_t = all_t.fillna(all_t.mean())
            
        types_df[aes][des] = all_t.T

# %%
most= [0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4,0,0,0,-0.4,-0.4,-0.4]

# %%
dt = {}
for ar, aes in zip([service,food,preparation,location],["service","food","preparation","location"]):
    # Set Final All 
    pow_a = types_df[aes]["all"].pow(1/3)

    max_row = [1/max(row) for index, row in pow_a.iterrows()]

    import numpy as np

    noise = np.random.normal(0,1,len(pow_a))*.10

    noise = 1- np.absolute(noise)

    pow_a_final = pow_a.mul(max_row, axis=0).mul(noise, axis=0)

    q1_frame = types_df[aes]["q1"]

    pow_q1 = q1_frame.pow(1/3)

    max_row = [1/max(row) for index, row in pow_q1.iterrows()]

    import numpy as np

    np.random.seed(1)

    noise = np.random.normal(0,1,len(pow_q1))*.10

    noise = 1- np.absolute(noise)

    pow_q1 =pow_q1.mul(max_row, axis=0).mul(noise, axis=0)

    pow_q1= pow_q1.fillna(pow_a_final.mean())

    np.random.seed(1)

    noise = np.random.normal(0,1,len(pow_q1))*.10

    noise = 1 + np.absolute(noise)

    pow_q1 = pow_q1.mul(noise, axis=0)

    np.random.seed(3)

    noise = np.random.normal(0,1,len(pow_q1))*.10

    noise = 1 - np.absolute(noise)

    pow_q1 = pow_q1.mul(noise, axis=0)

    pow_q1_final = pow_q1*0.30 + pow_a_final*0.70

    q2_frame = types_df[aes]["q2"]

    pow_q2 = q2_frame.pow(1/3)

    max_row = [1/max(row) for index, row in pow_q2.iterrows()]

    import numpy as np

    np.random.seed(1)

    noise = np.random.normal(0,1,len(pow_q2))*.10

    noise = 1- np.absolute(noise)

    pow_q2 =pow_q2.mul(max_row, axis=0).mul(noise, axis=0)

    pow_q2= pow_q2.fillna(pow_a_final.mean())

    np.random.seed(1)

    noise = np.random.normal(0,1,len(pow_q2))*.10

    noise = 1 + np.absolute(noise)

    pow_q2 = pow_q2.mul(noise, axis=0)

    np.random.seed(3)

    noise = np.random.normal(0,1,len(pow_q2))*.10

    noise = 1 - np.absolute(noise)

    pow_q2 = pow_q2.mul(noise, axis=0)

    pow_q2_final = pow_q2*0.30 + pow_a_final*0.70

    max_row = [1/max(row) for index, row in pow_a_final.iterrows()]

    np.random.seed(4)
    noise = np.random.normal(0,1,len(pow_a))*.10

    noise = 1- np.absolute(noise)

    pow_a_final_2 = pow_a_final.mul(max_row, axis=0).mul(noise, axis=0)


    max_row = [1/max(row) for index, row in pow_q2_final.iterrows()]

    np.random.seed(4)
    noise = np.random.normal(0,1,len(pow_a))*.10

    noise = 1- np.absolute(noise)

    pow_q2_final_2 = pow_q2_final.mul(max_row, axis=0).mul(noise, axis=0)


    max_row = [1/max(row) for index, row in pow_q1_final.iterrows()]

    np.random.seed(4)
    noise = np.random.normal(0,1,len(pow_a))*.10

    noise = 1- np.absolute(noise)

    pow_q1_final_2 = pow_q1_final.mul(max_row, axis=0).mul(noise, axis=0)




    import colorlover as cl
    from IPython.display import HTML


    colors_all  = cl.scales['11']["qual"]["Set3"] 


    colors_all.extend(cl.scales['11']["qual"]["Paired"])



    pow_a_final.columns = [ra+"-ALL " for ra in pow_a_final.columns]

    pow_a_final_T = pow_a_final.T
    pow_a_final_T

    pow_q1_final_2.columns = [ra+"-TQ " for ra in pow_q1_final_2.columns]

    pow_q1_final_2_T = pow_q1_final_2.T

    pow_q2_final_2.columns = [ra+"-PQ " for ra in pow_q2_final_2.columns]

    pow_q2_final_2_T = pow_q2_final_2.T

    dars = pow_a_final_T
    dars = pd.concat((dars,pow_q1_final_2_T ),axis=0)
    dars = pd.concat((dars,pow_q2_final_2_T ),axis=0)

    dars = dars.sort_index()

    import plotly.plotly as py
    import plotly.graph_objs as go

    data = [] 
    i = -1
    
    for col in dars.columns:
        i = i + 1
        trace = go.Bar(
            y=dars.index, x= dars[col],
            name=str(col),
            orientation = 'h',

            marker = dict(color = colors_all[i],
            line = dict(color = colors_all[i],
            width = 3)))
        data.append(trace)


    layout = go.Layout(
        barmode='stack',
        bargap = 0.1,
        xaxis= dict(
        showgrid=False,
        zeroline=False,
        showline=False,

        ),
    yaxis= dict(
        showgrid=False,
        zeroline=False,
        showline=False,
    ),
    )

    fig = go.Figure(data=data, layout=layout)
    #py.iplot(fig, filename='marker-h-bar')

    dt[aes] = fig
# Out:
# ---------------------------------------------------------------------------
# PlotlyDictKeyError                        Traceback (most recent call last)
# <ipython-input-415-b6b49ea804bb> in <module>()
#     163             marker = dict(color = colors_all[i],
#     164             line = dict(color = colors_all[i],
# --> 165             width = 3)))
#     166         data.append(trace)
#     167
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     375         d = {key: val for key, val in dict(*args, **kwargs).items()}
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#     379     def __dir__(self):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __setitem__(self, key, value, _raise)
#     426                 if _raise:
#     427                     path = self._get_path() + (key, )
# --> 428                     raise exceptions.PlotlyDictKeyError(self, path)
#     429                 return
#     430
#
# PlotlyDictKeyError: 'bargap' is not allowed in 'bar'
#
# Path To Error: ['bargap']
#
# Valid attributes for 'bar' at path [] under parents []:
#
#     ['bardir', 'base', 'basesrc', 'constraintext', 'customdata',
#     'customdatasrc', 'dx', 'dy', 'error_x', 'error_y', 'hoverinfo',
#     'hoverinfosrc', 'hoverlabel', 'hovertext', 'hovertextsrc', 'ids',
#     'idssrc', 'insidetextfont', 'legendgroup', 'marker', 'name', 'offset',
#     'offsetsrc', 'opacity', 'orientation', 'outsidetextfont', 'r', 'rsrc',
#     'showlegend', 'stream', 't', 'text', 'textfont', 'textposition',
#     'textpositionsrc', 'textsrc', 'tsrc', 'type', 'uid', 'visible',
#     'width', 'widthsrc', 'x', 'x0', 'xaxis', 'xcalendar', 'xsrc', 'y',
#     'y0', 'yaxis', 'ycalendar', 'ysrc']
#
# Run `<bar-object>.help('attribute')` on any of the above.
# '<bar-object>' is the object at []

# %%
dt
# Out:
# {'food': {'data': [{'marker': {'color': 'rgb(141,211,199)',
#      'line': {'color': 'rgb(141,211,199)', 'width': 3}},
#     'name': 'bread',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.394636
#     APPB-PQ      0.499610
#     APPB-TQ      0.545635
#     BJRI-ALL     0.815822
#     BJRI-PQ      0.798523
#     BJRI-TQ      0.864123
#     CAKE-ALL     0.823170
#     CAKE-PQ      0.747632
#     CAKE-TQ      0.856189
#     CHIL-ALL     0.717102
#     CHIL-PQ      0.740146
#     CHIL-TQ      0.786172
#     CPKI-ALL     0.991201
#     CPKI-PQ      0.994944
#     CPKI-TQ      0.994944
#     RRGB-ALL     0.660457
#     RRGB-PQ      0.697893
#     RRGB-TQ      0.743918
#     TGIF-ALL     0.474303
#     TGIF-PQ      0.559036
#     TGIF-TQ      0.605061
#     Name: bread, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(255,255,179)',
#      'line': {'color': 'rgb(255,255,179)', 'width': 3}},
#     'name': 'burger',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.467110
#     APPB-PQ      0.529189
#     APPB-TQ      0.540443
#     BJRI-ALL     0.736419
#     BJRI-PQ      0.874734
#     BJRI-TQ      0.788797
#     CAKE-ALL     0.777909
#     CAKE-PQ      0.812780
#     CAKE-TQ      0.907368
#     CHIL-ALL     0.568732
#     CHIL-PQ      0.622879
#     CHIL-TQ      0.597645
#     CPKI-ALL     0.957493
#     CPKI-PQ      0.950005
#     CPKI-TQ      0.950005
#     RRGB-ALL     0.792787
#     RRGB-PQ      0.812738
#     RRGB-TQ      0.788190
#     TGIF-ALL     0.463343
#     TGIF-PQ      0.455071
#     TGIF-TQ      0.505375
#     Name: burger, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(190,186,218)',
#      'line': {'color': 'rgb(190,186,218)', 'width': 3}},
#     'name': 'cheese',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.533478
#     APPB-PQ      0.487941
#     APPB-TQ      0.463287
#     BJRI-ALL     0.762235
#     BJRI-PQ      0.858905
#     BJRI-TQ      0.690523
#     CAKE-ALL     0.966775
#     CAKE-PQ      0.900409
#     CAKE-TQ      0.874356
#     CHIL-ALL     0.608955
#     CHIL-PQ      0.590663
#     CHIL-TQ      0.625526
#     CPKI-ALL     0.904956
#     CPKI-PQ      0.858510
#     CPKI-TQ      0.900409
#     RRGB-ALL     0.817780
#     RRGB-PQ      0.774920
#     RRGB-TQ      0.728178
#     TGIF-ALL     0.492328
#     TGIF-PQ      0.426308
#     TGIF-TQ      0.466385
#     Name: cheese, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(251,128,114)',
#      'line': {'color': 'rgb(251,128,114)', 'width': 3}},
#     'name': 'chicken',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.449159
#     APPB-PQ      0.476561
#     APPB-TQ      0.533244
#     BJRI-ALL     0.691275
#     BJRI-PQ      0.774115
#     BJRI-TQ      0.769069
#     CAKE-ALL     0.699024
#     CAKE-PQ      0.701230
#     CAKE-TQ      0.809399
#     CHIL-ALL     0.462457
#     CHIL-PQ      0.513485
#     CHIL-TQ      0.528801
#     CPKI-ALL     0.884318
#     CPKI-PQ      0.930640
#     CPKI-TQ      0.930640
#     RRGB-ALL     0.537295
#     RRGB-PQ      0.598017
#     RRGB-TQ      0.598610
#     TGIF-ALL     0.362545
#     TGIF-PQ      0.379975
#     TGIF-TQ      0.402949
#     Name: chicken, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(128,177,211)',
#      'line': {'color': 'rgb(128,177,211)', 'width': 3}},
#     'name': 'dessert',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.512711
#     APPB-PQ      0.602515
#     APPB-TQ      0.485585
#     BJRI-ALL     0.848433
#     BJRI-PQ      0.946020
#     BJRI-TQ      0.955054
#     CAKE-ALL     0.854193
#     CAKE-PQ      0.788274
#     CAKE-TQ      0.946219
#     CHIL-ALL     0.729770
#     CHIL-PQ      0.686280
#     CHIL-TQ      0.693004
#     CPKI-ALL     0.964900
#     CPKI-PQ      0.958170
#     CPKI-TQ      0.958170
#     RRGB-ALL     0.775967
#     RRGB-PQ      0.729634
#     RRGB-TQ      0.831824
#     TGIF-ALL     0.590599
#     TGIF-PQ      0.660902
#     TGIF-TQ      0.691541
#     Name: dessert, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(253,180,98)',
#      'line': {'color': 'rgb(253,180,98)', 'width': 3}},
#     'name': 'fries',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.491746
#     APPB-PQ      0.427306
#     APPB-TQ      0.472115
#     BJRI-ALL     0.793671
#     BJRI-PQ      0.836033
#     BJRI-TQ      0.726290
#     CAKE-ALL     0.939311
#     CAKE-PQ      0.841542
#     CAKE-TQ      0.841542
#     CHIL-ALL     0.598471
#     CHIL-PQ      0.559685
#     CHIL-TQ      0.555823
#     CPKI-ALL     0.742002
#     CPKI-PQ      0.702355
#     CPKI-TQ      0.670069
#     RRGB-ALL     0.867768
#     RRGB-PQ      0.770104
#     RRGB-TQ      0.771049
#     TGIF-ALL     0.513895
#     TGIF-PQ      0.442931
#     TGIF-TQ      0.436706
#     Name: fries, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(179,222,105)',
#      'line': {'color': 'rgb(179,222,105)', 'width': 3}},
#     'name': 'pasta',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.432068
#     APPB-PQ      0.529158
#     APPB-TQ      0.549307
#     BJRI-ALL     0.685420
#     BJRI-PQ      0.644153
#     BJRI-TQ      0.737747
#     CAKE-ALL     0.759455
#     CAKE-PQ      0.773595
#     CAKE-TQ      0.736882
#     CHIL-ALL     0.644467
#     CHIL-PQ      0.624066
#     CHIL-TQ      0.597403
#     CPKI-ALL     0.845302
#     CPKI-PQ      0.935229
#     CPKI-TQ      0.935229
#     RRGB-ALL     0.659460
#     RRGB-PQ      0.698288
#     RRGB-TQ      0.718438
#     TGIF-ALL     0.471288
#     TGIF-PQ      0.465402
#     TGIF-TQ      0.578478
#     Name: pasta, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(252,205,229)',
#      'line': {'color': 'rgb(252,205,229)', 'width': 3}},
#     'name': 'pizza',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.689493
#     APPB-PQ      0.759037
#     APPB-TQ      0.746832
#     BJRI-ALL     0.758405
#     BJRI-PQ      0.857123
#     BJRI-TQ      0.762890
#     CAKE-ALL     0.619210
#     CAKE-PQ      0.707005
#     CAKE-TQ      0.698823
#     CHIL-ALL     0.627624
#     CHIL-PQ      0.623066
#     CHIL-TQ      0.703001
#     CPKI-ALL     0.927666
#     CPKI-PQ      0.940142
#     CPKI-TQ      0.940142
#     RRGB-ALL     0.599847
#     RRGB-PQ      0.692671
#     RRGB-TQ      0.683322
#     TGIF-ALL     0.316472
#     TGIF-PQ      0.482883
#     TGIF-TQ      0.482564
#     Name: pizza, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(217,217,217)',
#      'line': {'color': 'rgb(217,217,217)', 'width': 3}},
#     'name': 'salad',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.481261
#     APPB-PQ      0.475364
#     APPB-TQ      0.435074
#     BJRI-ALL     0.810224
#     BJRI-PQ      0.834267
#     BJRI-TQ      0.736940
#     CAKE-ALL     0.785016
#     CAKE-PQ      0.767808
#     CAKE-TQ      0.703555
#     CHIL-ALL     0.613033
#     CHIL-PQ      0.698814
#     CHIL-TQ      0.536352
#     CPKI-ALL     0.995386
#     CPKI-PQ      0.966775
#     CPKI-TQ      0.966775
#     RRGB-ALL     0.601442
#     RRGB-PQ      0.548361
#     RRGB-TQ      0.533907
#     TGIF-ALL     0.514119
#     TGIF-PQ      0.461272
#     TGIF-TQ      0.538736
#     Name: salad, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(188,128,189)',
#      'line': {'color': 'rgb(188,128,189)', 'width': 3}},
#     'name': 'sandwich',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.444757
#     APPB-PQ      0.573876
#     APPB-TQ      0.553576
#     BJRI-ALL     0.778363
#     BJRI-PQ      0.793680
#     BJRI-TQ      0.751232
#     CAKE-ALL     0.901701
#     CAKE-PQ      0.885252
#     CAKE-TQ      0.885252
#     CHIL-ALL     0.558406
#     CHIL-PQ      0.658450
#     CHIL-TQ      0.630401
#     CPKI-ALL     0.785514
#     CPKI-PQ      0.806079
#     CPKI-TQ      0.783924
#     RRGB-ALL     0.764128
#     RRGB-PQ      0.791506
#     RRGB-TQ      0.769467
#     TGIF-ALL     0.450850
#     TGIF-PQ      0.578028
#     TGIF-TQ      0.557695
#     Name: sandwich, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(204,235,197)',
#      'line': {'color': 'rgb(204,235,197)', 'width': 3}},
#     'name': 'sauce',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.486252
#     APPB-PQ      0.547536
#     APPB-TQ      0.439872
#     BJRI-ALL     0.757484
#     BJRI-PQ      0.897118
#     BJRI-TQ      0.723781
#     CAKE-ALL     0.994557
#     CAKE-PQ      0.937203
#     CAKE-TQ      0.873509
#     CHIL-ALL     0.671867
#     CHIL-PQ      0.725430
#     CHIL-TQ      0.585142
#     CPKI-ALL     0.905217
#     CPKI-PQ      0.928104
#     CPKI-TQ      0.938133
#     RRGB-ALL     0.932366
#     RRGB-PQ      0.938133
#     RRGB-TQ      0.856536
#     TGIF-ALL     0.555360
#     TGIF-PQ      0.622835
#     TGIF-TQ      0.485167
#     Name: sauce, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(166,206,227)',
#      'line': {'color': 'rgb(166,206,227)', 'width': 3}},
#     'name': 'steak',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.384111
#     APPB-PQ      0.461115
#     APPB-TQ      0.484167
#     BJRI-ALL     0.608038
#     BJRI-PQ      0.744896
#     BJRI-TQ      0.630778
#     CAKE-ALL     0.632656
#     CAKE-PQ      0.649627
#     CAKE-TQ      0.710729
#     CHIL-ALL     0.442924
#     CHIL-PQ      0.505723
#     CHIL-TQ      0.646737
#     CPKI-ALL     0.651040
#     CPKI-PQ      0.663570
#     CPKI-TQ      0.733545
#     RRGB-ALL     0.984011
#     RRGB-PQ      0.991201
#     RRGB-TQ      0.991201
#     TGIF-ALL     0.433187
#     TGIF-PQ      0.540468
#     TGIF-TQ      0.480357
#     Name: steak, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')}],
#   'layout': {'barmode': 'stack',
#    'xaxis': {'showgrid': False, 'showline': False, 'zeroline': False},
#    'yaxis': {'showgrid': False, 'showline': False, 'zeroline': False}}},
#  'location': {'data': [{'marker': {'color': 'rgb(141,211,199)',
#      'line': {'color': 'rgb(141,211,199)', 'width': 3}},
#     'name': 'area',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.563075
#     APPB-PQ      0.571876
#     APPB-TQ      0.583363
#     BJRI-ALL     0.939311
#     BJRI-PQ      0.994944
#     BJRI-TQ      0.933337
#     CAKE-ALL     0.706534
#     CAKE-PQ      0.728739
#     CAKE-TQ      0.769734
#     CHIL-ALL     0.566820
#     CHIL-PQ      0.520624
#     CHIL-TQ      0.551693
#     CPKI-ALL     0.849618
#     CPKI-PQ      0.839789
#     CPKI-TQ      0.994944
#     RRGB-ALL     0.686336
#     RRGB-PQ      0.727184
#     RRGB-TQ      0.715719
#     TGIF-ALL     0.514470
#     TGIF-PQ      0.458198
#     TGIF-TQ      0.563865
#     Name: area, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(255,255,179)',
#      'line': {'color': 'rgb(255,255,179)', 'width': 3}},
#     'name': 'atmosphere',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.571464
#     APPB-PQ      0.733578
#     APPB-TQ      0.561444
#     BJRI-ALL     0.845302
#     BJRI-PQ      0.950005
#     BJRI-TQ      0.950005
#     CAKE-ALL     0.835613
#     CAKE-PQ      0.942347
#     CAKE-TQ      0.923024
#     CHIL-ALL     0.754210
#     CHIL-PQ      0.878011
#     CHIL-TQ      0.815669
#     CPKI-ALL     0.808092
#     CPKI-PQ      0.920596
#     CPKI-TQ      0.856500
#     RRGB-ALL     0.570524
#     RRGB-PQ      0.773633
#     RRGB-TQ      0.676471
#     TGIF-ALL     0.438017
#     TGIF-PQ      0.569948
#     TGIF-TQ      0.460318
#     Name: atmosphere, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(190,186,218)',
#      'line': {'color': 'rgb(190,186,218)', 'width': 3}},
#     'name': 'birthday',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.823346
#     APPB-PQ      0.826185
#     APPB-TQ      0.805383
#     BJRI-ALL     0.670918
#     BJRI-PQ      0.710552
#     BJRI-TQ      0.622179
#     CAKE-ALL     0.636409
#     CAKE-PQ      0.693177
#     CAKE-TQ      0.698087
#     CHIL-ALL     0.629331
#     CHIL-PQ      0.566465
#     CHIL-TQ      0.570435
#     CPKI-ALL     0.927666
#     CPKI-PQ      0.900409
#     CPKI-TQ      0.900409
#     RRGB-ALL     0.770267
#     RRGB-PQ      0.849198
#     RRGB-TQ      0.824456
#     TGIF-ALL     0.484800
#     TGIF-PQ      0.585307
#     TGIF-TQ      0.571524
#     Name: birthday, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(251,128,114)',
#      'line': {'color': 'rgb(251,128,114)', 'width': 3}},
#     'name': 'experience',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.659645
#     APPB-PQ      0.556723
#     APPB-TQ      0.565736
#     BJRI-ALL     0.790930
#     BJRI-PQ      0.686481
#     BJRI-TQ      0.727704
#     CAKE-ALL     0.754270
#     CAKE-PQ      0.677845
#     CAKE-TQ      0.700190
#     CHIL-ALL     0.617796
#     CHIL-PQ      0.554929
#     CHIL-TQ      0.540148
#     CPKI-ALL     0.995386
#     CPKI-PQ      0.930640
#     CPKI-TQ      0.930640
#     RRGB-ALL     0.766593
#     RRGB-PQ      0.640008
#     RRGB-TQ      0.681633
#     TGIF-ALL     0.538866
#     TGIF-PQ      0.486759
#     TGIF-TQ      0.462708
#     Name: experience, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(128,177,211)',
#      'line': {'color': 'rgb(128,177,211)', 'width': 3}},
#     'name': 'family',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.583201
#     APPB-PQ      0.605992
#     APPB-TQ      0.601052
#     BJRI-ALL     0.863568
#     BJRI-PQ      0.958170
#     BJRI-TQ      0.873436
#     CAKE-ALL     0.709836
#     CAKE-PQ      0.744782
#     CAKE-TQ      0.728166
#     CHIL-ALL     0.584511
#     CHIL-PQ      0.690152
#     CHIL-TQ      0.649143
#     CPKI-ALL     0.901701
#     CPKI-PQ      0.906044
#     CPKI-TQ      0.958170
#     RRGB-ALL     0.688177
#     RRGB-PQ      0.728532
#     RRGB-TQ      0.667138
#     TGIF-ALL     0.466243
#     TGIF-PQ      0.491871
#     TGIF-TQ      0.515848
#     Name: family, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(253,180,98)',
#      'line': {'color': 'rgb(253,180,98)', 'width': 3}},
#     'name': 'friends',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.534797
#     APPB-PQ      0.601283
#     APPB-TQ      0.538858
#     BJRI-ALL     0.789755
#     BJRI-PQ      0.702469
#     BJRI-TQ      0.761569
#     CAKE-ALL     0.768193
#     CAKE-PQ      0.694599
#     CAKE-TQ      0.673640
#     CHIL-ALL     0.616632
#     CHIL-PQ      0.560370
#     CHIL-TQ      0.607665
#     CPKI-ALL     0.994557
#     CPKI-PQ      0.841542
#     CPKI-TQ      0.841542
#     RRGB-ALL     0.761293
#     RRGB-PQ      0.690120
#     RRGB-TQ      0.700932
#     TGIF-ALL     0.475168
#     TGIF-PQ      0.448301
#     TGIF-TQ      0.516459
#     Name: friends, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(179,222,105)',
#      'line': {'color': 'rgb(179,222,105)', 'width': 3}},
#     'name': 'kids',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.507919
#     APPB-PQ      0.584910
#     APPB-TQ      0.505441
#     BJRI-ALL     0.720026
#     BJRI-PQ      0.772682
#     BJRI-TQ      0.651121
#     CAKE-ALL     0.620216
#     CAKE-PQ      0.661554
#     CAKE-TQ      0.603162
#     CHIL-ALL     0.535306
#     CHIL-PQ      0.595654
#     CHIL-TQ      0.484660
#     CPKI-ALL     0.984011
#     CPKI-PQ      0.935229
#     CPKI-TQ      0.935229
#     RRGB-ALL     0.652783
#     RRGB-PQ      0.554916
#     RRGB-TQ      0.645420
#     TGIF-ALL     0.461549
#     TGIF-PQ      0.553262
#     TGIF-TQ      0.509163
#     Name: kids, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(252,205,229)',
#      'line': {'color': 'rgb(252,205,229)', 'width': 3}},
#     'name': 'location',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.583821
#     APPB-PQ      0.641101
#     APPB-TQ      0.671592
#     BJRI-ALL     0.698593
#     BJRI-PQ      0.689127
#     BJRI-TQ      0.767544
#     CAKE-ALL     0.698196
#     CAKE-PQ      0.725275
#     CAKE-TQ      0.769269
#     CHIL-ALL     0.599911
#     CHIL-PQ      0.669286
#     CHIL-TQ      0.593773
#     CPKI-ALL     0.879105
#     CPKI-PQ      0.940142
#     CPKI-TQ      0.940142
#     RRGB-ALL     0.681171
#     RRGB-PQ      0.664193
#     RRGB-TQ      0.684827
#     TGIF-ALL     0.499716
#     TGIF-PQ      0.451517
#     TGIF-TQ      0.440844
#     Name: location, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(217,217,217)',
#      'line': {'color': 'rgb(217,217,217)', 'width': 3}},
#     'name': 'night',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.522662
#     APPB-PQ      0.605535
#     APPB-TQ      0.645155
#     BJRI-ALL     0.697658
#     BJRI-PQ      0.879639
#     BJRI-TQ      0.779236
#     CAKE-ALL     0.648542
#     CAKE-PQ      0.720968
#     CAKE-TQ      0.819459
#     CHIL-ALL     0.553586
#     CHIL-PQ      0.629255
#     CHIL-TQ      0.778484
#     CPKI-ALL     0.777664
#     CPKI-PQ      0.966775
#     CPKI-TQ      0.966775
#     RRGB-ALL     0.546237
#     RRGB-PQ      0.613509
#     RRGB-TQ      0.562708
#     TGIF-ALL     0.450378
#     TGIF-PQ      0.487766
#     TGIF-TQ      0.550035
#     Name: night, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(188,128,189)',
#      'line': {'color': 'rgb(188,128,189)', 'width': 3}},
#     'name': 'outside',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.519564
#     APPB-PQ      0.599962
#     APPB-TQ      0.496287
#     BJRI-ALL     0.860543
#     BJRI-PQ      0.820544
#     BJRI-TQ      0.781837
#     CAKE-ALL     0.957470
#     CAKE-PQ      0.883247
#     CAKE-TQ      0.833800
#     CHIL-ALL     0.578504
#     CHIL-PQ      0.638090
#     CHIL-TQ      0.542995
#     CPKI-ALL     0.960570
#     CPKI-PQ      0.885252
#     CPKI-TQ      0.885252
#     RRGB-ALL     0.730785
#     RRGB-PQ      0.736602
#     RRGB-TQ      0.665429
#     TGIF-ALL     0.499561
#     TGIF-PQ      0.587021
#     TGIF-TQ      0.459019
#     Name: outside, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(204,235,197)',
#      'line': {'color': 'rgb(204,235,197)', 'width': 3}},
#     'name': 'parking',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.294273
#     APPB-PQ      0.516986
#     APPB-TQ      0.466942
#     BJRI-ALL     0.469893
#     BJRI-PQ      0.654848
#     BJRI-TQ      0.647319
#     CAKE-ALL     0.507261
#     CAKE-PQ      0.684182
#     CAKE-TQ      0.651191
#     CHIL-ALL     0.357965
#     CHIL-PQ      0.566984
#     CHIL-TQ      0.434242
#     CPKI-ALL     0.830764
#     CPKI-PQ      0.938133
#     CPKI-TQ      0.938133
#     RRGB-ALL     0.383993
#     RRGB-PQ      0.587416
#     RRGB-TQ      0.537373
#     TGIF-ALL     0.225504
#     TGIF-PQ      0.463002
#     TGIF-TQ      0.273555
#     Name: parking, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(166,206,227)',
#      'line': {'color': 'rgb(166,206,227)', 'width': 3}},
#     'name': 'place',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.507878
#     APPB-PQ      0.588044
#     APPB-TQ      0.555796
#     BJRI-ALL     0.860268
#     BJRI-PQ      0.991201
#     BJRI-TQ      0.887294
#     CAKE-ALL     0.795016
#     CAKE-PQ      0.855656
#     CAKE-TQ      0.867498
#     CHIL-ALL     0.558223
#     CHIL-PQ      0.596752
#     CHIL-TQ      0.614876
#     CPKI-ALL     0.888719
#     CPKI-PQ      0.983179
#     CPKI-TQ      0.991201
#     RRGB-ALL     0.697129
#     RRGB-PQ      0.735153
#     RRGB-TQ      0.666494
#     TGIF-ALL     0.462882
#     TGIF-PQ      0.439763
#     TGIF-TQ      0.509679
#     Name: place, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(31,120,180)',
#      'line': {'color': 'rgb(31,120,180)', 'width': 3}},
#     'name': 'restaurant',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.508670
#     APPB-PQ      0.597327
#     APPB-TQ      0.526459
#     BJRI-ALL     0.719166
#     BJRI-PQ      0.816506
#     BJRI-TQ      0.793139
#     CAKE-ALL     0.764475
#     CAKE-PQ      0.816666
#     CAKE-TQ      0.797479
#     CHIL-ALL     0.572457
#     CHIL-PQ      0.611466
#     CHIL-TQ      0.625891
#     CPKI-ALL     0.836425
#     CPKI-PQ      0.957493
#     CPKI-TQ      0.957493
#     RRGB-ALL     0.607712
#     RRGB-PQ      0.658528
#     RRGB-TQ      0.686620
#     TGIF-ALL     0.447227
#     TGIF-PQ      0.410762
#     TGIF-TQ      0.436242
#     Name: restaurant, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(178,223,138)',
#      'line': {'color': 'rgb(178,223,138)', 'width': 3}},
#     'name': 'visit',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.460514
#     APPB-PQ      0.617922
#     APPB-TQ      0.573461
#     BJRI-ALL     0.704338
#     BJRI-PQ      0.915929
#     BJRI-TQ      0.782082
#     CAKE-ALL     0.604899
#     CAKE-PQ      0.742787
#     CAKE-TQ      0.796335
#     CHIL-ALL     0.498631
#     CHIL-PQ      0.569175
#     CHIL-TQ      0.642746
#     CPKI-ALL     0.863903
#     CPKI-PQ      0.966775
#     CPKI-TQ      0.966775
#     RRGB-ALL     0.559139
#     RRGB-PQ      0.703213
#     RRGB-TQ      0.690885
#     TGIF-ALL     0.466374
#     TGIF-PQ      0.469645
#     TGIF-TQ      0.518056
#     Name: visit, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')}],
#   'layout': {'barmode': 'stack',
#    'xaxis': {'showgrid': False, 'showline': False, 'zeroline': False},
#    'yaxis': {'showgrid': False, 'showline': False, 'zeroline': False}}},
#  'preparation': {'data': [{'marker': {'color': 'rgb(141,211,199)',
#      'line': {'color': 'rgb(141,211,199)', 'width': 3}},
#     'name': 'appetizer',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.485030
#     APPB-PQ      0.524353
#     APPB-TQ      0.557669
#     BJRI-ALL     0.772710
#     BJRI-PQ      0.876683
#     BJRI-TQ      0.887450
#     CAKE-ALL     0.857686
#     CAKE-PQ      0.914152
#     CAKE-TQ      0.943195
#     CHIL-ALL     0.656853
#     CHIL-PQ      0.809062
#     CHIL-TQ      0.641722
#     CPKI-ALL     0.957493
#     CPKI-PQ      0.994944
#     CPKI-TQ      0.994944
#     RRGB-ALL     0.627335
#     RRGB-PQ      0.652804
#     RRGB-TQ      0.724756
#     TGIF-ALL     0.495400
#     TGIF-PQ      0.620889
#     TGIF-TQ      0.619778
#     Name: appetizer, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(255,255,179)',
#      'line': {'color': 'rgb(255,255,179)', 'width': 3}},
#     'name': 'bar',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.502643
#     APPB-PQ      0.504734
#     APPB-TQ      0.607565
#     BJRI-ALL     0.825131
#     BJRI-PQ      0.950005
#     BJRI-TQ      0.797019
#     CAKE-ALL     0.726501
#     CAKE-PQ      0.752126
#     CAKE-TQ      0.782320
#     CHIL-ALL     0.518112
#     CHIL-PQ      0.492387
#     CHIL-TQ      0.521373
#     CPKI-ALL     0.966775
#     CPKI-PQ      0.938760
#     CPKI-TQ      0.950005
#     RRGB-ALL     0.590518
#     RRGB-PQ      0.577124
#     RRGB-TQ      0.651453
#     TGIF-ALL     0.445709
#     TGIF-PQ      0.397470
#     TGIF-TQ      0.511351
#     Name: bar, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(190,186,218)',
#      'line': {'color': 'rgb(190,186,218)', 'width': 3}},
#     'name': 'beer',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.383323
#     APPB-PQ      0.490662
#     APPB-TQ      0.357900
#     BJRI-ALL     0.884318
#     BJRI-PQ      0.900409
#     BJRI-TQ      0.900409
#     CAKE-ALL     0.543231
#     CAKE-PQ      0.590182
#     CAKE-TQ      0.607958
#     CHIL-ALL     0.523369
#     CHIL-PQ      0.501281
#     CHIL-TQ      0.594281
#     CPKI-ALL     0.777149
#     CPKI-PQ      0.751261
#     CPKI-TQ      0.769037
#     RRGB-ALL     0.533261
#     RRGB-PQ      0.583317
#     RRGB-TQ      0.601093
#     TGIF-ALL     0.366695
#     TGIF-PQ      0.357736
#     TGIF-TQ      0.486394
#     Name: beer, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(251,128,114)',
#      'line': {'color': 'rgb(251,128,114)', 'width': 3}},
#     'name': 'dinner',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.527236
#     APPB-PQ      0.496308
#     APPB-TQ      0.621593
#     BJRI-ALL     0.858802
#     BJRI-PQ      0.799680
#     BJRI-TQ      0.829781
#     CAKE-ALL     0.835004
#     CAKE-PQ      0.754714
#     CAKE-TQ      0.799182
#     CHIL-ALL     0.623895
#     CHIL-PQ      0.584298
#     CHIL-TQ      0.546728
#     CPKI-ALL     0.964900
#     CPKI-PQ      0.930640
#     CPKI-TQ      0.930640
#     RRGB-ALL     0.758382
#     RRGB-PQ      0.627716
#     RRGB-TQ      0.774068
#     TGIF-ALL     0.526123
#     TGIF-PQ      0.490221
#     TGIF-TQ      0.560337
#     Name: dinner, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(128,177,211)',
#      'line': {'color': 'rgb(128,177,211)', 'width': 3}},
#     'name': 'dish',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.532700
#     APPB-PQ      0.649358
#     APPB-TQ      0.532913
#     BJRI-ALL     0.868086
#     BJRI-PQ      0.958170
#     BJRI-TQ      0.860138
#     CAKE-ALL     0.698653
#     CAKE-PQ      0.773425
#     CAKE-TQ      0.743569
#     CHIL-ALL     0.474921
#     CHIL-PQ      0.483338
#     CHIL-TQ      0.581680
#     CPKI-ALL     0.939311
#     CPKI-PQ      0.953343
#     CPKI-TQ      0.958170
#     RRGB-ALL     0.891478
#     RRGB-PQ      0.917582
#     RRGB-TQ      0.876705
#     TGIF-ALL     0.453520
#     TGIF-PQ      0.590162
#     TGIF-TQ      0.566522
#     Name: dish, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(253,180,98)',
#      'line': {'color': 'rgb(253,180,98)', 'width': 3}},
#     'name': 'drink',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.451312
#     APPB-PQ      0.450979
#     APPB-TQ      0.472423
#     BJRI-ALL     0.736674
#     BJRI-PQ      0.841542
#     BJRI-TQ      0.740512
#     CAKE-ALL     0.676210
#     CAKE-PQ      0.692644
#     CAKE-TQ      0.657874
#     CHIL-ALL     0.536826
#     CHIL-PQ      0.526274
#     CHIL-TQ      0.458939
#     CPKI-ALL     0.845302
#     CPKI-PQ      0.818779
#     CPKI-TQ      0.841542
#     RRGB-ALL     0.646677
#     RRGB-PQ      0.647270
#     RRGB-TQ      0.551073
#     TGIF-ALL     0.514717
#     TGIF-PQ      0.461805
#     TGIF-TQ      0.502373
#     Name: drink, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(179,222,105)',
#      'line': {'color': 'rgb(179,222,105)', 'width': 3}},
#     'name': 'drinks',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.554135
#     APPB-PQ      0.538234
#     APPB-TQ      0.612051
#     BJRI-ALL     0.737290
#     BJRI-PQ      0.734771
#     BJRI-TQ      0.755486
#     CAKE-ALL     0.699028
#     CAKE-PQ      0.679451
#     CAKE-TQ      0.746809
#     CHIL-ALL     0.610661
#     CHIL-PQ      0.559799
#     CHIL-TQ      0.605045
#     CPKI-ALL     0.927666
#     CPKI-PQ      0.935229
#     CPKI-TQ      0.935229
#     RRGB-ALL     0.648869
#     RRGB-PQ      0.558926
#     RRGB-TQ      0.657586
#     TGIF-ALL     0.514505
#     TGIF-PQ      0.444421
#     TGIF-TQ      0.501043
#     Name: drinks, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(252,205,229)',
#      'line': {'color': 'rgb(252,205,229)', 'width': 3}},
#     'name': 'food',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.541770
#     APPB-PQ      0.513622
#     APPB-TQ      0.544606
#     BJRI-ALL     0.772820
#     BJRI-PQ      0.733338
#     BJRI-TQ      0.750294
#     CAKE-ALL     0.778317
#     CAKE-PQ      0.807686
#     CAKE-TQ      0.766759
#     CHIL-ALL     0.600202
#     CHIL-PQ      0.555809
#     CHIL-TQ      0.563377
#     CPKI-ALL     0.995386
#     CPKI-PQ      0.940142
#     CPKI-TQ      0.940142
#     RRGB-ALL     0.679691
#     RRGB-PQ      0.591340
#     RRGB-TQ      0.645147
#     TGIF-ALL     0.521893
#     TGIF-PQ      0.444236
#     TGIF-TQ      0.467504
#     Name: food, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(217,217,217)',
#      'line': {'color': 'rgb(217,217,217)', 'width': 3}},
#     'name': 'kitchen',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.409305
#     APPB-PQ      0.476588
#     APPB-TQ      0.493562
#     BJRI-ALL     0.525103
#     BJRI-PQ      0.715744
#     BJRI-TQ      0.729256
#     CAKE-ALL     0.492596
#     CAKE-PQ      0.618147
#     CAKE-TQ      0.664423
#     CHIL-ALL     0.363558
#     CHIL-PQ      0.493603
#     CHIL-TQ      0.465696
#     CPKI-ALL     0.901701
#     CPKI-PQ      0.966775
#     CPKI-TQ      0.966775
#     RRGB-ALL     0.480986
#     RRGB-PQ      0.609413
#     RRGB-TQ      0.632472
#     TGIF-ALL     0.324117
#     TGIF-PQ      0.394605
#     TGIF-TQ      0.512226
#     Name: kitchen, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(188,128,189)',
#      'line': {'color': 'rgb(188,128,189)', 'width': 3}},
#     'name': 'lunch',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.584564
#     APPB-PQ      0.543706
#     APPB-TQ      0.522885
#     BJRI-ALL     0.812349
#     BJRI-PQ      0.729171
#     BJRI-TQ      0.675879
#     CAKE-ALL     0.822517
#     CAKE-PQ      0.681386
#     CAKE-TQ      0.771511
#     CHIL-ALL     0.555698
#     CHIL-PQ      0.482130
#     CHIL-TQ      0.485209
#     CPKI-ALL     0.994557
#     CPKI-PQ      0.885252
#     CPKI-TQ      0.885252
#     RRGB-ALL     0.685408
#     RRGB-PQ      0.645177
#     RRGB-TQ      0.685669
#     TGIF-ALL     0.528220
#     TGIF-PQ      0.418214
#     TGIF-TQ      0.459938
#     Name: lunch, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(204,235,197)',
#      'line': {'color': 'rgb(204,235,197)', 'width': 3}},
#     'name': 'meal',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.534500
#     APPB-PQ      0.513898
#     APPB-TQ      0.546048
#     BJRI-ALL     0.734594
#     BJRI-PQ      0.745559
#     BJRI-TQ      0.659248
#     CAKE-ALL     0.729012
#     CAKE-PQ      0.601406
#     CAKE-TQ      0.709254
#     CHIL-ALL     0.514457
#     CHIL-PQ      0.497443
#     CHIL-TQ      0.545550
#     CPKI-ALL     0.984011
#     CPKI-PQ      0.938133
#     CPKI-TQ      0.938133
#     RRGB-ALL     0.692275
#     RRGB-PQ      0.637148
#     RRGB-TQ      0.598256
#     TGIF-ALL     0.479991
#     TGIF-PQ      0.397012
#     TGIF-TQ      0.443679
#     Name: meal, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(166,206,227)',
#      'line': {'color': 'rgb(166,206,227)', 'width': 3}},
#     'name': 'menu',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.435327
#     APPB-PQ      0.511061
#     APPB-TQ      0.489558
#     BJRI-ALL     0.778818
#     BJRI-PQ      0.898355
#     BJRI-TQ      0.899721
#     CAKE-ALL     0.879105
#     CAKE-PQ      0.952660
#     CAKE-TQ      0.991201
#     CHIL-ALL     0.548003
#     CHIL-PQ      0.746957
#     CHIL-TQ      0.564052
#     CPKI-ALL     0.863379
#     CPKI-PQ      0.991201
#     CPKI-TQ      0.967524
#     RRGB-ALL     0.663568
#     RRGB-PQ      0.745120
#     RRGB-TQ      0.740480
#     TGIF-ALL     0.380408
#     TGIF-PQ      0.562430
#     TGIF-TQ      0.472031
#     Name: menu, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(31,120,180)',
#      'line': {'color': 'rgb(31,120,180)', 'width': 3}},
#     'name': 'order',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.445621
#     APPB-PQ      0.551612
#     APPB-TQ      0.558102
#     BJRI-ALL     0.602337
#     BJRI-PQ      0.752133
#     BJRI-TQ      0.757039
#     CAKE-ALL     0.669773
#     CAKE-PQ      0.777714
#     CAKE-TQ      0.809741
#     CHIL-ALL     0.513462
#     CHIL-PQ      0.603172
#     CHIL-TQ      0.580620
#     CPKI-ALL     0.777664
#     CPKI-PQ      0.957493
#     CPKI-TQ      0.957493
#     RRGB-ALL     0.581146
#     RRGB-PQ      0.673563
#     RRGB-TQ      0.675737
#     TGIF-ALL     0.419197
#     TGIF-PQ      0.459112
#     TGIF-TQ      0.497428
#     Name: order, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(178,223,138)',
#      'line': {'color': 'rgb(178,223,138)', 'width': 3}},
#     'name': 'plates',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.455164
#     APPB-PQ      0.582190
#     APPB-TQ      0.598187
#     BJRI-ALL     0.706364
#     BJRI-PQ      0.773339
#     BJRI-TQ      0.769012
#     CAKE-ALL     0.836963
#     CAKE-PQ      0.872717
#     CAKE-TQ      0.966775
#     CHIL-ALL     0.474770
#     CHIL-PQ      0.631238
#     CHIL-TQ      0.614092
#     CPKI-ALL     0.960570
#     CPKI-PQ      0.966775
#     CPKI-TQ      0.945947
#     RRGB-ALL     0.630821
#     RRGB-PQ      0.667202
#     RRGB-TQ      0.740685
#     TGIF-ALL     0.417702
#     TGIF-PQ      0.553684
#     TGIF-TQ      0.567797
#     Name: plates, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(51,160,44)',
#      'line': {'color': 'rgb(51,160,44)', 'width': 3}},
#     'name': 'portion',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.372436
#     APPB-PQ      0.560515
#     APPB-TQ      0.395027
#     BJRI-ALL     0.629355
#     BJRI-PQ      0.742025
#     BJRI-TQ      0.622363
#     CAKE-ALL     0.830764
#     CAKE-PQ      0.884318
#     CAKE-TQ      0.884318
#     CHIL-ALL     0.428576
#     CHIL-PQ      0.600177
#     CHIL-TQ      0.557506
#     CPKI-ALL     0.754047
#     CPKI-PQ      0.830119
#     CPKI-TQ      0.870741
#     RRGB-ALL     0.370205
#     RRGB-PQ      0.558939
#     RRGB-TQ      0.514250
#     TGIF-ALL     0.327551
#     TGIF-PQ      0.528804
#     TGIF-TQ      0.482640
#     Name: portion, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(251,154,153)',
#      'line': {'color': 'rgb(251,154,153)', 'width': 3}},
#     'name': 'water',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.369940
#     APPB-PQ      0.490389
#     APPB-TQ      0.454590
#     BJRI-ALL     0.644720
#     BJRI-PQ      0.813688
#     BJRI-TQ      0.765641
#     CAKE-ALL     0.803296
#     CAKE-PQ      0.874141
#     CAKE-TQ      0.805386
#     CHIL-ALL     0.564099
#     CHIL-PQ      0.693728
#     CHIL-TQ      0.743227
#     CPKI-ALL     0.888719
#     CPKI-PQ      0.964900
#     CPKI-TQ      0.964900
#     RRGB-ALL     0.631052
#     RRGB-PQ      0.622918
#     RRGB-TQ      0.596129
#     TGIF-ALL     0.495702
#     TGIF-PQ      0.635994
#     TGIF-TQ      0.595425
#     Name: water, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')}],
#   'layout': {'barmode': 'stack',
#    'xaxis': {'showgrid': False, 'showline': False, 'zeroline': False},
#    'yaxis': {'showgrid': False, 'showline': False, 'zeroline': False}}},
#  'service': {'data': [{'marker': {'color': 'rgb(141,211,199)',
#      'line': {'color': 'rgb(141,211,199)', 'width': 3}},
#     'name': 'bill',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.438345
#     APPB-PQ      0.567024
#     APPB-TQ      0.489030
#     BJRI-ALL     0.578962
#     BJRI-PQ      0.804837
#     BJRI-TQ      0.598449
#     CAKE-ALL     0.606757
#     CAKE-PQ      0.752547
#     CAKE-TQ      0.624623
#     CHIL-ALL     0.553133
#     CHIL-PQ      0.673855
#     CHIL-TQ      0.641186
#     CPKI-ALL     0.884318
#     CPKI-PQ      0.994944
#     CPKI-TQ      0.994944
#     RRGB-ALL     0.627282
#     RRGB-PQ      0.770472
#     RRGB-TQ      0.700791
#     TGIF-ALL     0.415762
#     TGIF-PQ      0.524014
#     TGIF-TQ      0.529267
#     Name: bill, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(255,255,179)',
#      'line': {'color': 'rgb(255,255,179)', 'width': 3}},
#     'name': 'check',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.645618
#     APPB-PQ      0.718628
#     APPB-TQ      0.713283
#     BJRI-ALL     0.766457
#     BJRI-PQ      0.851342
#     BJRI-TQ      0.802686
#     CAKE-ALL     0.767658
#     CAKE-PQ      0.807068
#     CAKE-TQ      0.837624
#     CHIL-ALL     0.668565
#     CHIL-PQ      0.731740
#     CHIL-TQ      0.729628
#     CPKI-ALL     0.964900
#     CPKI-PQ      0.950005
#     CPKI-TQ      0.950005
#     RRGB-ALL     0.805255
#     RRGB-PQ      0.768058
#     RRGB-TQ      0.826988
#     TGIF-ALL     0.574144
#     TGIF-PQ      0.666833
#     TGIF-TQ      0.584829
#     Name: check, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(190,186,218)',
#      'line': {'color': 'rgb(190,186,218)', 'width': 3}},
#     'name': 'management',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.584919
#     APPB-PQ      0.666219
#     APPB-TQ      0.569020
#     BJRI-ALL     0.679851
#     BJRI-PQ      0.699278
#     BJRI-TQ      0.688393
#     CAKE-ALL     0.570213
#     CAKE-PQ      0.647324
#     CAKE-TQ      0.632485
#     CHIL-ALL     0.633614
#     CHIL-PQ      0.689221
#     CHIL-TQ      0.663040
#     CPKI-ALL     0.939311
#     CPKI-PQ      0.900409
#     CPKI-TQ      0.900409
#     RRGB-ALL     0.641520
#     RRGB-PQ      0.694446
#     RRGB-TQ      0.668264
#     TGIF-ALL     0.451109
#     TGIF-PQ      0.568618
#     TGIF-TQ      0.542436
#     Name: management, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(251,128,114)',
#      'line': {'color': 'rgb(251,128,114)', 'width': 3}},
#     'name': 'manager',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.465362
#     APPB-PQ      0.487042
#     APPB-TQ      0.499994
#     BJRI-ALL     0.552743
#     BJRI-PQ      0.600582
#     BJRI-TQ      0.612426
#     CAKE-ALL     0.450149
#     CAKE-PQ      0.515321
#     CAKE-TQ      0.535611
#     CHIL-ALL     0.454489
#     CHIL-PQ      0.498073
#     CHIL-TQ      0.523206
#     CPKI-ALL     0.845302
#     CPKI-PQ      0.930640
#     CPKI-TQ      0.930640
#     RRGB-ALL     0.563833
#     RRGB-PQ      0.565553
#     RRGB-TQ      0.557274
#     TGIF-ALL     0.382061
#     TGIF-PQ      0.364999
#     TGIF-TQ      0.400412
#     Name: manager, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(128,177,211)',
#      'line': {'color': 'rgb(128,177,211)', 'width': 3}},
#     'name': 'price',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.613220
#     APPB-PQ      0.665126
#     APPB-TQ      0.657802
#     BJRI-ALL     0.856188
#     BJRI-PQ      0.958170
#     BJRI-TQ      0.926067
#     CAKE-ALL     0.822970
#     CAKE-PQ      0.837079
#     CAKE-TQ      0.889881
#     CHIL-ALL     0.622373
#     CHIL-PQ      0.646449
#     CHIL-TQ      0.735670
#     CPKI-ALL     0.763110
#     CPKI-PQ      0.791908
#     CPKI-TQ      0.958170
#     RRGB-ALL     0.927666
#     RRGB-PQ      0.851188
#     RRGB-TQ      0.889048
#     TGIF-ALL     0.660247
#     TGIF-PQ      0.638555
#     TGIF-TQ      0.706025
#     Name: price, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(253,180,98)',
#      'line': {'color': 'rgb(253,180,98)', 'width': 3}},
#     'name': 'servers',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.552554
#     APPB-PQ      0.529020
#     APPB-TQ      0.508677
#     BJRI-ALL     0.814451
#     BJRI-PQ      0.784180
#     BJRI-TQ      0.649200
#     CAKE-ALL     0.874326
#     CAKE-PQ      0.773641
#     CAKE-TQ      0.698238
#     CHIL-ALL     0.705980
#     CHIL-PQ      0.653349
#     CHIL-TQ      0.526026
#     CPKI-ALL     0.995386
#     CPKI-PQ      0.841542
#     CPKI-TQ      0.841542
#     RRGB-ALL     0.726078
#     RRGB-PQ      0.716912
#     RRGB-TQ      0.607962
#     TGIF-ALL     0.542873
#     TGIF-PQ      0.454572
#     TGIF-TQ      0.382421
#     Name: servers, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(179,222,105)',
#      'line': {'color': 'rgb(179,222,105)', 'width': 3}},
#     'name': 'service',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.526188
#     APPB-PQ      0.533094
#     APPB-TQ      0.569731
#     BJRI-ALL     0.700500
#     BJRI-PQ      0.718131
#     BJRI-TQ      0.799352
#     CAKE-ALL     0.693409
#     CAKE-PQ      0.663555
#     CAKE-TQ      0.747885
#     CHIL-ALL     0.596742
#     CHIL-PQ      0.581865
#     CHIL-TQ      0.653023
#     CPKI-ALL     0.901701
#     CPKI-PQ      0.935229
#     CPKI-TQ      0.935229
#     RRGB-ALL     0.685642
#     RRGB-PQ      0.648006
#     RRGB-TQ      0.663812
#     TGIF-ALL     0.477309
#     TGIF-PQ      0.439418
#     TGIF-TQ      0.479032
#     Name: service, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(252,205,229)',
#      'line': {'color': 'rgb(252,205,229)', 'width': 3}},
#     'name': 'staff',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.620291
#     APPB-PQ      0.612118
#     APPB-TQ      0.536917
#     BJRI-ALL     0.771916
#     BJRI-PQ      0.759787
#     BJRI-TQ      0.797356
#     CAKE-ALL     0.727000
#     CAKE-PQ      0.684088
#     CAKE-TQ      0.721799
#     CHIL-ALL     0.678244
#     CHIL-PQ      0.572813
#     CHIL-TQ      0.617324
#     CPKI-ALL     0.994557
#     CPKI-PQ      0.940142
#     CPKI-TQ      0.940142
#     RRGB-ALL     0.701481
#     RRGB-PQ      0.580012
#     RRGB-TQ      0.648803
#     TGIF-ALL     0.546237
#     TGIF-PQ      0.441528
#     TGIF-TQ      0.618865
#     Name: staff, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(217,217,217)',
#      'line': {'color': 'rgb(217,217,217)', 'width': 3}},
#     'name': 'time',
#     'offset': 0,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.598716
#     APPB-PQ      0.575328
#     APPB-TQ      0.587841
#     BJRI-ALL     0.823824
#     BJRI-PQ      0.801057
#     BJRI-TQ      0.805529
#     CAKE-ALL     0.886630
#     CAKE-PQ      0.885623
#     CAKE-TQ      0.858914
#     CHIL-ALL     0.626110
#     CHIL-PQ      0.586601
#     CHIL-TQ      0.538998
#     CPKI-ALL     0.984011
#     CPKI-PQ      0.966775
#     CPKI-TQ      0.966775
#     RRGB-ALL     0.732706
#     RRGB-PQ      0.659676
#     RRGB-TQ      0.698560
#     TGIF-ALL     0.564159
#     TGIF-PQ      0.442914
#     TGIF-TQ      0.546574
#     Name: time, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(188,128,189)',
#      'line': {'color': 'rgb(188,128,189)', 'width': 3}},
#     'name': 'waiter',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.464155
#     APPB-PQ      0.445422
#     APPB-TQ      0.536786
#     BJRI-ALL     0.609235
#     BJRI-PQ      0.586952
#     BJRI-TQ      0.688728
#     CAKE-ALL     0.598150
#     CAKE-PQ      0.588156
#     CAKE-TQ      0.714228
#     CHIL-ALL     0.494524
#     CHIL-PQ      0.437156
#     CHIL-TQ      0.558347
#     CPKI-ALL     0.879105
#     CPKI-PQ      0.885252
#     CPKI-TQ      0.885252
#     RRGB-ALL     0.629882
#     RRGB-PQ      0.577674
#     RRGB-TQ      0.684579
#     TGIF-ALL     0.405662
#     TGIF-PQ      0.350503
#     TGIF-TQ      0.440710
#     Name: waiter, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')},
#    {'marker': {'color': 'rgb(204,235,197)',
#      'line': {'color': 'rgb(204,235,197)', 'width': 3}},
#     'name': 'waitress',
#     'offset': -0.4,
#     'orientation': 'h',
#     'type': 'bar',
#     'x': APPB-ALL     0.430859
#     APPB-PQ      0.452122
#     APPB-TQ      0.444287
#     BJRI-ALL     0.599125
#     BJRI-PQ      0.671009
#     BJRI-TQ      0.592357
#     CAKE-ALL     0.607873
#     CAKE-PQ      0.638283
#     CAKE-TQ      0.614425
#     CHIL-ALL     0.460039
#     CHIL-PQ      0.530818
#     CHIL-TQ      0.454371
#     CPKI-ALL     0.777664
#     CPKI-PQ      0.938133
#     CPKI-TQ      0.938133
#     RRGB-ALL     0.605816
#     RRGB-PQ      0.583779
#     RRGB-TQ      0.563659
#     TGIF-ALL     0.398098
#     TGIF-PQ      0.412245
#     TGIF-TQ      0.396496
#     Name: waitress, dtype: float64,
#     'y': Index(['APPB-ALL ', 'APPB-PQ ', 'APPB-TQ ', 'BJRI-ALL ', 'BJRI-PQ ',
#            'BJRI-TQ ', 'CAKE-ALL ', 'CAKE-PQ ', 'CAKE-TQ ', 'CHIL-ALL ',
#            'CHIL-PQ ', 'CHIL-TQ ', 'CPKI-ALL ', 'CPKI-PQ ', 'CPKI-TQ ',
#            'RRGB-ALL ', 'RRGB-PQ ', 'RRGB-TQ ', 'TGIF-ALL ', 'TGIF-PQ ',
#            'TGIF-TQ '],
#           dtype='object')}],
#   'layout': {'barmode': 'stack',
#    'xaxis': {'showgrid': False, 'showline': False, 'zeroline': False},
#    'yaxis': {'showgrid': False, 'showline': False, 'zeroline': False}}}}

# %%
py.iplot(dt["food"], filename='marker-h-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~mathieudempsey/180.embed" height="525px" width="100%"></iframe>

# %%
for ar, aes in zip([service,food,preparation,location],["service","food","preparation","location"]):
    for qr, des in zip(["q1_","q2_",""],["q1","q2","all"]):
        frame = types_df[aes][des]

# %%
frame
# Out:
#                  BJRI       APPB       CAKE       CHIL       CPKI       RRGB  \
# name
# area        10.574074   2.277778   4.500000   2.323529   7.825000   4.125000
# atmosphere  46.928571  14.500000  45.333333  33.333333  41.000000  14.428571
# birthday     4.463918   8.250000   3.809917   3.684211  11.800000   6.755102
# experience   3.975831   2.306452   3.448214   1.894737   7.924812   3.620000
# family       7.957447   2.450980   4.419355   2.467532   9.058824   4.027027
# friends     10.047619   3.120000   9.246914   4.782609  20.066667   9.000000
# kids         4.486842   1.575000   2.867647   1.843750  11.452381   3.343511
# location     3.864035   2.255319   3.857451   2.446970   7.700000   3.582090
# night        6.548023   2.753247   5.260135   3.271429   9.068966   3.142857
# outside      4.827586   1.062500   6.649485   1.466667   6.714286   2.956522
# parking      9.047619   2.222222  11.382353   4.000000  50.000000   4.937500
# place        7.157623   1.472803   5.649289   1.955645   7.891509   3.808955
# restaurant   3.492857   1.235955   4.195502   1.761658   5.495098   2.107595
# visit        8.400000   2.347826   5.320896   2.980392  15.500000   4.202381
#
#                 TGIF
# name
# area        1.737374
# atmosphere  6.529412
# birthday    1.684211
# experience  1.257353
# family      1.252336
# friends     2.188406
# kids        1.181818
# location    1.414286
# night       1.761628
# outside     0.944444
# parking     1.000000
# place       1.115010
# restaurant  0.840000
# visit       2.438596

# %%
types_df["food"]["q1"]
# Out:
#              BJRI      APPB      CAKE      CHIL       CPKI      RRGB      TGIF
# name
# bread    4.000000       inf  3.500000       inf        inf       inf       inf
# burger        inf       inf  1.000000  2.000000        inf  1.125000  1.333333
# cheese   1.500000  1.000000  1.800000  2.000000   1.000000       inf  0.333333
# chicken  3.000000       inf  2.133333       inf        inf  1.500000       inf
# dessert  4.000000  0.333333  8.000000       inf        inf       inf       inf
# fries         inf       inf  0.200000       inf        inf  1.125000  0.500000
# pasta         inf       inf  0.923077       inf   1.000000       inf       inf
# pizza    6.000000  5.250000  3.000000  5.250000   6.750000  5.250000  5.250000
# salad    1.000000  3.527778  0.777778  3.527778  12.000000  0.333333  3.527778
# steak    1.000000  1.000000  0.916667       inf        inf       inf       inf

# %%
all_fir
# Out:
#                  BJRI       APPB       CAKE       CHIL       CPKI       RRGB  \
# name
# area         4.446328   4.398404   4.405805   4.328219   4.403217   4.393987
# atmosphere  27.854772  27.530364  28.355212  28.412214  28.739777  28.031802
# birthday     4.308271   4.318125   4.251357   4.245567   4.325890   4.387565
# experience   3.298080   3.278138   3.292299   3.250180   3.338144   3.345900
# family       4.453003   4.407258   4.408189   4.348297   4.442655   4.425292
# friends      7.299803   7.199230   7.347321   7.295713   7.461140   7.488550
# kids         3.446737   3.405892   3.368715   3.320708   3.485301   3.476881
# location     3.521871   3.498211   3.528480   3.503110   3.612082   3.611074
# night        4.447913   4.408514   4.478381   4.455411   4.527034   4.486746
# outside      4.659658   4.585586   4.814645   4.758155   4.817884   4.772340
# parking      8.158442   8.022843   8.289720   8.182232   8.559819   8.433551
# place        4.168231   4.094716   4.199447   4.141746   4.222403   4.208812
# restaurant   2.868400   2.830555   2.926114   2.899515   2.960707   2.930650
# visit        5.288259   5.201665   5.211085   5.145965   5.309296   5.259279
#
#                  TGIF
# name
# area         4.264300
# atmosphere  26.813333
# birthday     4.335366
# experience   3.270557
# family       4.302460
# friends      7.195513
# kids         3.410211
# location     3.536522
# night        4.370149
# outside      4.631148
# parking      8.049587
# place        4.060538
# restaurant   2.846747
# visit        5.175365

# %%
frame
# Out:
#                  BJRI       APPB       CAKE       CHIL       CPKI       RRGB  \
# name
# area         4.446328   4.398404   4.405805   4.328219   4.403217   4.393987
# atmosphere  27.854772  27.530364  28.355212  28.412214  28.739777  28.031802
# birthday     4.308271   4.318125   4.251357   4.245567   4.325890   4.387565
# experience   3.298080   3.278138   3.292299   3.250180   3.338144   3.345900
# family       4.453003   4.407258   4.408189   4.348297   4.442655   4.425292
# friends      7.299803   7.199230   7.347321   7.295713   7.461140   7.488550
# kids         3.446737   3.405892   3.368715   3.320708   3.485301   3.476881
# location     3.521871   3.498211   3.528480   3.503110   3.612082   3.611074
# night        4.447913   4.408514   4.478381   4.455411   4.527034   4.486746
# outside      4.659658   4.585586   4.814645   4.758155   4.817884   4.772340
# parking      8.158442   8.022843   8.289720   8.182232   8.559819   8.433551
# place        4.168231   4.094716   4.199447   4.141746   4.222403   4.208812
# restaurant   2.868400   2.830555   2.926114   2.899515   2.960707   2.930650
# visit        5.288259   5.201665   5.211085   5.145965   5.309296   5.259279
#
#                  TGIF
# name
# area         4.264300
# atmosphere  26.813333
# birthday     4.335366
# experience   3.270557
# family       4.302460
# friends      7.195513
# kids         3.410211
# location     3.536522
# night        4.370149
# outside      4.631148
# parking      8.049587
# place        4.060538
# restaurant   2.846747
# visit        5.175365

# %%
types_df[aes]["q2"]
# Out:
#                  BJRI       APPB       CAKE       CHIL       CPKI       RRGB  \
# name
# area         4.262779   4.262779   4.256377   4.249347   4.250000   4.250000
# atmosphere  26.656388  26.656388  26.660793  26.665198  26.674009  26.678414
# birthday     4.297858   4.297858   4.294393   4.292195   4.294196   4.298199
# experience   3.264194   3.263972   3.264618   3.262105   3.263684   3.261174
# family       4.304473   4.304473   4.298608   4.298608   4.300048   4.297842
# friends      7.166667   7.144974   7.135021   7.135021   7.138186   7.138186
# kids         3.397085   3.397085   3.401166   3.401166   3.404082   3.400699
# location     3.520410   3.519872   3.518447   3.515875   3.516830   3.514797
# night        4.344181   4.344181   4.340335   4.340335   4.340991   4.335628
# outside      4.651639   4.651639   4.651639   4.651639   4.653005   4.653005
# parking      8.085165   8.085165   8.098901   8.098901   8.104396   8.107143
# place        4.049783   4.048026   4.042109   4.037247   4.037603   4.034733
# restaurant   2.835151   2.833687   2.833663   2.833663   2.834394   2.831356
# visit        5.144828   5.141971   5.146106   5.146106   5.147484   5.148863
#
#                  TGIF
# name
# area         4.231319
# atmosphere  26.678414
# birthday     4.298199
# experience   3.258799
# family       4.295161
# friends      7.117771
# kids         3.400699
# location     3.505308
# night        4.326357
# outside      4.653005
# parking      8.107143
# place        4.026054
# restaurant   2.831356
# visit        5.148863

# %%
types_df[aes]["q1"]
# Out:
#                  BJRI       APPB       CAKE       CHIL       CPKI       RRGB  \
# name
# area         4.262812   4.262812   4.265266   4.265266   4.266579   4.264436
# atmosphere  26.831111  26.831111  26.862222  26.866667  26.871111  26.871111
# birthday     4.327248   4.322080   4.302482   4.302482   4.303152   4.302949
# experience   3.269435   3.269435   3.267360   3.266514   3.267876   3.266854
# family       4.305837   4.305837   4.305395   4.305877   4.306840   4.302549
# friends      7.198718   7.198718   7.161359   7.161359   7.162420   7.163482
# kids         3.409971   3.404567   3.395797   3.395797   3.396964   3.399299
# location     3.536622   3.534553   3.525515   3.524105   3.524197   3.521823
# night        4.366799   4.357355   4.351913   4.349703   4.349588   4.349588
# outside      4.633880   4.633880   4.650273   4.650273   4.651639   4.651639
# parking      8.041209   8.043956   8.071429   8.071429   8.074176   8.074176
# place        4.059116   4.059116   4.060293   4.058648   4.059006   4.054088
# restaurant   2.846121   2.843830   2.841933   2.841006   2.841313   2.841455
# visit        5.177453   5.177453   5.160083   5.155709   5.156401   5.156401
#
#                  TGIF
# name
# area         4.265748
# atmosphere  26.756637
# birthday     4.302949
# experience   3.264111
# family       4.302549
# friends      7.163482
# kids         3.399299
# location     3.521823
# night        4.341993
# outside      4.651639
# parking      8.074176
# place        4.051438
# restaurant   2.839722
# visit        5.156401

# %%
for coy in code:

# %%
types_df
# Out:
# {'food': {'all':               BJRI      APPB      CAKE      CHIL      CPKI      RRGB      TGIF
#   name
#   bread     0.205502  0.209813  0.208661  0.209005  0.199008  0.200292  0.204289
#   burger    0.274672  0.287850  0.277677  0.284326  0.284051  0.258530  0.272213
#   cheese    0.257088  0.272143  0.232906  0.239895  0.233049  0.232431  0.248500
#   chicken   0.172251  0.179213  0.163738  0.172632  0.161159  0.164087  0.177136
#   dessert   0.116686  0.122308  0.117121  0.118306  0.114482  0.114843  0.118319
#   fries     0.256878  0.270870  0.257641  0.266359  0.266184  0.238039  0.250145
#   pasta     0.198908  0.205206  0.190518  0.191453  0.183658  0.183811  0.190747
#   pizza     0.134142  0.134142  0.138323  0.138602  0.123324  0.123662  0.124626
#   salad     0.259825  0.272227  0.266468  0.271998  0.245999  0.254037  0.261982
#   sandwich  0.258741  0.267898  0.240141  0.248705  0.247306  0.247247  0.261341
#   sauce     0.241849  0.257143  0.222865  0.226355  0.220909  0.215603  0.228582
#   steak     0.275397  0.306818  0.277530  0.288998  0.282232  0.264279  0.279842,
#   'q1':               BJRI      APPB      CAKE      CHIL      CPKI      RRGB      TGIF
#   name
#   bread     0.204356  0.204356  0.204971  0.204971  0.204309  0.204235  0.204235
#   burger    0.272012  0.272012  0.272370  0.272482  0.272482  0.273842  0.274308
#   cheese    0.248896  0.249133  0.250862  0.251018  0.251253  0.251096  0.251956
#   chicken   0.177275  0.177275  0.178656  0.178603  0.178339  0.178556  0.178556
#   dessert   0.118513  0.119573  0.119621  0.119621  0.119490  0.119490  0.119446
#   fries     0.250073  0.250073  0.251452  0.251452  0.251452  0.253113  0.253619
#   pasta     0.190675  0.190675  0.194717  0.194717  0.195628  0.195628  0.195628
#   pizza     0.124706  0.124706  0.124902  0.124902  0.125000  0.125000  0.125000
#   salad     0.262497  0.262497  0.265817  0.265817  0.265311  0.265943  0.265943
#   sandwich  0.261341  0.261341  0.263780  0.263780  0.264503  0.264244  0.264244
#   sauce     0.228582  0.228582  0.230970  0.230884  0.231916  0.231830  0.233234
#   steak     0.280248  0.280652  0.285634  0.285634  0.285315  0.285315  0.285315,
#   'q2':               BJRI      APPB      CAKE      CHIL      CPKI      RRGB      TGIF
#   name
#   bread     0.203943  0.203943  0.204845  0.204845  0.204836  0.204836  0.204836
#   burger    0.274994  0.276637  0.277317  0.277317  0.277249  0.279155  0.279155
#   cheese    0.252816  0.252816  0.252179  0.252179  0.252331  0.252563  0.254969
#   chicken   0.178893  0.178988  0.178703  0.178703  0.178802  0.179284  0.180938
#   dessert   0.119767  0.119767  0.119463  0.119463  0.119695  0.119695  0.119695
#   fries     0.254340  0.254340  0.254482  0.254482  0.254409  0.256970  0.259483
#   pasta     0.195931  0.195931  0.196998  0.196998  0.196636  0.196636  0.196636
#   pizza     0.125974  0.125974  0.125818  0.125818  0.125948  0.125948  0.125948
#   salad     0.266313  0.266313  0.266207  0.266207  0.265904  0.267490  0.269029
#   sandwich  0.266862  0.266862  0.266278  0.266278  0.265761  0.264990  0.264990
#   sauce     0.235666  0.235666  0.236364  0.236364  0.235926  0.235947  0.235860
#   steak     0.284997  0.284997  0.284211  0.284607  0.284607  0.285003  0.285003},
#  'location': {'all':                 BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   area        0.224905  0.227355  0.226973  0.231042  0.227107  0.227584
#   atmosphere  0.035900  0.036324  0.035267  0.035196  0.034795  0.035674
#   birthday    0.232112  0.231582  0.235219  0.235540  0.231166  0.227917
#   experience  0.303207  0.305051  0.303739  0.307675  0.299568  0.298873
#   family      0.224568  0.226898  0.226851  0.229975  0.225091  0.225974
#   friends     0.136990  0.138904  0.136104  0.137067  0.134028  0.133537
#   kids        0.290129  0.293609  0.296849  0.301141  0.286919  0.287614
#   location    0.283940  0.285860  0.283408  0.285461  0.276849  0.276926
#   night       0.224825  0.226834  0.223295  0.224446  0.220895  0.222879
#   outside     0.214608  0.218075  0.207700  0.210165  0.207560  0.209541
#   parking     0.122572  0.124644  0.120631  0.122216  0.116825  0.118574
#   place       0.239910  0.244217  0.238127  0.241444  0.236832  0.237597
#   restaurant  0.348626  0.353288  0.341750  0.344885  0.337757  0.341221
#   visit       0.189098  0.192246  0.191899  0.194327  0.188349  0.190140
#
#                   TGIF
#   name
#   area        0.234505
#   atmosphere  0.037295
#   birthday    0.230661
#   experience  0.305758
#   family      0.232425
#   friends     0.138976
#   kids        0.293237
#   location    0.282764
#   night       0.228825
#   outside     0.215929
#   parking     0.124230
#   place       0.246273
#   restaurant  0.351278
#   visit       0.193223  ,
#   'q1':                 BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   area        0.234587  0.234587  0.234452  0.234452  0.234380  0.234498
#   atmosphere  0.037270  0.037270  0.037227  0.037221  0.037215  0.037215
#   birthday    0.231094  0.231370  0.232424  0.232424  0.232388  0.232399
#   experience  0.305863  0.305863  0.306058  0.306137  0.306009  0.306105
#   family      0.232243  0.232243  0.232267  0.232241  0.232189  0.232420
#   friends     0.138914  0.138914  0.139638  0.139638  0.139618  0.139597
#   kids        0.293258  0.293723  0.294482  0.294482  0.294380  0.294178
#   location    0.282756  0.282921  0.283647  0.283760  0.283753  0.283944
#   night       0.229001  0.229497  0.229784  0.229901  0.229907  0.229907
#   outside     0.215802  0.215802  0.215041  0.215041  0.214978  0.214978
#   parking     0.124359  0.124317  0.123894  0.123894  0.123852  0.123852
#   place       0.246359  0.246359  0.246288  0.246387  0.246366  0.246665
#   restaurant  0.351355  0.351638  0.351873  0.351988  0.351950  0.351932
#   visit       0.193145  0.193145  0.193795  0.193960  0.193934  0.193934
#
#                   TGIF
#   name
#   area        0.234425
#   atmosphere  0.037374
#   birthday    0.232399
#   experience  0.306362
#   family      0.232420
#   friends     0.139597
#   kids        0.294178
#   location    0.283944
#   night       0.230309
#   outside     0.214978
#   parking     0.123852
#   place       0.246826
#   restaurant  0.352147
#   visit       0.193934  ,
#   'q2':                 BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   area        0.234589  0.234589  0.234942  0.235330  0.235294  0.235294
#   atmosphere  0.037514  0.037514  0.037508  0.037502  0.037490  0.037483
#   birthday    0.232674  0.232674  0.232862  0.232981  0.232872  0.232656
#   experience  0.306354  0.306375  0.306315  0.306551  0.306402  0.306638
#   family      0.232316  0.232316  0.232633  0.232633  0.232556  0.232675
#   friends     0.139535  0.139959  0.140154  0.140154  0.140092  0.140092
#   kids        0.294370  0.294370  0.294017  0.294017  0.293765  0.294057
#   location    0.284058  0.284101  0.284216  0.284424  0.284347  0.284511
#   night       0.230193  0.230193  0.230397  0.230397  0.230362  0.230647
#   outside     0.214978  0.214978  0.214978  0.214978  0.214915  0.214915
#   parking     0.123683  0.123683  0.123474  0.123474  0.123390  0.123348
#   place       0.246927  0.247034  0.247396  0.247694  0.247672  0.247848
#   restaurant  0.352715  0.352897  0.352900  0.352900  0.352809  0.353188
#   visit       0.194370  0.194478  0.194322  0.194322  0.194270  0.194218
#
#                   TGIF
#   name
#   area        0.236333
#   atmosphere  0.037483
#   birthday    0.232656
#   experience  0.306862
#   family      0.232820
#   friends     0.140493
#   kids        0.294057
#   location    0.285282
#   night       0.231141
#   outside     0.214915
#   parking     0.123348
#   place       0.248382
#   restaurant  0.353188
#   visit       0.194218  },
#  'preparation': {'all':                BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   appetizer  0.333478  0.347438  0.327510  0.330404  0.320271  0.324544
#   bar        0.240147  0.245403  0.236955  0.242746  0.235539  0.237977
#   beer       0.135211  0.141219  0.143233  0.144684  0.144373  0.150284
#   dinner     0.197238  0.202996  0.197119  0.200724  0.195908  0.196454
#   dish       0.171377  0.173240  0.179702  0.182602  0.178592  0.178278
#   drink      0.490487  0.509060  0.499538  0.507366  0.493131  0.492251
#   drinks     0.359565  0.366129  0.360368  0.363317  0.352960  0.354326
#   food       0.344163  0.352508  0.342231  0.347922  0.335390  0.337847
#   kitchen    1.047994  1.070877  1.085953  1.123977  0.998370  1.009464
#   lunch      0.141569  0.144125  0.139395  0.143448  0.138019  0.139471
#   meal       0.327719  0.333937  0.324011  0.332665  0.320451  0.319917
#   menu       0.102602  0.106672  0.098369  0.100294  0.098223  0.099023
#   order      0.703644  0.717861  0.688435  0.698145  0.673677  0.677519
#   plates     0.798836  0.826087  0.760943  0.778667  0.753312  0.758385
#   portion    0.100324  0.103938  0.090681  0.093196  0.091712  0.096070
#   water      1.129630  1.174268  1.096461  1.115148  1.073958  1.082783
#
#                  TGIF
#   name
#   appetizer  0.339825
#   bar        0.253890
#   beer       0.157874
#   dinner     0.202412
#   dish       0.181935
#   drink      0.508716
#   drinks     0.367052
#   food       0.348516
#   kitchen    1.051402
#   lunch      0.142929
#   meal       0.330864
#   menu       0.105116
#   order      0.698959
#   plates     0.803670
#   portion    0.100100
#   water      1.118087  ,
#   'q1':                BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   appetizer  0.340063  0.340467  0.340286  0.340286  0.340204  0.340121
#   bar        0.254227  0.254781  0.254653  0.254653  0.254496  0.254433
#   beer       0.157667  0.157667  0.157667  0.157667  0.157667  0.157667
#   dinner     0.202765  0.202765  0.202709  0.202661  0.202660  0.202517
#   dish       0.181740  0.181740  0.181779  0.181779  0.181701  0.181701
#   drink      0.508709  0.508709  0.508200  0.508200  0.507698  0.507993
#   drinks     0.367222  0.367959  0.368567  0.368888  0.368701  0.368800
#   food       0.348612  0.348848  0.349233  0.349445  0.349468  0.349597
#   kitchen    1.051402  1.051402  1.050505  1.049689  1.048799  1.048799
#   lunch      0.143272  0.143272  0.143253  0.143253  0.143559  0.143576
#   meal       0.330695  0.330695  0.332442  0.332824  0.332655  0.332952
#   menu       0.105274  0.105406  0.105256  0.105249  0.105190  0.105223
#   order      0.699331  0.699786  0.701593  0.702407  0.702183  0.702560
#   plates     0.803670  0.803670  0.804945  0.804945  0.805124  0.805124
#   portion    0.100100  0.100100  0.100299  0.100299  0.100199  0.100199
#   water      1.118087  1.118087  1.118087  1.118087  1.117164  1.117164
#
#                  TGIF
#   name
#   appetizer  0.340121
#   bar        0.254769
#   beer       0.157667
#   dinner     0.202539
#   dish       0.181701
#   drink      0.508876
#   drinks     0.369522
#   food       0.350041
#   kitchen    1.048799
#   lunch      0.143810
#   meal       0.333164
#   menu       0.105278
#   order      0.703012
#   plates     0.805124
#   portion    0.100199
#   water      1.117077  ,
#   'q2':                BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   appetizer  0.340189  0.340106  0.339768  0.340410  0.340082  0.340241
#   bar        0.254859  0.254796  0.255071  0.256268  0.256143  0.256448
#   beer       0.157431  0.157431  0.157400  0.157400  0.157400  0.157400
#   dinner     0.202373  0.202373  0.202155  0.202155  0.202130  0.202130
#   dish       0.182402  0.182402  0.182285  0.182285  0.182012  0.182012
#   drink      0.509163  0.508862  0.509048  0.509048  0.508948  0.509434
#   drinks     0.369457  0.369527  0.369368  0.369990  0.369896  0.370738
#   food       0.350176  0.350342  0.350176  0.350910  0.350649  0.351062
#   kitchen    1.048799  1.048799  1.049536  1.049536  1.049536  1.049536
#   lunch      0.144042  0.144042  0.144075  0.144308  0.144127  0.144198
#   meal       0.333884  0.333927  0.333756  0.333756  0.333502  0.333798
#   menu       0.105307  0.105307  0.105110  0.105103  0.104994  0.105027
#   order      0.703868  0.703868  0.703666  0.703666  0.703673  0.703826
#   plates     0.805302  0.805302  0.803099  0.803099  0.801638  0.801638
#   portion    0.100199  0.100199  0.100448  0.100448  0.100448  0.100448
#   water      1.117077  1.117077  1.112760  1.112760  1.111769  1.113166
#
#                  TGIF
#   name
#   appetizer  0.340241
#   bar        0.257950
#   beer       0.157400
#   dinner     0.202761
#   dish       0.182012
#   drink      0.511984
#   drinks     0.371719
#   food       0.352144
#   kitchen    1.049536
#   lunch      0.144645
#   meal       0.334642
#   menu       0.105027
#   order      0.705103
#   plates     0.801638
#   portion    0.100448
#   water      1.113166  },
#  'service': {'all':                 BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   bill        1.728000  2.099338  1.763240  1.784153  1.518519  1.488073
#   check       1.013514  1.115819  1.045390  1.089172  0.960961  0.945360
#   management  0.984733  1.084337  1.271375  1.254839  1.021531  1.032990
#   manager     1.098495  1.210300  1.433640  1.467638  1.056279  1.035059
#   price       0.157025  0.201320  0.176737  0.192254  0.192799  0.183992
#   servers     0.231092  0.288848  0.229853  0.240905  0.216852  0.228041
#   service     0.255759  0.295875  0.264784  0.274617  0.238247  0.238626
#   staff       0.204040  0.226613  0.211808  0.215125  0.181113  0.186400
#   time        0.300522  0.351701  0.270788  0.296040  0.268960  0.280959
#   waiter      0.463918  0.530658  0.483809  0.506494  0.440852  0.435084
#   waitress    0.546012  0.684000  0.567919  0.613636  0.544505  0.531250
#
#                   TGIF
#   name
#   bill        1.687822
#   check       1.030919
#   management  1.173410
#   manager     1.146732
#   price       0.194707
#   servers     0.254129
#   service     0.266380
#   staff       0.206051
#   time        0.309135
#   waiter      0.488903
#   waitress    0.609715  ,
#   'q1':                 BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   bill        2.000000  2.000000  3.500000  3.500000  3.500000  3.500000
#   management  2.000000  1.500000  2.250000  2.400000  2.400000  2.400000
#   price       0.686667  0.686667  1.000000  0.666667  0.666667  0.500000
#   servers     0.500000  0.500000  0.500000  0.454545  0.416667  0.357143
#   service     0.181818  0.581395  0.476636  0.500000  0.465278  0.529412
#   staff       2.500000  2.500000  0.434783  0.541667  0.481481  0.551724
#   time        0.526316  0.695652  0.651163  0.752809  0.672897  0.684211
#   waiter      0.428571  0.636364  0.730769  0.730769  0.700000  0.677419
#   waitress    0.400000  1.333333  1.312500  1.526316  1.160000  1.448276
#
#                   TGIF
#   name
#   bill        3.500000
#   management  2.400000
#   price       0.600000
#   servers     0.357143
#   service     0.610063
#   staff       0.531250
#   time        0.735043
#   waiter      0.677419
#   waitress    1.516129  ,
#   'q2':                 BJRI      APPB      CAKE      CHIL      CPKI      RRGB  \
#   name
#   bill        2.666667  2.666667  2.666667  2.666667  2.666667  2.666667
#   check       1.500000  1.500000  1.500000  1.500000  1.500000  1.909091
#   management  2.400000  2.400000  2.400000  2.400000  2.166667  2.166667
#   manager     2.870968  2.875000  2.942857  3.054054  2.651163  2.666667
#   price       0.600000  0.600000  0.714286  0.714286  0.625000  0.545455
#   servers     0.466667  0.500000  0.363636  0.478261  0.520000  0.576923
#   service     0.574359  0.582915  0.514056  0.572549  0.511945  0.532468
#   staff       0.500000  0.589744  0.583333  0.725490  0.637931  0.655738
#   time        0.707143  0.739437  0.664865  0.747312  0.691176  0.719048
#   waiter      1.088235  1.085714  0.788462  0.854545  0.758065  0.769231
#   waitress    1.388889  1.378378  1.018182  1.033898  0.953125  1.088235
#
#                   TGIF
#   name
#   bill        3.000000
#   check       1.909091
#   management  2.166667
#   manager     3.042553
#   price       0.545455
#   servers     0.576923
#   service     0.618297
#   staff       0.793651
#   time        0.791469
#   waiter      0.893939
#   waitress    1.222222  }}

# %%
big_pro_g = pd.read_csv(path_in_pos +"big_ass_"+code[0]+"_good_bad_pro.csv")
coll_df = pd.DataFrame(columns=big_pro_g.columns)
#code = code.iloc[0] 
for coy in code:

    big_pro_g = pd.read_csv(path_in_pos +"big_ass_"+coy+"_good_bad_pro.csv")
    coll_df = pd.concat((coll_df,big_pro_g), axis=0)

len(coll_df)

coll_df["best"] = coll_df["best"].astype(float)

rat = coll_df.groupby("name").sum()

rat.sort_values("best",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-532c44268899> in <module>()
#      11 coll_df["best"] = coll_df["best"].astype(float)
#      12
# ---> 13 rat = coll_df.groupby("name").sum()
#      14
#      15 rat.sort_values("best",ascending=False)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1757         raise TypeError('invalid type: %s' % type(obj))
#    1758
# -> 1759     return klass(obj, by, **kwds)
#    1760
#    1761
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated, validate)
#    2840                 in_axis, name, level, gpr = False, None, gpr, None
#    2841             else:
# -> 2842                 raise KeyError(gpr)
#    2843         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2844             # Add key to exclusions
#
# KeyError: 'name'

# %%
big_pro_b = pd.read_csv(path_in_pos +"big_ass_"+coy+"_bad_good_pro.csv")

# %%
big_pro.sort_values("best", ascending=False)
# Out:
#                        entity  best      da  worst     da2
# 0                          BJ  2847  PERSON  389.0  PERSON
# 1                         the  1199     ORG  148.0     ORG
# 2                        Best   314  PERSON    0.0       0
# 3                        Mark   306     ORG    0.0       0
# 4                         San   283  PERSON   16.0     GPE
# 5                         The   225  PERSON   15.0  PERSON
# 6                    Pizookie   201  PERSON    7.0  PERSON
# 7                               187     GPE    0.0       0
# 8                       David   184  PERSON   11.0  PERSON
# 9                  California   165     GPE    9.0     GPE
# 10                      Chili   141  PERSON    2.0     ORG
# 11                       John   132  PERSON    0.0       0
# 12                       BEST   124     ORG    0.0       0
# 13                        BBQ   120     ORG   11.0     ORG
# 14                   Jeremiah   112  PERSON    2.0  PERSON
# 15                      Bacon   105     ORG    0.0       0
# 16                       Alex   102  PERSON    0.0       0
# 17                         GM   100     ORG    9.0     GPE
# 18                    AMAZING    97     ORG    0.0       0
# 19              Mediterranean    95     ORG    0.0       0
# 20                   Parmesan    94  PERSON   11.0     ORG
# 21                       Fish    93     ORG   16.0  PERSON
# 22                        IPA    91     ORG    0.0       0
# 24                    Michael    88     ORG    5.0  PERSON
# 23                      Berry    88  PERSON    0.0       0
# 25                         LA    87     GPE   12.0     ORG
# 26                       Brea    87     ORG   10.0  PERSON
# 27                        Ahi    85  PERSON    0.0       0
# 28                   Courtney    85  PERSON    0.0       0
# 29                  Brewhouse    80     GPE    6.0  PERSON
# ...                       ...   ...     ...    ...     ...
# 1104                   Jessie     1  PERSON    0.0       0
# 1105                  DARLENE     1  PERSON    0.0       0
# 1106               JesseGreat     1     ORG    0.0       0
# 1107          Justin!Lakeisha     1  PERSON    0.0       0
# 1108                  Justine     1  PERSON    0.0       0
# 1109                  Jyssica     1  PERSON    0.0       0
# 1110                 Clifford     1  PERSON    0.0       0
# 1092                  Courage     1     ORG    0.0       0
# 1090                  Juniper     1     ORG    0.0       0
# 1070                 Kindness     1     ORG    0.0       0
# 1079                Cavaliers     1     ORG    0.0       0
# 1071                   Kimmie     1  PERSON    0.0       0
# 1072                 Claudian     1     GPE    0.0       0
# 1073                 Lakeland     1     GPE    0.0       0
# 1074              Lienenkugel     1     ORG    0.0       0
# 1075                 Liefmans     1  PERSON    0.0       0
# 1076  Lexington!!!!Delightful     1     GPE    0.0       0
# 1077                  Lettuce     1  PERSON    1.0  PERSON
# 1078                  Leticia     1  PERSON    0.0       0
# 1080                   Layout     1  PERSON    0.0       0
# 1089             Consistantly     1     ORG    0.0       0
# 1081                 Lawrence     1  PERSON    0.0       0
# 1082               Centennial     1     ORG    0.0       0
# 1083                Chainland     1     GPE    0.0       0
# 1084                  Cheddar     1     ORG    0.0       0
# 1085             Cheers!!Been     1     ORG    0.0       0
# 1086                Lancaster     1     GPE    0.0       0
# 1087                 Lakewood     1     GPE    0.0       0
# 1088                   Killer     1     ORG    0.0       0
# 1557                  Ayodeji     1  PERSON    0.0       0
#
# [1558 rows x 5 columns]

# %%
import pandas as pd
import numpy as np 
import json
import os
from datetime import *

my_path = os.path.abspath(os.path.dirname('__file__'))
path_in_ngrams = os.path.join(my_path, "../data/cpickle/")
my_path = os.path.abspath(os.path.dirname('__file__'))
path = os.path.join(my_path, "../input_fields.csv")

input_fields = pd.read_csv(path)

code = input_fields["code_or_ticker"]


from os import listdir
from os.path import isfile, join


code = input_fields["code_or_ticker"]
full_dict = {}

#code = code.iloc[0] 
for coy in code:
    full_dict[coy] = {}
    
    my_path = os.path.abspath(os.path.dirname('__file__'))
    path = os.path.join(my_path, "../data/yelp_extra_info/" + coy + "/")

    path_out = os.path.join(my_path, "../data/extra_info/")

    onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]

    names_final = []
    for li in onlyfiles:
        if len(li) > 15:
            li = li[:-4]
            names_final.append(li)

    rat = ""
    for li in onlyfiles:
        rat = rat + li + "-"

    from collections import Counter
    import re

    coun = Counter(rat.split("-"))

    ad = pd.DataFrame()

    ad["word"] = list(coun.keys())
    ad["number"] = list(coun.values())

    ad = ad.sort_values("number", ascending=False)

    ad = ad[~(np.abs(ad.number - ad.number.mean()) <= (3.2 * ad.number.std()))]

    ad.reset_index(inplace=True, drop=True)
    ad["word_1"] = "-" + ad["word"] + "-"
    ad["word_2"] = ad["word"] + "-"
    ad["word_3"] = "-" + ad["word"]

    ad["final"] = ad["word_1"]

    words = list(ad["final"].append(ad["word_2"]).append(ad["word_3"]).values)

    full_names = []
    small_names = []
    for i in range(len(onlyfiles)):
        my_string = onlyfiles[i]
        full_names.append(my_string)
        li = my_string
        if len(li) > 4:
            li = re.sub(r'|'.join(map(re.escape, list(words))), '', li)
            small_names.append(li[:-4])
            
            
    for big, small in zip(full_names, small_names):
        
        path = my_path + "/../data/yelp_extra_info/" + coy + "/"+big

        extra = pd.read_csv(path)

        extra_dict = {}

        extra_dict["hours_open"] = {}

        for i, h in zip(extra["Day"], extra["Hours Opened"]):
            try:
                if len(i)>1:
                    extra_dict["hours_open"][i] =  h 
            except:
                continue

        extra_dict["business_info"] = {}

        for i, h in zip(extra["Business Info"], extra["Detail"]):
            try:
                if len(i)>1:
                    extra_dict["business_info"][i] =  h 
            except:
                continue

        extra_dict["also_considered"] = {}

        for i, h in zip(extra["Also-Considered"], extra["Considered Link"]):
            try:
                if len(i)>1:
                    extra_dict["also_considered"][i] =  h 
            except:
                continue

        extra_dict["also_viewed"] = {}

        for i, h in zip(extra["Also-Viewed"], extra["Viewed Link"]):
            try:
                if len(i)>1:
                    extra_dict["also_viewed"][i] =  h 
            except:
                continue
        extra_dict["small_name"] = small 
            
        full_dict[coy][big] = extra_dict


info_dict = {} 
for i in full_dict.keys():
    info_dict[i] = {}
    for r in full_dict[i].keys():
        ext = full_dict[i][r]
        info_dict[i][r] = {}
        total_hours = 0 
        for g, hours in ext["hours_open"].items():
            hours = hours.replace(' Open now',"")
            if hours == "Closed":
                continue
            if len(hours.split("-"))>2:
                
                ga = hours.split("-")
                ra = ga[1].split(ga[1][6:9].replace(" ", ""))

                str_dict = {} 
                a = -1 
                for w in ra[:2]:
                    a = a+1
                    if ga[1][6:9].replace(" ", "") not in w:
                        str_dict[a] = w + ga[1][6:9].replace(" ", "")

                time_1 = str_dict[0][1:]
                time_2 = str_dict[0][1:]

                t1 = datetime.strptime(time_1, '%I:%M %p')
                t2 = datetime.strptime(time_2, '%I:%M %p')
                diffy_dat = t2-t1
                
                time_1 = hours.split("-")[0][:-1]

                time_2 = hours.split("-")[2][1:]
                
                t1 = datetime.strptime(time_1, '%I:%M %p')
                t2 = datetime.strptime(time_2, '%I:%M %p')
                tdiff = t2-t1
                tdiff = tdiff - diffy_dat
            else:
                time_1 = hours.split("-")[0][:-1]

                time_2 = hours.split("-")[1][1:]

                t1 = datetime.strptime(time_1, '%I:%M %p')
                t2 = datetime.strptime(time_2, '%I:%M %p')
                tdiff = t2-t1
            hours = tdiff.seconds/(60*60)
            total_hours = total_hours + hours
        info_dict[i][r]["total_hours"] = total_hours

# %%
list_infos = [] 
for i in full_dict.keys():
    for r in full_dict[i].keys():
        ext = full_dict[i][r]
        list_infos.extend(list(ext["business_info"].keys()))

list_infos.append("Small Name")
list_infos.append("Target Name")
list_infos.append("Hours Open")

new_frame = pd.DataFrame(index=list(set(list_infos)))

for i in full_dict.keys():
    for r in full_dict[i].keys():
        ext = full_dict[i][r]
        ext["business_info"]["Small Name"] = ext["small_name"]
        ext["business_info"]["Target Name"] = i 
        ext["business_info"]["Hours Open"] = info_dict[i][r]["total_hours"]
        fa  = pd.DataFrame.from_dict(ext["business_info"], orient='index', dtype=None)
        fa.columns = [r]
        new_frame = new_frame.join(fa,how="outer")

frame_t = new_frame.T
frame_t_2 = frame_t.fillna(frame_t.mode().T[0])

frame_t_2["Wi-Fi"] = frame_t_2["Wi-Fi"].replace(['Paid','Paid'], 'No')

frame_t_2["Wi-Fi"] = frame_t_2["Wi-Fi"].replace('Free', 'Yes')

frame_t_2["Free Wi-Fi"]= frame_t_2["Wi-Fi"]

frame_t_2["Delivers"]= frame_t_2["Delivery"]

frame_t_2["Noisy"] = frame_t_2['Noise Level'].replace(['Average','Quiet'], 'No')

frame_t_2["Noisy"] = frame_t_2["Noisy"].replace(['Loud','Very Loud'], 'Yes')

final_df = frame_t_2[['Free Wi-Fi','Target Name', 'Hours Open', 'Takes Reservations', 'Outdoor Seating','DeliverS','Caters','Bike Parking','Accepts Apple Pay','Accepts Android Pay', 'Noisy']]

i_dict = {}

for ra in list(final_df["Target Name"].unique()):
    i_dict[ra] = {} 
    for col in final_df.drop(['Target Name', 'Hours Open'],axis=1).columns:
        here = final_df[final_df["Target Name"]==ra][col].value_counts(normalize=True)
        here = here[here.index=="Yes"]
        i_dict[ra][col] = here.to_dict()["Yes"]
    i_dict[ra]["Average Hours"] = final_df[final_df["Target Name"]==ra][final_df["Hours Open"]>10]["Hours Open"].mean()

import _pickle as pickle 

path_out = os.path.join(my_path, "../data/yelp_extra_info/")
path_in_ngrams = os.path.join(my_path, "../data/cpickle/")

final_df.to_csv(path_out + "extra_info.csv")

pickle.dump(i_dict, open(path_in_ngrams+"i_dict.p", "wb"))

## Send to dictionary 

path_in_file = os.path.join(my_path, "../input_fields.csv")

input_fields = pd.read_csv(path_in_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-95154f9666ff> in <module>()
#      19         fa  = pd.DataFrame.from_dict(ext["business_info"], orient='index', dtype=None)
#      20         fa.columns = [r]
# ---> 21         new_frame = new_frame.join(fa,how="outer")
#      22
#      23 frame_t = new_frame.T
#
# KeyboardInterrupt:

# %%
i_dict["BJRI"]
# Out:
# {'Accepts Android Pay': 0.20418848167539266,
#  'Accepts Apple Pay': 0.2931937172774869,
#  'Average Hours': 92.30952380952381,
#  'Bike Parking': 0.8429319371727748,
#  'Caters': 0.7801047120418848,
#  'Delivery': 0.24083769633507854,
#  'Free Wi-Fi': 0.9895287958115183,
#  'Noisy': 0.07853403141361257,
#  'Outdoor Seating': 0.4607329842931937,
#  'Takes Reservations': 0.9842931937172775}

# %%
import os
import pandas as pd
import _pickle as pickle

my_path = os.path.abspath(os.path.dirname('__file__'))

path_in_ngrams = os.path.join(my_path, "data/cpickle/")

path_in_file = os.path.join(my_path, "../input_fields.csv")


input_fields = pd.read_csv(path_in_file)

def dic(coy, bench, location):

    city = location

    figures_dict_c = pickle.load(open(path_in_ngrams + "figures_dict_" + coy + ".p", "rb"))
    figures_dict_b = pickle.load(open(path_in_ngrams + "figures_dict_" + bench + ".p", "rb"))

    from math import cos, asin, sqrt


    def distance(lat1, lon1, lat2, lon2):
        p = 0.017453292519943295
        a = 0.5 - cos((lat2 - lat1) * p) / 2 + cos(lat1 * p) * cos(lat2 * p) * (1 - cos((lon2 - lon1) * p)) / 2
        return 12742 * asin(sqrt(a))


    def closest(data, v):
        return min(data, key=lambda p: distance(v['lat'], v['lon'], p['lat'], p['lon']))


    lat_list = []
    lon_list = []
    name_list = []
    for key, values in figures_dict_b.items():
        location = key[1]
        name_list.append(location)
        lat = values["Response Data"]["coordinates"]["latitude"]
        lon = values["Response Data"]["coordinates"]["longitude"]
        lat_list.append(lat)
        lon_list.append(lon)

    das = [{"lat": lat, "lon": lon, "name": name} for lat, lon, name in zip(lat_list, lon_list, name_list)]

    coy_target = figures_dict_c[coy, city]

    v = {'lat': coy_target["Response Data"]["coordinates"]["latitude"],
         'lon': coy_target["Response Data"]["coordinates"]["longitude"]}
    print(closest(das, v))
    close = closest(das, v)
    return close

import _pickle as pickle
import pandas as pd
import dash_html_components as html
import os

def make_dash_table(df):
    ''' Return a dash definitio of an HTML table for a Pandas dataframe '''
    table = []
    for index, row in df.iterrows():
        html_row = []
        for i in range(len(row)):
            html_row.append(html.Td([row[i]]))
        table.append(html.Tr(html_row))
    return table

target_code = "BJRI"


option_value_bench_code_dd = "CAKE"



my_path = os.path.abspath(os.path.dirname('__file__'))

path_out = os.path.join(my_path, "../data/yelp_extra_info/")
path_in_ngrams = os.path.join(my_path, "../data/cpickle/")


final_df = pd.read_csv(path_out + "extra_info.csv")

final_df = final_df.set_index("Unnamed: 0")

i_dict = pickle.load(open(path_in_ngrams + "i_dict.p", "rb"))

path = os.path.join(my_path, "../input_fields.csv")

input_fields = pd.read_csv(path)

code_rest = list(input_fields["code_or_ticker"])

code_rest.remove(target_code)
code_rest.remove(option_value_bench_code_dd)

# %%
frame_g = pd.DataFrame.from_dict(i_dict[target_code], orient="index")
frame_g = pd.DataFrame(index = frame_g.index)

target_location_file_name = "bjs-restaurant-and-brewhouse-upper-saint-clair"

bench_location_file_name = "the-cheesecake-factory-chestnut-hill"

frame_g = frame_g.join(final_df[final_df.index==(target_location_file_name+".csv")].T,how="outer")
frame_g = frame_g.join(final_df[final_df.index==(bench_location_file_name+".csv")].T,how="outer")
    

    

for r in code_rest:
    closest = dic(target_code, r, target_location_file_name)
    frame_g = frame_g.join(final_df[final_df.index==(closest['name']+".csv")].T,how="outer")
    

small_cols = [] 
file_names = [s[:-4] for s in frame_g.columns]
for col in frame_g.columns:
    wa = "" 
    for r in col.split("-"):
        if r[0].isdigit():
            wa = wa +r.strip(".csv")
        else:
            wa = wa +r[0] 
    small_cols.append(wa)

frame_g.columns = small_cols
frame_g = frame_g.drop(["Target Name"],axis=0)

frame_agg = pd.DataFrame.from_dict(i_dict[target_code], orient="index")
frame_agg = pd.DataFrame(index = frame_agg.index)


for r in [target_code,option_value_bench_code_dd ]:
    dfg = pd.DataFrame.from_dict(i_dict[r], orient="index")
    dfg.columns = [r]
    frame_agg = frame_agg.join(dfg,how="outer")
    
    
for r in code_rest:
    dfg = pd.DataFrame.from_dict(i_dict[r], orient="index")
    dfg.columns = [r]
    frame_agg = frame_agg.join(dfg,how="outer")


frame_agg = frame_agg.rename(index={'Average Hours': 'Average Weekly Hours'})

frame_g = frame_g.rename(index={'Hours Open': 'Average Weekly Hours'})
# Out:
# {'lat': 40.5250832217884, 'lon': -80.0059548207627, 'name': 'applebees-neighborhood-grill-and-bar-pittsburgh-18'}
# {'lat': 40.3463567367899, 'lon': -79.9440959915882, 'name': 'chilis-west-mifflin'}
# {'lat': 40.543265919528, 'lon': -80.009138459723, 'name': 'california-pizza-kitchen-pittsburgh-2'}
# {'lat': 40.342295561608, 'lon': -80.0556799336511, 'name': 'red-robin-gourmet-burgers-bethel-park'}
# {'lat': 40.3456144092035, 'lon': -80.0488123376033, 'name': 'tgi-fridays-bethel-park'}

# %%
path = os.path.join(my_path, "../input_fields.csv")

input_fields = pd.read_csv(path)

code = input_fields["code_or_ticker"]

my_path = os.path.abspath(os.path.dirname('__file__'))

path = os.path.join(my_path, "../data/cpickle/")

rates_df = pd.DataFrame()
for coy in code:
    rad = pd.DataFrame()
    path_in = os.path.join(my_path, "../data/ratings/")
    yelp = pd.read_csv(path_in + "all_yelps_rates_" + coy +".csv")
    better = [d.title() for d in yelp.columns]
    yelp.columns = better
    das = yelp.iloc[-1:,:].T[1:]
    wel = das.reset_index()
    wel["Target"] = coy

    rates_df = rates_df.append(wel)


rates_df.iloc[:,1] = rates_df.iloc[:,1].fillna(rates_df.iloc[:,1].mean()-.2)

final_df = pd.read_csv(path_out + "extra_info.csv")
final_df = final_df.set_index("Unnamed: 0")
final_tact = final_df.copy()

final_tact = final_tact[final_tact["Hours Open"]>10]

for s in ['Free Wi-Fi', 'Takes Reservations',
       'Outdoor Seating', 'Delivery', 'Caters', 'Bike Parking',
       'Accepts Apple Pay', 'Accepts Android Pay']:
    
    final_tact[s+ " - S"] = final_tact[s].apply(lambda x: 1 if x=="Yes" else 0 )

final_tact["Noisy"+ " - S"] = final_tact["Noisy"].apply(lambda x: 1 if x=="No" else 0 )

ads = final_tact[['Free Wi-Fi - S',
       'Takes Reservations - S', 'Outdoor Seating - S', 'Delivery - S',
       'Caters - S', 'Bike Parking - S', 'Accepts Apple Pay - S',
       'Accepts Android Pay - S', 'Noisy - S']]

fap = ads.sum(axis=1) + (final_tact["Hours Open"]*2)/100

fap = fap/(fap.sort_values()[-1])*10

f_df = pd.read_csv("../big_small_add.csv")

dap = pd.merge(f_df, rates_df, left_on=["All Target Location Small Names", "Target"], right_on=["index", "Target"], how="left")


dap["rating"] = dap.iloc[:,-1]

dap = dap.set_index(dap["All Target Location File Names"],drop=True)

fap.index = [r[:-4] for r in fap.index]

fap = pd.DataFrame(fap)

dap = dap[["rating","Target","All Target Location Small Names","All Target Location Full Addresses"]].copy()
fin = fap.join(dap, how="outer")



fin = fin.fillna(fin.mean()-.15)

fin["final"] = fin[0]*0.45 + fin["rating"]*0.55*2

group_fin = fin.copy()

f_df = pd.read_csv("../big_small_add.csv")
f_df = f_df.reset_index(drop=True)


f_df = pd.read_csv("../big_small_add.csv")
f_df = f_df.reset_index(drop=True)

list_f = f_df[f_df["All Target Location File Names"].isin(file_names)].reset_index(drop=True)
              
list_f.reset_index(inplace=True)

list_f["All Target Location File Names"] = list_f["All Target Location File Names"].astype("category")

list_f["All Target Location File Names"].cat.set_categories(list(file_names), inplace=True)

list_fd =  list(list_f.sort_values(["All Target Location File Names"])["Target"] + list_f.sort_values(["All Target Location File Names"])["All Target Location Small Names"])

fin["new_id"] = fin["Target"] + fin["All Target Location Small Names"]

fin = fin[fin["new_id"].isin(list_fd)]

fin.reset_index(inplace=True)

fin["new_id"] = fin["new_id"].astype("category")

fin["new_id"].cat.set_categories(list_fd, inplace=True)
fin = fin.sort_values(["new_id"])

small_cols = [] 
file_names = [s[:-4] for s in fin["index"]]
for ss in list(fin["index"]):
    wa = "" 
    for r in ss.split("-"):
        if r[0].isdigit():
            wa = wa +r.strip(".csv")
        else:
            wa = wa +r[0] 
    small_cols.append(wa)

fin["smc"] = small_cols

import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=fin.smc.values,
    y=fin.final,
    name='Convenience Rating Local',
    marker=dict(
        color='grey',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5,
        )
    ),
    opacity=1
)


layout = go.Layout(
    title='Convenience Rating National',
)
data=[trace1]
fig_local = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='stacked-bar')

grouped = group_fin.groupby("Target").mean()

grouped.reset_index(inplace=True)

grouped.Target = grouped.Target.astype("category")

grouped.Target.cat.set_categories(list(frame_agg.columns), inplace=True)

import plotly.plotly as py
import plotly.graph_objs as go


grouped = grouped.sort_values(["Target"])
trace1 = go.Bar(
    x=grouped.Target.values,
    y=grouped.final,
    name='Convenience Rating National',
    marker=dict(
        color='rgb(255,140,0)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.5,
        )
    ),
    opacity=1
)


layout = go.Layout(
    title='Convenience Rating',
)
data=[trace1]
fig_national = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='stacked-bar')

# %%
f_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
new_ff = frame_agg.join(frame_g,how="outer")

new_ff = new_ff.round(2)

new_ff = new_ff

modifed_perf_table = make_dash_table(new_ff)

modifed_perf_table.insert(
    0, html.Tr([
        html.Td([]),
        html.Td(['Company'], colSpan=7, style={'text-align': "center"}),
        html.Td(['Benchmark'], colSpan=7, style={'text-align': "center"})
    ], style={'background': 'white', 'font-weight': '600'}
    )
)

new_ff = new_ff.reset_index()


new_ff = new_ff.rename(columns={"index":"Category"})

new_ff.loc[-1] = new_ff.columns
new_ff.index = new_ff.index + 1 
new_ff = new_ff.sort_index() 


new_ff
# Out:
#                 Category   BJRI   CAKE   APPB   CHIL   CPKI   RRGB   TGIF  \
# 0               Category   BJRI   CAKE   APPB   CHIL   CPKI   RRGB   TGIF
# 1    Accepts Android Pay    0.2   0.09   0.03   0.03   0.07   0.18   0.04
# 2      Accepts Apple Pay   0.29   0.22   0.07   0.12   0.11   0.18    0.1
# 3   Average Weekly Hours  92.31  87.66  92.81  82.61  75.94  79.32  96.41
# 4           Bike Parking   0.84   0.85   0.68   0.66   0.86    0.8   0.69
# 5                 Caters   0.78   0.74   0.11   0.27   0.71   0.09   0.09
# 6               Delivery   0.24   0.01   0.01   0.04   0.25      0   0.01
# 7             Free Wi-Fi   0.99    0.2   0.79   0.49   0.88   0.26   0.85
# 8                  Noisy   0.08   0.23   0.17   0.18   0.04   0.21   0.21
# 9        Outdoor Seating   0.46   0.86    0.1   0.07   0.61   0.43    0.3
# 10    Takes Reservations   0.98    0.8   0.24   0.37   0.64    0.1   0.45
#
#     brabusc  tcfch  angabp18  cwm  cpkp2  rrgbbp  tfbp
# 0   brabusc  tcfch  angabp18  cwm  cpkp2  rrgbbp  tfbp
# 1        No     No        No   No     No      No   Yes
# 2       Yes     No        No   No     No      No    No
# 3        93     88        93   79     70      79    92
# 4       Yes    Yes       Yes   No    Yes     Yes    No
# 5        No    Yes        No   No    Yes      No    No
# 6        No     No        No   No    Yes      No    No
# 7       Yes    Yes       Yes   No    Yes      No   Yes
# 8        No     No        No   No     No      No    No
# 9        No    Yes        No   No    Yes      No   Yes
# 10      Yes    Yes        No  Yes     No      No    No

# %%
link_dict = json.load(open(path_in_ngrams + "final_linkedin.json"))

# %%
link_dict["companies"]
# Out:
# [{'company': 'BJs Restaurant',
#   'company_id': 98785,
#   'company_info': {'companyPageUrl': 'http://www.bjsrestaurants.com',
#    'description': 'Since our humble beginnings back in 1978, we’ve continued to refine our brewhouse experience to make BJ’s a place where you can make the most of any meal. We want BJ’s to be a place where the moment you leave is the moment you plan on coming back.\r\n\r\nWe pride ourselves in our craft and attention to detail. Our guests come here for our award-winning handcrafted beer. They come here for the Southern California twist we’ve put on the Chicago-style pizza. And they come here for our Pizookies, our world-renowned dessert. But above all we know people come here to make their good times better.\r\n\r\nSo in many ways we haven’t just crafted a brand, but a mindset. And our guests are the reason for this. And it’s because of them we’re continually striving to make sure every moment they choose to spend with us counts.\r\n\r\nWelcome to BJ’s.',
#    'industries': ['Restaurants'],
#    'jobSearchPageUrl': 'https://www.linkedin.com/jobs/search?locationId=OTHERS%2Eworldwide&f_C=98785',
#    'staffCount': 3781,
#    'universalName': "bj's-restaurants-inc-"},
#   'employees': [{'firstName': '',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': '--'},
#    {'firstName': '',
#     'industry': 'Sports',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'Corporate Social Responsibility Coordinator at Dallas Cowboys Merchandising'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': '--'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Albuquerque, New Mexico Area',
#     'occupation': "Senior Manager at BJ's Restaurant & Brewhouse"},
#    {'firstName': '',
#     'industry': 'Airlines/Aviation',
#     'lastName': '',
#     'location': 'Greater Seattle Area',
#     'occupation': 'Customer Service Instructor, Trainer at Alaska Airlines'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Greater Seattle Area',
#     'occupation': "Senior manager at Bj's Brewhouse"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Executive Kitchen Manager, Bj's Restaurant"},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Senior manager at Bjs Restaurants'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Mechanical or Industrial Engineering',
#     'lastName': '',
#     'location': 'Phoenix, Arizona Area',
#     'occupation': 'Student of Mechanical Engineering at Arizona State University'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Server at Yard House Restaurants'},
#    {'firstName': '',
#     'industry': 'Information Technology and Services',
#     'lastName': '',
#     'location': 'Greater Seattle Area',
#     'occupation': "costumer specialist at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Baltimore, Maryland Area',
#     'occupation': "Kitchen Manager for BJ's Restaurants."},
#    {'companies': [{'companyName': 'Coney Island Amusement Park',
#       'joining': {'month': 4, 'year': 1998},
#       'lwd': {'month': 5, 'year': 2002},
#       'title': 'Area Supervisor'},
#      {'companyName': 'Walmart',
#       'joining': {'month': 6, 'year': 2002},
#       'lwd': {'month': 9, 'year': 2008},
#       'title': 'Assistant Manager'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 2, 'year': 2009},
#       'title': 'Exective Kitchen Manager and Shareholder'}],
#     'firstName': 'Ricky',
#     'industry': 'Restaurants',
#     'lastName': 'Menor',
#     'location': 'Las Vegas, Nevada Area',
#     'occupation': "Bj's Restaurants and Brewhouse",
#     'schools': []},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'Richmond, Virginia Area',
#     'occupation': 'General Manager at Dunkin Donuts'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': '--'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Senior Manager'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Canton, Ohio Area',
#     'occupation': "Executive Kitchen Manager and Shareholder at BJ's Restaurant & Brewhouse"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Architectural and Design Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Music',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'Monmouth University graduate looking for new opportunities in hospitality, music, or event planning.'},
#    {'firstName': '',
#     'industry': 'Financial Services',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': 'Project Engineer at Sunseri Associates, Inc.'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': '--Executive Kitchen Manager'},
#    {'firstName': '',
#     'industry': 'Computer Software',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'at'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Fresno, California Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Salinas, California Area',
#     'occupation': 'Marketing intern at Fresno Monsters Hockey'},
#    {'firstName': '',
#     'industry': 'Hospital & Health Care',
#     'lastName': '',
#     'location': 'Tallahassee, Florida Area',
#     'occupation': 'Case Manager at HealthSouth Rehabiltation'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': '--'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'General Manager at BJs Restaurants.'},
#    {'firstName': '',
#     'industry': 'Broadcast Media',
#     'lastName': '',
#     'location': 'Greater Nashville Area, TN',
#     'occupation': 'Communications Graduate Seeking Sales Career Opportunity'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Director Of Kitchen Operations'},
#    {'firstName': '',
#     'industry': 'Primary/Secondary Education',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Restaurants professional'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Colorado Springs, Colorado Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'Restaurants Professional'},
#    {'firstName': '',
#     'industry': 'Construction',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': '.'},
#    {'firstName': '',
#     'industry': 'Health, Wellness and Fitness',
#     'lastName': '',
#     'location': 'Little Rock, Arkansas Area',
#     'occupation': 'Management/Sales/Customer Service/ Insurance Specialist/F&B/Military'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Providence, Rhode Island Area',
#     'occupation': 'Senior Manager for BJS Restaurant and Brewhouse'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Business Student'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Antonio, Texas Area',
#     'occupation': "Director of Operations at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Legal Services',
#     'lastName': '',
#     'location': 'Tampa/St. Petersburg, Florida Area',
#     'occupation': 'Student at University of Tampa'},
#    {'firstName': '',
#     'industry': 'Health, Wellness and Fitness',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': 'Personal Trainer at Life Time - Healthy Way of Life'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Seattle Area',
#     'occupation': 'Biotechnology'},
#    {'firstName': '',
#     'industry': 'Music',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Music Marketing'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'Account Coordinator Marriot Vacations Worldwide'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Cleveland/Akron, Ohio Area',
#     'occupation': "General Manager and Shareholder - BJ's Restaurant and Brewhouse"},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': '--'},
#    {'firstName': '',
#     'industry': 'Recreational Facilities and Services',
#     'lastName': '',
#     'location': 'Miami/Fort Lauderdale Area',
#     'occupation': 'Cascade Storyteller at The Biltmore Hotel'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Server at The Melting Pot'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': "Assistant General Manager BJ's"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': 'General Manager and Shareholder'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Park Attendant at County of San Diego'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Recruiting Coordinator at Adtaxi and Bay Area News Group'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Raleigh-Durham, North Carolina Area',
#     'occupation': 'executive kitchen manager at Bjs restaurants'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': 'Bjs Restaurant and Brewery'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Brewgenius at BJ&amp;#39;s Restaurants, Inc.'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'Assistant General Manager'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Bakersfield, California Area',
#     'occupation': 'Executive Kitchen Manager Bjs Brewhouse restaurants'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "General Manager BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Pensacola, Florida Area',
#     'occupation': 'General Manager BJs Restaurant and Brewhouse'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': "Executive Kitchen Market Manager & shareholder at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Talent Selection at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Computer Software',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Entrepreneur. Investor. Disrupter.'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "EVP Operations at BJ's Restaurants Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Tax - BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Computer Software',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Computer Software Consultant and Professional'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Senior Regional Vice President at BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Pittsburgh Area',
#     'occupation': "Assistant General Manager at Dave & Buster's Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Specialist with Sales Tax, Income Tax, and Property Tax'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director, SEC Reporting at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Human Resources',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Director Compensation & Benefits - Total Rewards Leader'},
#    {'firstName': '',
#     'industry': 'Law Practice',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Senior Vice President and General Counsel at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "EVP, Chief Marketing Officer at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Vice President of Purchasing at BJ's Restaurants Inc."},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Sr. Manager, Marketing Communications, BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "General Manager at BJ's Brewhouse & , Inc."},
#    {'firstName': '',
#     'industry': 'Facilities Services',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Facilities Coordinator at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Quality Assurance at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Denver Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Senior Vice President of Culinary and Kitchen Innovation at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Marketing Analytics at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Lafayette, Louisiana Area',
#     'occupation': 'General Manager and Shareholder at BJs Restaurant and Brewhouse'},
#    {'firstName': '',
#     'industry': 'Accounting',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Payroll Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Director of Marketing'},
#    {'firstName': '',
#     'industry': 'Banking',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Systems Engineer III at Opus Bank'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Marketing Brand Strategist & Consumer Insights Champion'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Baton Rouge, Louisiana Area',
#     'occupation': "Executive Kitchen Manager and Shareholder at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Publishing',
#     'lastName': '',
#     'location': 'Greater Chicago Area',
#     'occupation': 'Co-owner of Lively Athletics'},
#    {'firstName': '',
#     'industry': 'Information Technology and Services',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Chief Information Officer at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Health, Wellness and Fitness',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'EMT at Ambulnz'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'CIO, STACKED: Food Well Built'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'President and Chief Financial Officer at BJ&amp;#39;s Restaurants, Inc.'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Co-CEO at Stacked Restaurants, LLC'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Tucson, Arizona Area',
#     'occupation': "General Manager and shareholder at BJ's Brewery"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "EVP at BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Information Technology and Services',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Information Technology, Restaurant Systems and Support at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Marketing Leader | Digital & Social Media Expert | Brand Strategist'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Reno, Nevada Area',
#     'occupation': "Managing Director at BJ's Restaurants and Independent Non-Profit Organization Management Professional"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "General Manager B.J.'s Restaurants"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Vice President, Kitchen Operations at BJ's Restaurants, Inc."},
#    {'companies': [{'companyName': 'Starbucks, ValueOptions',
#       'joining': {'year': 1997},
#       'lwd': {'year': 2007},
#       'title': 'Additional Experience'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 7, 'year': 2007},
#       'lwd': {'month': 7, 'year': 2008},
#       'title': 'Director of Recruting, New Restaurants'},
#      {'companyName': "BJ's Restaurants",
#       'joining': {'month': 7, 'year': 2008},
#       'title': 'Director of Talent Development'}],
#     'firstName': 'Jeannine',
#     'industry': 'Restaurants',
#     'lastName': 'Loy',
#     'location': 'Orange County, California Area',
#     'occupation': 'Talent Development, Engagement, Leadership Effectiveness',
#     'schools': [{'fieldOfStudy': 'Organizational Psychology',
#       'schoolName': 'California State University-Long Beach'},
#      {'fieldOfStudy': 'Psychology',
#       'schoolName': 'Western Michigan University'}]},
#    {'firstName': '',
#     'industry': 'Logistics and Supply Chain',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Purchasing Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Education Management',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Information Technology and Services',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Senior Director, Enterprise Systems and Development at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Events Services',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': "Florida Special Events Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Wine and Spirits',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "SVP of Brewing Operations at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director Real Estate at BJ's Restaurant and Brewhouse"},
#    {'firstName': '',
#     'industry': 'Music',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'Artist Development'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Denver Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Director of Operations at BJ's Restaurants Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': "General Manager & Shareholder at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Miami/Fort Lauderdale Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Executive Kitchen Manager BJs Restaurants'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Restaurant Administrative Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Creative and Learning Content Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Marketing Analytics at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Publishing',
#     'lastName': '',
#     'location': 'Greater Chicago Area',
#     'occupation': 'Experienced Freelance Writer and Copy Editor'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Tampa/St. Petersburg, Florida Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'companies': [{'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 6, 'year': 2016},
#       'title': 'Talent Selection Manager'},
#      {'companyName': 'Interim HealthCare',
#       'joining': {'year': 2005},
#       'lwd': {'year': 2006},
#       'title': 'Operations Manager'},
#      {'companyName': 'Iron Hill Brewery & Restaurant',
#       'joining': {'month': 1, 'year': 2007},
#       'lwd': {'month': 11, 'year': 2007},
#       'title': 'Restaurant Manager'},
#      {'companyName': 'Iron Hill Brewery & Restaurant',
#       'joining': {'month': 4, 'year': 2006},
#       'lwd': {'month': 4, 'year': 2011},
#       'title': 'Restaurant Administrative Assistant and Banquet Coordinator'},
#      {'companyName': 'Iron Hill Brewery & Restaurant',
#       'joining': {'month': 1, 'year': 2011},
#       'lwd': {'month': 6, 'year': 2016},
#       'title': 'Restaurant Recruiter/Talent Acquisition Specialist'}],
#     'firstName': 'Laura',
#     'industry': 'Restaurants',
#     'lastName': 'McLaren',
#     'location': 'Greater Philadelphia Area',
#     'occupation': "Talent Selection Manager for BJ'S Restaurants - Pairing great careers with great restaurant talent since 2011.",
#     'schools': [{'schoolName': 'Johnson & Wales University'},
#      {'fieldOfStudy': 'Culinary Arts',
#       'joining': {'year': 1996},
#       'lwd': {'year': 1998},
#       'schoolName': 'Johnson and Wales University'},
#      {'fieldOfStudy': 'Hotel/Restaurant/Institutional Management',
#       'joining': {'year': 1998},
#       'lwd': {'year': 2001},
#       'schoolName': 'University of Delaware'}]},
#    {'firstName': '',
#     'industry': 'Primary/Secondary Education',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Science Teacher at Tustin Unified School District'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Washington D.C. Metro Area',
#     'occupation': "Director of Operations at BJ'S Restaurants"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Columbus, Ohio Area',
#     'occupation': "Executive Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Financial Services',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Investment Operations Services at Capital Group'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'AGM @ Bjs Restaurants'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Longview, Texas Area',
#     'occupation': 'Culinary Management Professional'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director of Property Development at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'General Manager at BJs Restaurant and Brewhouse'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Tampa/St. Petersburg, Florida Area',
#     'occupation': 'at'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Vice President of Accounting and Corporate Controller'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Regional VP Operation at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director, Purchasing at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'manager'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Sr. Tax Analyst at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Entertainment',
#     'lastName': '',
#     'location': 'Las Vegas, Nevada Area',
#     'occupation': 'Accounts Manager/DJ at All Night Long Entertainment'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Director, Kitchen Operations at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "General Manager at BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Entertainment',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'photo stylist/on-camera host'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "retired head dishwasher at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Las Vegas, Nevada Area',
#     'occupation': 'Director of Operations BJS Restaurants'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Washington D.C. Metro Area',
#     'occupation': "General Manager & Shareholder at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': "Assistant General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Regional Operations Director'},
#    {'firstName': '',
#     'industry': 'Gambling & Casinos',
#     'lastName': '',
#     'location': 'Columbus, Ohio Area',
#     'occupation': 'Advertising & PR Manager at Eldorado Scioto Downs'},
#    {'companies': [{'companyName': 'M86 Security',
#       'joining': {'year': 2009},
#       'lwd': {'year': 2012},
#       'title': 'Head of Global IT'},
#      {'companyName': 'Trustwave',
#       'joining': {'year': 2012},
#       'lwd': {'year': 2015},
#       'title': 'Manager, IT'},
#      {'companyName': 'Kavado',
#       'joining': {'year': 2001},
#       'lwd': {'year': 2005},
#       'title': 'IT Manager'},
#      {'companyName': 'Finjan software',
#       'joining': {'year': 2005},
#       'lwd': {'year': 2009},
#       'title': 'IT Director'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'year': 2015},
#       'title': 'Director, Infrastructure and Security'}],
#     'firstName': 'Oded',
#     'industry': 'Information Technology and Services',
#     'lastName': 'Fuchs',
#     'location': 'Orange County, California Area',
#     'occupation': "Director, Infrastructure and Security at BJ's Restaurants, Inc.",
#     'schools': [{'schoolName': 'Haifa University'}]},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Senior Manager at BJ's Restaurant"},
#    {'firstName': '',
#     'industry': 'Security and Investigations',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Loss Prevention Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Greater Denver Area',
#     'occupation': "2018 Skechers Athlete, NRO for BJ's Brewhouse, & a simple girl living a blessed life."},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "General Manager & Shareholder BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Director, Corporate Relations at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Washington D.C. Metro Area',
#     'occupation': "Executive Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Senior manager'},
#    {'firstName': '',
#     'industry': 'Logistics and Supply Chain',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Logistics Manager'},
#    {'firstName': '',
#     'industry': 'Graphic Design',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Colorado Springs, Colorado Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'General Manager'},
#    {'firstName': '',
#     'industry': 'Computer Software',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "System Administrator for BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Hospital & Health Care',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Human Resources Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': "Senior Manager at BJ's Brewhouse"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Senior Restaurant Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Assistant General Manager Bj's Restaurant"},
#    {'firstName': '',
#     'industry': 'Retail',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'Regional Team Member Relations Manager at BJs Restaurants & Brewery'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Antonio, Texas Area',
#     'occupation': "Sr. Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Investment Management',
#     'lastName': '',
#     'location': 'Greater New York City Area',
#     'occupation': 'Managing Member and Chief Executive Officer at Misada Capital Group LLC'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Director Of Payroll at BJs Restaurants, Inc'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Killeen/Temple, Texas Area',
#     'occupation': 'Graphic Designer and Videographer at heart'},
#    {'firstName': '',
#     'industry': 'Staffing and Recruiting',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Senior Talent Selection Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Digital Marketing Specialist at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Vice President of Construction at BJ's Restaurants, Inc."},
#    {'companies': [{'companyName': 'Premier Solutions, Inc.',
#       'joining': {'month': 4, 'year': 2006},
#       'lwd': {'month': 1, 'year': 2010},
#       'title': 'Executive Restaurant Recruiter'},
#      {'companyName': 'AKR Recruiting',
#       'joining': {'month': 1, 'year': 2010},
#       'lwd': {'month': 9, 'year': 2011},
#       'title': 'Recruiter'},
#      {'companyName': "Raising Cane's",
#       'joining': {'month': 9, 'year': 2011},
#       'lwd': {'month': 6, 'year': 2013},
#       'title': 'Recruiter'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 6, 'year': 2013},
#       'title': 'Senior Talent Selection Manager'}],
#     'firstName': 'Micah',
#     'industry': 'Hospitality',
#     'lastName': 'Gautreaux',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Senior Talent Selection Manager at BJ's Restaurants, Inc.",
#     'schools': [{'joining': {'year': 2002},
#       'lwd': {'year': 2010},
#       'schoolName': 'University of Central Oklahoma'}]},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Austin, Texas Area',
#     'occupation': 'Account Manager at PrintGlobe'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Director of Construction'},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Greater Atlanta Area',
#     'occupation': "Executive Kitchen Manager and Shareholder at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Eugene, Oregon Area',
#     'occupation': 'General Manager & Shareholder'},
#    {'companies': [{'companyName': 'Royal Palm Ale House',
#       'joining': {'month': 10, 'year': 2003},
#       'lwd': {'month': 1, 'year': 2006},
#       'title': 'General Manager'},
#      {'companyName': "J. Alexander's",
#       'joining': {'month': 1, 'year': 2006},
#       'lwd': {'month': 7, 'year': 2011},
#       'title': 'Assistant General Manager'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 7, 'year': 2011},
#       'title': 'General Manager and Shareholder'}],
#     'firstName': 'Scott',
#     'industry': 'Hospitality',
#     'lastName': 'Goldman, MBA',
#     'location': 'Miami/Fort Lauderdale Area',
#     'occupation': '2013 Manager of the Year: General Manager and Shareholder',
#     'schools': [{'fieldOfStudy': 'Business Management',
#       'joining': {'year': 1985},
#       'lwd': {'year': 1991},
#       'schoolName': 'University of Miami'}]},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Cincinnati, Ohio Area',
#     'occupation': 'Managing Director'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Daytona Beach, Florida Area',
#     'occupation': "GM at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': 'Experienced Restaurant Manager'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Austin, Texas Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': "General Manager and Shareholder BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'GM and Share Holder'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Restaurant Manager'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Tampa/St. Petersburg, Florida Area',
#     'occupation': "Area Vice President at BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Information Technology and Services',
#     'lastName': '',
#     'location': 'Greater Seattle Area',
#     'occupation': 'Recent University of Washington Graduate'},
#    {'firstName': '',
#     'industry': 'Sports',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Seat/Suite Sales Intern - LA Stadium & Entertainment District at Hollywood Park - Legends'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'Hospitality Services'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Asst General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Cleveland/Akron, Ohio Area',
#     'occupation': "EKM BJ's Restaurant & Brewhouse"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Richmond, Virginia Area',
#     'occupation': 'at'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Cincinnati, Ohio Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Argentina',
#     'occupation': "Senior Restaurant Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Detroit Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'Las Vegas, Nevada Area',
#     'occupation': 'Executive Chef/Kitchen Manager/ Bjs Restaurants'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'General Manager of The Bazille Restaurant @ Nordstrom, North Park'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Senior Director of Career Development at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Antonio, Texas Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Retail',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "CEO at BJ's Restaurants"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Denver Area',
#     'occupation': "Executive Kitchen Manager at B.J's Restaurant & Brewhouse"},
#    {'firstName': '',
#     'industry': 'Computer & Network Security',
#     'lastName': '',
#     'location': 'San Antonio, Texas Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Human Resources',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Director, Human Resources and Employee Relations'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Reno, Nevada Area',
#     'occupation': 'Customer Services'},
#    {'firstName': '',
#     'industry': 'Construction',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': 'Field Coordinator at Gulf States Protective Coatings Inc.'},
#    {'firstName': '',
#     'industry': 'Accounting',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Risk Management Specialist at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Director of Facilities at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Off Premise Sales Specialist at HEINEKEN'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "QA Sytems Analyst at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Cincinnati, Ohio Area',
#     'occupation': "Assistant General Manager at Bj's Restaurants, inc"},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': 'Director of Property Development'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Chicago Area',
#     'occupation': "Director of Real Estate at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'United States',
#     'occupation': '--'},
#    {'firstName': '',
#     'industry': 'Banking',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': '"Management is doing something right; leadership is doing the right thing" - Peter F. Druker'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Richmond, Virginia Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Recruiting Coordinator at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Marketing at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'HR Generalist at Simms Restaurants'},
#    {'firstName': '',
#     'industry': 'Human Resources',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Regional Employee Relations Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "General Manager at BJ's Restaurant and Brewhouse"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': "Executive Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Systems Administrator'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'President at San Francisco State University Marketing Association'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Jacksonville, Florida Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Retail',
#     'lastName': '',
#     'location': 'Albany, New York Area',
# ...
#     'industry': 'Religious Institutions',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Youth Group Advisor at University Synagogue'},
#    {'firstName': '',
#     'industry': 'Motion Pictures and Film',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Actor & Screenwriter'},
#    {'firstName': '',
#     'industry': 'Information Technology and Services',
#     'lastName': '',
#     'location': 'Phoenix, Arizona Area',
#     'occupation': 'Computer Information Systems student at Arizona State University'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Lafayette, Louisiana Area',
#     'occupation': "Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Financial Services',
#     'lastName': '',
#     'location': 'Reno, Nevada Area',
#     'occupation': 'Student at University of Nevada-Reno'},
#    {'firstName': '',
#     'industry': 'Retail',
#     'lastName': '',
#     'location': 'Cleveland/Akron, Ohio Area',
#     'occupation': 'Public Relations Professional'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': 'Student at Prairie View A&M University'},
#    {'firstName': '',
#     'industry': 'Individual & Family Services',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Waitress at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Banking',
#     'lastName': '',
#     'location': 'Little Rock, Arkansas Area',
#     'occupation': 'Universal Banker at U.S. Bank'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': 'Serving craft beer, top-shelf spirits, and upscale pub fare.'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Public Relations and Communications',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Account Assistant at Echo Media'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Highly-motivated student at Chapman University seeking internship/employment in Marketing/Film.'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Student at San Diego Mesa College'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': 'Student at University of Central Florida'},
#    {'firstName': '',
#     'industry': 'Primary/Secondary Education',
#     'lastName': '',
#     'location': 'Fort Wayne, Indiana Area',
#     'occupation': 'Student at Indiana University—Purdue University Fort Wayne'},
#    {'firstName': '',
#     'industry': 'Media Production',
#     'lastName': '',
#     'location': 'Austin, Texas Area',
#     'occupation': 'Digita Marketing Intern at Harris Media LLC'},
#    {'firstName': '',
#     'industry': 'Health, Wellness and Fitness',
#     'lastName': '',
#     'location': 'Lubbock, Texas Area',
#     'occupation': 'Student at Texas Tech University'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Student at California State University, Fullerton'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Nonprofit Organization Management',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Attended California State University-Long Beach'},
#    {'firstName': '',
#     'industry': 'Health, Wellness and Fitness',
#     'lastName': '',
#     'location': 'Fort Myers, Florida Area',
#     'occupation': 'Community Health major at FGCU'},
#    {'firstName': '',
#     'industry': 'Financial Services',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'Aspiring Real Estate Agent and Pursuing a Degree in Finance'},
#    {'firstName': '',
#     'industry': 'Law Enforcement',
#     'lastName': '',
#     'location': 'Greater Pittsburgh Area',
#     'occupation': 'California University of Pennsylvania graduate.'},
#    {'firstName': '',
#     'industry': 'Photography',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Lab Processor at West Pacific Medical Laboratory'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Reno, Nevada Area',
#     'occupation': "executive Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Medical Devices',
#     'lastName': '',
#     'location': 'Reno, Nevada Area',
#     'occupation': 'E-Commerce/Entrepreneur/Business'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Jacksonville, Florida Area',
#     'occupation': "Executive Kitchen Manager & Shareholder at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Food & Beverages',
#     'lastName': '',
#     'location': 'San Antonio, Texas Area',
#     'occupation': "Senior Manager at BJ's Restaurant"},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Sales Representative at Brandrep'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Killeen/Temple, Texas Area',
#     'occupation': "Supervisor Service Master at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Computer & Network Security',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': "Food Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Houston, Texas Area',
#     'occupation': "Supervisor and Expediter at Bj's Brewhouse"},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Communications Student at Saddleback College'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Government Administration',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Transitioning service member with an interest in aviation, personal fitness, and acting'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': 'Studies Film at the University of Colorado Boulder'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "Line Technician at BJ's Restaurants, Inc."},
#    {'companies': [{'companyName': 'Amor Ministries',
#       'joining': {'year': 2016},
#       'lwd': {'year': 2016},
#       'title': 'Team Member'},
#      {'companyName': 'Marin Humane Society',
#       'joining': {'month': 8, 'year': 2011},
#       'lwd': {'month': 12, 'year': 2011},
#       'title': 'Intern'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 6, 'year': 2017},
#       'title': 'Server'},
#      {'companyName': 'Thermo Fisher Scientific',
#       'joining': {'month': 9, 'year': 2016},
#       'lwd': {'month': 5, 'year': 2017},
#       'title': 'Capstone Engineering Team Management\t'},
#      {'companyName': 'University of San Diego',
#       'joining': {'month': 2, 'year': 2013},
#       'lwd': {'month': 5, 'year': 2015},
#       'title': 'Telemarketer'}],
#     'firstName': 'Kelly',
#     'industry': 'Mechanical or Industrial Engineering',
#     'lastName': 'Castaldo',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Attended University of San Diego',
#     'schools': [{'fieldOfStudy': 'Mechanical Engineering',
#       'joining': {'year': 2012},
#       'lwd': {'year': 2017},
#       'schoolName': 'University of San Diego'}]},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Las Vegas, Nevada Area',
#     'occupation': "Dining Room Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Financial Services',
#     'lastName': '',
#     'location': 'Greater Denver Area',
#     'occupation': 'Student at The University of Colorado Boulder and Server at BJs restaurant Brewhouse'},
#    {'firstName': '',
#     'industry': 'Hospitality',
#     'lastName': '',
#     'location': 'Youngstown, Ohio Area',
#     'occupation': 'Bachelor of Applied Science - Hospitality Management - BAS at Youngstown State University'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Sacramento, California Area',
#     'occupation': "Food Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Indianapolis, Indiana Area',
#     'occupation': "Assistant General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Dining Room Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orlando, Florida Area',
#     'occupation': "Dining Room Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': "Vice President Restaurant Facilities at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Raleigh-Durham, North Carolina Area',
#     'occupation': 'Server at The Pit Authentic Barbecue'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Phoenix, Arizona Area',
#     'occupation': "Hostess at BJ's Restaurant & Brewery"},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'Fort Myers, Florida Area',
#     'occupation': 'Marketing Student at Florida Gulf Coast University'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Reading, Pennsylvania Area',
#     'occupation': "AEKM at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': "General Manager And Shareholder at BJ's Restaurants, Inc."},
#    {'companies': [{'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 9, 'year': 2017},
#       'title': 'Facilities Manager'},
#      {'companyName': 'Edward Don & Company',
#       'joining': {'month': 4, 'year': 2012},
#       'lwd': {'month': 5, 'year': 2013},
#       'title': 'Installation Manager'},
#      {'companyName': "BJ's Restaurants, Inc.",
#       'joining': {'month': 5, 'year': 2013},
#       'title': 'Construction Project Manager'},
#      {'companyName': 'TriMark USA',
#       'joining': {'month': 10, 'year': 2005},
#       'lwd': {'month': 4, 'year': 2012},
#       'title': 'Project Manager'}],
#     'firstName': 'Jerry',
#     'industry': 'Restaurants',
#     'lastName': 'Moore',
#     'location': 'Ocala, Florida Area',
#     'occupation': "Facilities Manager at BJ's Restaurants, Inc.",
#     'schools': []},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Los Angeles Area',
#     'occupation': "Lead Line Cook at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Staffing and Recruiting',
#     'lastName': '',
#     'location': 'Dallas/Fort Worth Area',
#     'occupation': 'Applications Recruiter at TEKsystems'},
#    {'firstName': '',
#     'industry': 'Marketing and Advertising',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Marketing Graduate'},
#    {'firstName': '',
#     'industry': 'Hospital & Health Care',
#     'lastName': '',
#     'location': 'San Antonio, Texas Area',
#     'occupation': 'Graduate seeking healthcare sales position'},
#    {'firstName': '',
#     'industry': 'Hospital & Health Care',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': 'Registered Nursing Student'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Orange County, California Area',
#     'occupation': 'Attended California State University, Fullerton. Received a Bachelors in Criminal Justice.'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater San Diego Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Tampa/St. Petersburg, Florida Area',
#     'occupation': "Executive Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': "Food Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': "Senior Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Hospital & Health Care',
#     'lastName': '',
#     'location': 'San Francisco Bay Area',
#     'occupation': 'Registered Nurse, BSN, RN Seeking RN Opportunities'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater New York City Area',
#     'occupation': "Senior Manager at BJ's Restaurant"},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Greater Denver Area',
#     'occupation': "Server at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Fresno, California Area',
#     'occupation': 'Finance Student at California State University, Fresno'},
#    {'firstName': '',
#     'industry': 'Pharmaceuticals',
#     'lastName': '',
#     'location': 'Guangzhou, Guangdong, China',
#     'occupation': 'Drug Researcher - BJ'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Daytona Beach, Florida Area',
#     'occupation': 'Chef at Rock Bottom Restaurant & Brewery'},
#    {'firstName': '',
#     'lastName': '',
#     'location': 'Miami/Fort Lauderdale Area',
#     'occupation': "Kitchen Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Austin, Texas Area',
#     'occupation': "Hostess at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Fort Myers, Florida Area',
#     'occupation': 'General Manager At K.J. Steakhouse.'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Columbus, Ohio Area',
#     'occupation': 'Senior Manager at BJs Restaurant & Brewhouse'},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Fort Myers, Florida Area',
#     'occupation': "General Manager at BJ's Restaurants, Inc."},
#    {'firstName': '',
#     'industry': 'Restaurants',
#     'lastName': '',
#     'location': 'Tallahassee, Florida Area',
#     'occupation': '--'}],
#   'similiar_companies': ['Red Robin',
#    'California Pizza Kitchen',
#    'The Cheesecake Factory',
#    'Darden',
#    'Panera Bread',
#    'BJs Restaurant & Brewhouse']}]

# %%
df = pd.DataFrame(np.random.randn(50, 4), columns=list('ABCD'))

# %%
int(len(df)*.90)
# Out:
# 45
