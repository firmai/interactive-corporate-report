# %%
import os
import pandas as pd


input_fields = pd.read_csv("../input_fields.csv")
websites = input_fields["website"]
codes = input_fields["code_or_ticker"]
my_path = os.path.abspath(os.path.dirname('__file__'))

path_out = my_path + "/../data/similarweb/"


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
rad

import re

fi_dict = {} 
gr = pd.DataFrame()
pf = pd.DataFrame()
top = pd.DataFrame()
top_org = pd.DataFrame()
top_paid = pd.DataFrame()
top = pd.DataFrame()
similar = pd.DataFrame()
social = pd.DataFrame()

path_spy = my_path + "/../data/spyfu/"

i = -1
for coy in codes:
    i = i +1
    rad = pd.read_csv(path_out + coy+"_similarweb.csv")
    spyf = pd.read_csv(path_spy + coy+"_spyfu.csv")
    spyf = spyf[["Est Monthly Seo Click","Est Monthly PPC Click","Est Monthly AdWords Budget"]]
    spyf.columns = ["Seo Click","PPC Click","Adwords Budget"]
    
    nlof = rad[["Category Rank","Total Visits","Avg Visit Duration","Pages Per Visit","Bounce Rate"]].iloc[0,:]
    nlof["Seo Click"] = spyf["Seo Click"].values[0]
    nlof["PPC Click"] = spyf["Seo Click"].values[0]
    nlof["Adwords Budget"] = spyf["Seo Click"].values[0]
    
    sources = rad["Traffic Sources"]
    
    cat = sources[0][2:].split(", (")
    rt = []
    rt = [f.split(",")[0][1:-1] for f in cat]
    bt = [f.split(", ")[1][1:-2] for f in cat]

    pf[coy] = bt
    pf.index = rt
    
    sources = rad["Top Referring Sites"]

    cat = sources[0][2:].split(", (")
    rt = []
    rt = [f.split(",")[0][1:-1] for f in cat]
    bt = [f.split(", ")[1][1:-2] for f in cat]

    top[coy+"_perc"] = bt
    top[coy+"_webs"] = rt
    
    
    sources = rad["Top 5 Organic Keywords"]
    
    cat = sources[0][2:].split(", (")
    rt = []
    rt = [f.split(",")[0][1:-1] for f in cat]
    bt = [f.split(", ")[1][1:-2] for f in cat]

    top_org[coy+"_perc"] = bt
    top_org[coy+"_webs"] = rt
    
    sources = rad["Top 5 Paid Keywords"]
    
   
    cat = sources[0][2:].split(", (")
    try:
        bt = [f.split(", ")[1][1:-2] for f in cat]
        rt = [f.split(",")[0][1:-1] for f in cat]
        top_paid[coy+"_perc"] = bt
        top_paid[coy+"_webs"] = rt
    except:
        top_paid[coy+"_perc"] = bt
        top_paid[coy+"_webs"] = rt

    
    sources = rad["Similarity Sites"]
    
    cat = sources[0][2:].split(", (")
    rt = []
    rt = [f.split(",")[0][1:-1] for f in cat]
    bt = [f.split(", ")[1][1:-2] for f in cat]

    similar[coy+"_perc"] = bt
    similar[coy+"_webs"] = rt
    
    sources = rad["Social Items"]
    
    cat = sources[0][2:].split(", (")
    rt = []
    rt = [f.split(",")[0][1:-1] for f in cat]
    bt = [f.split(", ")[1][1:-2] for f in cat]

    social[coy+"_perc"] = bt
    social[coy+"_webs"] = rt
    
    gr[coy] = list(nlof.values)
    org_perc = rad["Organic Keywords Percent"][0]
    paid_perc = rad["Paid Keywords Percent"][0]
    

    
gr.index = nlof.index
gr = gr.reset_index()
gr = gr.T
gr = gr.reset_index()
key_metrics =gr.replace({"index":"Firm"})

h = pf
pf = pf.reset_index()
pf = pf.T
pf = pf.reset_index()
referrals =pf.replace({"index":""})


import _pickle as pickle

key_metrics.columns = key_metrics.iloc[0,:]
fi_dict["key_metrics"] = key_metrics
fi_dict["referrals"] = referrals
fi_dict["top"] = top
fi_dict["org_perc"] = org_perc
fi_dict["paid_perc"] = paid_perc
fi_dict["top_org"] = top_org
fi_dict["top_paid"] = top_paid
fi_dict["social"] = social 
fi_dict["similar"] = similar

my_path = os.path.abspath(os.path.dirname('__file__'))
path_out = my_path + "/../data/similarweb/"
pickle.dump(fi_dict,open(path_out +"website.p", "wb"))

# %%
gr
# Out:
#    index              0             1                   2                3  \
# 0  index  Category Rank  Total Visits  Avg Visit Duration  Pages Per Visit
# 1   BJRI            231       669.98K             0:04:53             5.75
# 2   APPB             29         4.71M            00:03:27             9.11
# 3   CAKE             88         1.72M            00:03:17             8.46
# 4   CHIL             58         3.10M            00:04:18             6.27
# 5   CPKI            465       527.64K            00:01:05             1.95
# 6   RRGB            126         1.45M            00:04:36             6.35
# 7   TGIF            170         1.13M            00:02:28             4.27
#
#              4          5          6               7
# 0  Bounce Rate  Seo Click  PPC Click  Adwords Budget
# 1       30.99%      1.25M      1.25M           1.25M
# 2       30.45%      6.61M      6.61M           6.61M
# 3       38.80%      1.27M      1.27M           1.27M
# 4       37.67%      7.71M      7.71M           7.71M
# 5       69.87%       849k       849k            849k
# 6       25.35%      2.86M      2.86M           2.86M
# 7       39.79%       965k       965k            965k

# %%
key_metrics.columns = key_metrics.iloc[0,:]

h = h.T

h

h["Display"] = [s[:-1] for s in list(h["Display"])]

h.to_csv(path_out+"referral.csv")

# %%
for col in h.columns:
    h[col] = [r[:-1] for r in h[col]]
    h[col] = h[col].astype(float)
    h[col] = h[col]/h[col].sum()

# %%
h.to_csv(path_out+"referral_vals.csv")

# %%
h
# Out:
#         Direct  Referrals    Search    Social      Mail   Display
# BJRI  0.139950   0.129978  0.143022  0.113846  0.201907  0.120879
# APPB  0.159577   0.139074  0.141451  0.096923  0.095771  0.150183
# CAKE  0.078968   0.156458  0.171190  0.083077  0.020315  0.073260
# CHIL  0.189576   0.153831  0.120156  0.040000  0.271973  0.498168
# CPKI  0.147630   0.140085  0.145990  0.056154  0.113599  0.076923
# RRGB  0.171130   0.108753  0.125720  0.486154  0.184909  0.054945
# TGIF  0.113168   0.171821  0.152470  0.123846  0.111526  0.025641

# %%
fi_dict["top"]
# Out:
#   BJRI_perc              BJRI_webs APPB_perc            APPB_webs CAKE_perc  \
# 0    41.33%               yelp.com    23.52%              msn.com    16.60%
# 1     7.99%      eatdrinkdeals.com    12.43%  spoonuniversity.com    15.92%
# 2     7.99%              raise.com     7.99%   favoritecandle.com    14.99%
# 3     7.99%  careers.workatbjs.com     7.20%             yelp.com     8.61%
# 4    4.36%'     visitfortwayne.com    5.77%'    searchencrypt.com    7.88%'
#
#              CAKE_webs CHIL_perc            CHIL_webs CPKI_perc  \
# 0             yelp.com    38.47%       chilistogo.com    23.30%
# 1           indeed.com     8.33%    searchencrypt.com    16.02%
# 2  ww3.cakecareers.com     7.78%  survey.medallia.com    10.68%
# 3         buzzfeed.com     7.23%             hulu.com     8.74%
# 4              msn.com    3.40%'      mail.gspike.com    8.74%'
#
#                           CPKI_webs RRGB_perc             RRGB_webs TGIF_perc  \
# 0                  memorialcity.com    25.93%              yelp.com    13.24%
# 1             scholasticatravel.com    18.08%               msn.com    13.24%
# 2                          yelp.com    10.38%    redrobincanada.com    13.24%
# 3  cpkpizzadough.myguestaccount.com     9.26%  hustlermoneyblog.com     9.62%
# 4                     westfield.com    4.85%'     searchencrypt.com    9.11%'
#
#            TGIF_webs
# 0  searchencrypt.com
# 1           yelp.com
# 2    coupongreat.com
# 3   en.wikipedia.org
# 4  talktofridays.com

# %%
fi_dict["top_org"]
# Out:
#   BJRI_perc        BJRI_webs APPB_perc APPB_webs CAKE_perc  \
# 0    15.32%              bjs                        45.61%
# 1    14.37%   bj's brewhouse                        23.01%
# 2     7.82%  bj's restaurant                         4.02%
# 3     5.14%        bj's menu                         0.89%
# 4    3.67%'         bjs menu         '              0.83%'
#
#                     CAKE_webs CHIL_perc     CHIL_webs CPKI_perc  \
# 0          cheesecake factory    31.15%        chilis    40.00%
# 1     cheesecake factory menu    10.38%   chilis menu    13.78%
# 2      the cheesecake factory     4.64%       chillis     9.30%
# 3  cheesecake factory toronto     4.42%       chili's     7.90%
# 4         cheese cake factory    3.86%'  chili's menu    1.27%'
#
#                        CPKI_webs RRGB_perc          RRGB_webs TGIF_perc  \
# 0       california pizza kitchen    37.90%          red robin    28.15%
# 1                            cpk    18.23%     red robin menu     9.66%
# 2  california pizza kitchen menu     7.50%           redrobin     8.90%
# 3                       cpk menu     1.93%         red robins     6.67%
# 4               california pizza    1.62%'  red robin rewards    5.39%'
#
#           TGIF_webs
# 0       tgi fridays
# 1              tgif
# 2           fridays
# 3  tgi fridays menu
# 4      fridays menu

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools

coy = "BJRI"
perc_p_s = fi_dict["social"][coy+"_perc"]
webs_p_s = fi_dict["social"][coy+"_webs"]


coy = "BJRI"
perc_s = fi_dict["top"][coy+"_perc"]
webs_s = fi_dict["top"][coy+"_webs"]


trace3 = go.Bar(
            x=perc_p_s,
            y=webs_p_s,
        text = "%",
    name = "Social",
            orientation = 'h',
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=3),
    
))

trace4 = go.Bar(
            x=perc_s,
            y=webs_s,
        text = "%",
    name = "Other",
            orientation = 'h',
    marker = dict(color = 'rgba(208, 105, 80, 0.6)',
        line = dict(color = 'rgba(208, 105, 80, 1.0)',
            width = 3)
    
))


coy = "BJRI"
perc = fi_dict["top_org"][coy+"_perc"]
webs = fi_dict["top_org"][coy+"_webs"]
perc_p = fi_dict["top_paid"][coy+"_perc"]
webs_p = fi_dict["top_paid"][coy+"_webs"]

trace1 = go.Bar(
            x=perc,
            y=webs,
        text = "%",
    name = "Organic",
            orientation = 'h',
    marker=dict(
        color='rgb(158,202,225)',
        line=dict(
            color='rgb(8,48,107)',
            width=3),
    
))

trace2 = go.Bar(
            x=perc_p,
            y=webs_p,
        text = "%",
    name = "Paid",
            orientation = 'h',
    marker = dict(color = 'rgba(208, 105, 80, 0.6)',
        line = dict(color = 'rgba(208, 105, 80, 1.0)',
            width = 3)
    
))

fig = tools.make_subplots(rows=2, cols=2)



fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 2, 1)
fig.append_trace(trace3, 1, 2)
fig.append_trace(trace4, 2, 2)


fig["layout"].update(xaxis1=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
yaxis1=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
                    
xaxis2=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
yaxis2=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
                    xaxis3=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
yaxis3=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
                    
xaxis4=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),
yaxis4=dict(
    showgrid=False,
    zeroline=False,
    showline=False,
),)

py.iplot(fig, filename='text-chart-basic')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~snowde/82.embed" height="525px" width="100%"></iframe>

# %%
social
# Out:
#   BJRI_perc  BJRI_webs APPB_perc APPB_webs CAKE_perc   CAKE_webs CHIL_perc  \
# 0    62.79%   Facebook                        43.96%     Youtube    52.41%
# 1    24.71%    Youtube                        36.63%    Facebook    33.85%
# 2     7.06%  Pinterest                         8.48%   Pinterest     7.47%
# 3     4.61%    Twitter                         5.11%   Instagram     3.33%
# 4    0.83%'     Reddit         '              2.16%'  Foursquare    2.84%'
#
#     CHIL_webs CPKI_perc  CPKI_webs RRGB_perc   RRGB_webs TGIF_perc  TGIF_webs
# 0     Youtube    54.60%   Facebook    89.23%      Reddit    42.44%   Facebook
# 1    Facebook    15.36%     Reddit     6.91%    Facebook    37.34%    Youtube
# 2     Twitter    14.28%    Youtube     2.59%     Youtube     7.47%     Reddit
# 3      Reddit     9.30%  Pinterest     0.83%   Pinterest     5.33%  Instagram
# 4  Foursquare    6.46%'    Twitter    0.21%'  Foursquare    5.01%'    Twitter

# %%
rt
# Out:
# ['searchencrypt.com',
#  'yelp.com',
#  'coupongreat.com',
#  'en.wikipedia.org',
#  'talktofridays.com']

# %%
rt
# Out:
# ['searchencrypt.com',
#  'yelp.com',
#  'coupongreat.com',
#  'en.wikipedia.org',
#  'talktofridays.com']

# %%
sources = rad["Top Referring Sites"]

cat = sources[0][2:].split(", (")
rt = []
rt = [f.split(",")[0][1:-1] for f in cat]
bt = [f.split(", ")[1][1:-2] for f in cat]

top[coy+"_perc"] = bt
top[coy+"_webs"] = rt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-b4b1942f5add> in <module>()
#       6 bt = [f.split(", ")[1][1:-2] for f in cat]
#       7
# ----> 8 top[coy] = bt
#       9 top.index = rt
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2758
#    2759             # turn me into an ndarray
# -> 2760             value = _sanitize_index(value, self.index, copy=False)
#    2761             if not isinstance(value, (np.ndarray, Index)):
#    2762                 if isinstance(value, list) and len(value) > 0:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3078
#    3079     if len(data) != len(index):
# -> 3080         raise ValueError('Length of values does not match length of ' 'index')
#    3081
#    3082     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
top
# Out:
#   index                  0         1                2                 3  \
# 0        searchencrypt.com  yelp.com  coupongreat.com  en.wikipedia.org
# 1  BJRI             41.33%     7.99%            7.99%             7.99%
# 2  APPB             23.52%    12.43%            7.99%             7.20%
# 3  CAKE             16.60%    15.92%           14.99%             8.61%
# 4  CHIL             38.47%     8.33%            7.78%             7.23%
# 5  CPKI             23.30%    16.02%           10.68%             8.74%
# 6  RRGB             25.93%    18.08%           10.38%             9.26%
# 7  TGIF             13.24%    13.24%           13.24%             9.62%
#
#                    4
# 0  talktofridays.com
# 1             4.36%'
# 2             5.77%'
# 3             7.88%'
# 4             3.40%'
# 5             8.74%'
# 6             4.85%'
# 7             9.11%'

# %%
top = pd.DataFrame()
top_org = pd.DataFrame()
top_paid = pd.DataFrame()
top = pd.DataFrame()
similar = pd.DataFrame()
social = pd.DataFrame()

# %%
rt
# Out:
# []

# %%
cat
# Out:
# ['']

# %%
coy
# Out:
# 'CAKE'

# %%
gr
# Out:
#   index              0             1                   2                3  \
# 0        Category Rank  Total Visits  Avg Visit Duration  Pages Per Visit
# 1  BJRI            231       669.98K             0:04:53             5.75
# 2  APPB             29         4.71M            00:03:27             9.11
# 3  CAKE             88         1.72M            00:03:17             8.46
# 4  CHIL             58         3.10M            00:04:18             6.27
# 5  CPKI            465       527.64K            00:01:05             1.95
# 6  RRGB            126         1.45M            00:04:36             6.35
# 7  TGIF            170         1.13M            00:02:28             4.27
#
#              4
# 0  Bounce Rate
# 1       30.99%
# 2       30.45%
# 3       38.80%
# 4       37.67%
# 5       69.87%
# 6       25.35%
# 7       39.79%

# %%
pf
# Out:
#   index       0          1       2       3      4        5
# 0        Direct  Referrals  Search  Social   Mail  Display
# 1  BJRI  21.32%      6.43%  65.55%   1.48%  4.87%   0.33%'
# 2  APPB  24.31%      6.88%  64.83%   1.26%  2.31%   0.41%'
# 3  CAKE  12.03%      7.74%  78.46%   1.08%  0.49%   0.20%'
# 4  CHIL  28.88%      7.61%  55.07%   0.52%  6.56%   1.36%'
# 5  CPKI  22.49%      6.93%  66.91%   0.73%  2.74%   0.21%'
# 6  RRGB  26.07%      5.38%  57.62%   6.32%  4.46%   0.15%'
# 7  TGIF  17.24%      8.50%  69.88%   1.61%  2.69%   0.07%'

# %%
cat
# Out:
# ["'Direct', '17.24%')",
#  "'Referrals', '8.50%')",
#  "'Search', '69.88%')",
#  "'Social', '1.61%')",
#  "'Mail', '2.69%')",
#  "'Display', '0.07%')]"]

# %%
pf
# Out:
#                    0
# Direct        Direct
# Referrals  Referrals
# Search        Search
# Social        Social
# Mail            Mail
# Display      Display

# %%
rt
# Out:
# ["'Direct'", "'Referrals'", "'Search'", "'Social'", "'Mail'", "'Display'"]

# %%
nlof
# Out:
# Category Rank              170
# Total Visits             1.13M
# Avg Visit Duration    00:02:28
# Pages Per Visit           4.27
# Bounce Rate             39.79%
# Name: 0, dtype: object

# %%
import pandas as pd
import os
import os.path
from functools import reduce

small_dict = {}
input_fields = pd.read_csv("../input_fields.csv")
short = input_fields["short_name"]
codes = input_fields["code_or_ticker"]
overall_dict = {} 
for coy in codes:
    print(coy)
    final = [] 
    
    my_path = os.path.abspath(os.path.dirname('__file__'))

    dir_lis = my_path + "/../data/doordash/"+coy+"/"
    
    a = os.listdir(dir_lis)
    b = ["category"]

    final = [word for word in a if not any(bad in word for bad in b)]

    my_path = os.path.abspath(os.path.dirname('__file__'))
    if not os.path.exists(dir_lis + final[0].split(".")[0]+ '.xlsx'):
        print("Ra")
        for csvfile in final:
            workbook = Workbook(dir_lis + csvfile[:-4] + '.xlsx')
            worksheet = workbook.add_worksheet()
            with open(dir_lis + csvfile, 'rt', encoding='utf8') as f:
                reader = csv.reader(f)
                for r, row in enumerate(reader):
                    for c, col in enumerate(row):
                        worksheet.write(r, c, col)
            workbook.close()
      
    a = os.listdir(dir_lis)
    b = ["category"]
    
    final = [word for word in a if not any(bad in word for bad in b)]
    
    final = [i for i in final if ('.xlsx' in i)]
    
    small_dict = {}
    for fil in final:
        
        path_in = os.path.join(dir_lis,fil)
        print(path_in)
        doors = pd.read_excel(path_in)
        doors.columns = ["Name","Price","Description","Ingredients"]
        #doors = pd.read_csv(path_in, error_bad_lines=False)

        #pd.set_option('display.max_columns', None)
        #pd.set_option('display.max_rows', None)
        #disc = doors["Name"].str.find("Disclaimer")
        #disc = doors["Name"].str.find("Disclaimer")
        #disc = disc[disc.values==0].index[0]
        #ext_info = doors.iloc[disc+1,:]
        
        disc = doors["Price"].str.find(doors.loc[0,"Price"])

        disc = disc[disc.values==0].index
        if len(disc)>1:
            doors = doors.iloc[:disc[1],:]

        
        ext_info = doors.iloc[0,:]

        addy = ext_info["Description"]
        try:
            rating = ext_info["Name"].split("/")[0]
        except AttributeError:
            rating = None 
            
        try:
            number = ext_info["Price"].split(" ")[0]
        except AttributeError:
            number = None 

        adds = pd.read_csv("../big_small_add.csv")
        
        adds = adds[adds["Target"]==coy].reset_index(drop=True)

        from difflib import SequenceMatcher

        matching_ratio = []
        for com in adds["All Target Location Full Addresses"].values:
            matching_ratio.append(SequenceMatcher(None, addy.lower(), com.lower()).ratio())

        ft = pd.DataFrame(columns=["Ratio","Adds"])

        ft["Ratio"] = matching_ratio

        ft["Adds"] = adds["All Target Location Full Addresses"].values

        ft = ft.sort_values("Ratio",ascending=False).reset_index(drop=True)["Adds"][0]

        small_name = adds[adds["All Target Location Full Addresses"]==ft]["All Target Location Small Names"].reset_index(drop=True)[0]

        ### Okay Now You have the name # If error then something else 

        # Most Loved 5
        # Most Popular 10
        voors = doors[doors.index>0].reset_index(drop=True)

        voors["Price"] = [v[1:] for v in voors["Price"]]
        voors["Price"] = voors["Price"].astype(float)
       

        rad = voors.dtypes=="object"

        rad = rad[rad==True].index

        repls = ('¬†', ''), ('.', ''), ('‚Äô',''), ('‚Ä†',''), ('√±','n'), ('√©','i'),('Ôøº',''),('Ñ¢',''),('¬Æ',''),  

        for col in list(rad):
            voors[col] = [reduce(lambda a, kv: a.replace(*kv), repls, s) for s in voors[col]]

        

        food_dict = {}
        for  f in voors["Description"].unique():
            pops = voors[voors["Description"]==f].reset_index(drop=True)

            ingr = []
            for r in pops["Ingredients"]:
                for v in r.split("|"):
                    ingr.append(v.strip())

            prod = []
            for r in pops["Name"]:
                prod.append(r.strip())

            prices = []
            for r in pops["Price"]:
                prices.append(r)

            ingr = list(filter(None, ingr))
            food_dict[f] = {}
            food_dict[f]["ingredients"] = ingr
            food_dict[f]["products"] = prod 
            food_dict[f]["prices"] = prices 
            food_dict["rating"] = rating
            food_dict["number"] = number

        small_dict[small_name] = food_dict
    overall_dict[coy] = small_dict

    

dict_doordash = {}

nerf = pd.DataFrame(columns=["category","products","prices","target"])

bord = overall_dict
for coy in codes:
    for g in bord[coy].keys():
        del bord[coy][g]["rating"]
        del bord[coy][g]["number"]
        for k,v in overall_dict[coy][g].items():
            wilf = pd.DataFrame()
            prods = overall_dict[coy][g][k]["products"]
            prices = overall_dict[coy][g][k]["prices"]
            wilf["products"] = prods
            wilf["prices"] = prices
            wilf["category"] = str(k)
            wilf["target"] = coy
            
            nerf = pd.concat((nerf, wilf),axis=0)

verf = nerf.copy()

verf['category'] = verf['category'].replace(['Ribs and Steaks','Ribs', 'Fresh Steaks','Steaks & Ribs', 'Texas-Size Baby Back Ribs', 'Hand-Trimmed Steaks', 'From the Grill', 'Steak & Ribs', 'Steaks & Chops'], "Ribs, Steak and Chops")

verf['category'] = verf['category'].replace(['Guiltless Grill®','Fish & Seafood', 'Chicken' ,  'Chicken, Seafood & Pasta', 'Other Fun on a Bun', 'Fish & Seafood', "BJ's Premium Wings"], "Fish, Chicken and Other")

verf['category'] = verf['category'].replace(['Apps to Share', 'Build Your Appetizer Sampler', 'Entrées','Appetizers', 'Appetizer Salads','SkinnyLicious®: Small Plates & Appetizers','Appetizers', "BJ's Enlightened Entrées", 'Sizzling & Main Entrees', 'Specialty Entrees'], "Appetizers")

verf['category'] = verf['category'].replace(['Big Mouth® Burgers','Handcrafted Burgers', 'Fresh Mex', 'Full-On Fajitas','Burgers', 'Fire-Grilled Gourmet Burgers', "Red's Tavern Burgers", "Red Robin's Finest Gourmet Burgers",'Burger', 'Sandwich','Glamburgers® & Sandwiches', "BJ's Loaded Burgers", "BJ's Brewhouse Burgers", 'Crispy Chicken Sandwiches', 'Sandwiches and Tacos'], "Burgers and Sandwiches")

verf['category'] = verf['category'].replace(['Fresh Salads', 'Sandwiches & Soups','Soups', 'Fresh Salads','Soups', 'Salads','Soup', 'Salad',"BJ's Garden Fresh Entrée Salads", 'Starter Salads', 'Housemade Soups', 'SkinnyLicious®: Salads'], "Salads and Soup")

verf['category'] = verf['category'].replace(['Hey, Sweet Stuff','Ice Cream Delights', 'Sweet Things','Desserts','Dessert','Cheesecakes & Specialty Desserts', 'Ice Cream Delights','World-Famous Pizookies®', 'More Great Desserts'], "Desserts")

verf['category'] = verf['category'].replace(['Wraps & Sandwiches','Cajun Pasta','Chicken & Pastas','Pasta, Seafood More','Original Hand-Tossed Pizzas', 'Crispy Thin Crust Pizzas', 'Gluten-Free Pizzas', 'Pastas','Pastas','Pastas + Specialties', 'Pizzas', 'Pasta Favorites', 'Build Your Own Pizza', "BJ's Deep Dish Pizza", "BJ's Tavern-Cut Pizza"], "Pizza and Pastas")


cats = ["Ribs, Steak and Chops",
"Fish, Chicken and Other",
"Appetizers",
"Burgers and Sandwiches",
"Salads and Soup",
"Desserts",
"Pizza and Pastas"]


tgif = nerf[nerf["target"]=="RRGB"]

kerf = verf[verf["category"].isin(cats)].reset_index(drop=True)

len(kerf)

mens = kerf.groupby(["category","target"]).mean(); mens

sens = mens.reset_index()
goku = pd.DataFrame(columns=codes)
for cat in sens["category"].unique():
    rat = sens[sens["category"]==cat].set_index("target")
    rat = rat.T
    rat.index = ["category",cat]
    rat = rat.iloc[1:,:]
    goku = pd.concat((goku,rat),axis=0)

mean = goku.mean()
far = goku.T
far["mean"] = mean
goku = far.T
goku = goku.astype(float).round(2)

my_path = os.path.abspath(os.path.dirname('__file__'))

path_out = my_path + "/../data/doordash/"

goku = goku.reset_index()
goku = goku.rename(columns={"index": "Category"})
goku.loc[-1] = goku.columns  # adding a row
goku.index = goku.index + 1  # shifting index
goku = goku.sort_index()

dict_doordash["category"] = goku

goku.to_csv(path_out +"bench_cats.csv")

goku

loca_frame = {}

loca_frame["BJRI"] = list(overall_dict["BJRI"].keys())

loca_frame["CAKE"] = list(overall_dict["CAKE"].keys())

loca_frame["TGIF"] = list(overall_dict["TGIF"].keys())

loca_frame["CPKI"] = list(overall_dict["CPKI"].keys())

loca_frame["RRGB"] = list(overall_dict["RRGB"].keys())

loca_frame["APPB"] = list(overall_dict["APPB"].keys())

loca_frame["CHIL"] = list(overall_dict["CHIL"].keys())

dict_doordash["location"] = loca_frame

import _pickle as pickle

for item, backup in zip(["Most Popular", "Most Loved"],["Most Loved","Most Popular"]):
    dict_doordash["local "+item] = {} 

    fat = pd.DataFrame()
    rat = [] 
    raty = []
    
    for coy in codes:

        bad = overall_dict[coy]

        conc = pd.DataFrame(columns=["products","prices","rating","number","small"])
        for k, v in bad.items():
            kel = pd.DataFrame()
            try:
                products = v[item]["products"]
                prices = v[item]["prices"]
            except:
                try:
                    products = v[backup]["products"]
                    prices = v[backup]["prices"]
                except:
                    continue

            kel["products"] = products
            kel["prices"] = prices
            kel["rating"] = v["rating"]
            kel["number"] = v["number"]
            kel["small"] = k 

            conc = pd.concat((conc, kel),axis=0)
            # This one should be saved for hte individual locations

        conc["rating"] = conc["rating"]
        conc["number"] = conc["number"].replace({"Newly":None})
        conc["rating"] = conc["rating"].astype(float)
        conc["number"] = conc["number"].astype(float)
        
        ronc= conc[conc.index<5]

        ronc = ronc.fillna(ronc.mean())
        ronc["number"] = ronc["number"].astype(int)

        dict_doordash["local "+item][coy] = ronc 

        rag = conc.drop_duplicates("small").groupby("small").mean()

        rag = rag[~rag["rating"].isnull()]

        rag["percentage"] = ((rag["number"]/rag["number"].sum())).round(2)

        fr = pd.DataFrame()
        fr["products"] = conc["products"].value_counts().index
        fr["count"] = conc["products"].value_counts().values
        fr["percentage"] = (fr["count"].div(fr["count"].sum(), axis=0).multiply(100)).round(2)
        pir = []
        for c in fr["products"]:
            pra = conc[conc["products"]==c].drop_duplicates("products").reset_index(drop=True)["prices"][0]
            pir.append(pra)

        fr["prices"] = pir
        drs = fr[["products","percentage", "prices"]]
        drs.columns = [s+"_"+coy for s in drs.columns]
        rat.append((rag["percentage"] * rag["rating"]).sum()) # I am weighting by amount of reviews.
        fat["Ranking"] = fat.index + 1
        fat = pd.concat((fat, drs), axis=1)

    gat = fat[fat.index<10]

    per_col = [col for col in gat.columns if 'percentage' in col]
    pe_col = [col for col in gat.columns if 'prices' in col]

    new_row = ["Rating/Avg"]

    for r, pe, pr in zip(rat,gat[per_col].sum().values,gat[pe_col].mean().values):
        new_row.append(str(round(r,2))+"/5")
        new_row.append(str(round(pe,2))+"%")
        new_row.append("$"+str(round(pr,2)))


    vat = gat.append(pd.Series(new_row, index=gat.columns),ignore_index=True)

    
    dict_doordash[item] = vat


my_path = os.path.abspath(os.path.dirname('__file__'))
path_out = my_path + "/../data/doordash/"
pickle.dump(dict_doordash,open(path_out +"dict_doordash.p", "wb"))
# Out:
# BJRI
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-puyallup-161450214966.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-jose-2901286643.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-sugar-land-14536.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-west-covina-81327.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-newport-beach-4770.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-beavercreek-136909.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-allen-54529.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-woodland-hills-9501214966.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-anaheim-hills-17513.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-laguna-hills-7320215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-antonio-125841.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-mateo-2823286643.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-pasadena-7132286643.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-elk-grove-67299.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-rancho-santa-margarita-12010215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-sacramento-64418215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-shenandoah-38475.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-torrance-8206.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-plano-22535.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-boulder-100856.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-los-angeles-1377.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-chula-vista-81320.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-brea-48489215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-sacramento-65240.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-laguna-beach-56085.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-concord-32058.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-aurora-51154215223.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-redmond-19369286643.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-orange-15192.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-tacoma-161453.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-chino-hills-24560.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-cedar-park-102700215231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-cedar-park-102700.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-colorado-springs-210690215223.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-cupertino-2752.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-oklahoma-city-138668215233.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-bruno-26049.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-las-vegas-73292215223.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-austin-61218.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-hurst-46638215231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-newport-beach-4770242326.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-cupertino-2752286643.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-la-mesa-81324.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-irvine-3712215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-folsom-56291.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-round-rock-102702.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-boulder-100856215228.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-culver-city-1532.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-downey-132308.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-woodland-hills-9501.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-escondido-102701.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-valley-stream-127561.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-west-covina-81327215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-montebello-81331.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-jose-2902.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-culver-city-1532215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-coral-springs-213546215231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-orlando-127555.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-dallas-15333.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-valley-stream-127561214966.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-westminster-69868.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-orlando-127555215230.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-houston-91680.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-round-rock-102702215231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-la-mesa-81324215223.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-austin-78269.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-lewisville-54530.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-florence-173510.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-tukwila-33119.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-carlsbad-38491215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-oklahoma-city-138667215233.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-las-vegas-73292.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-oviedo-127553.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-brea-48489.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-rafael-67560.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-glendale-8414215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-columbus-41373.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-pembroke-pines-102703.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-plano-22535215230.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-city-of-industry-81339.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-juneau-174522282198.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-anaheim-hills-17513244267.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-mesa-132296215223.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-southlake-27812.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-rancho-santa-margarita-12010.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-noblesville-102704.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-glendale-8414.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-hurst-46638.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-escondido-102701215223.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-elk-grove-67299215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-juneau-174522292005.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-roseville-56290.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-jose-2901.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-sacramento-64418.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-oklahoma-city-138667.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-westlake-village-18951215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-arlington-46635.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-miamisburg-136914.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-teterboro-127562.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-brentwood-158147.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-mesa-132296.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-concord-32058215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-coral-springs-213546.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-roseville-56290215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-columbus-41372.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-carlsbad-38491.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-laguna-hills-7320.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-greenwood-66142.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-sacramento-65240215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-huntington-beach-3735.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-pasadena-7132214966.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-moreno-valley-167260.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-juneau-174522292844.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-webster-91929.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-diego-11927.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-burbank-6603.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-austin-61218215231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-arcadia-81336.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-dublin-35275.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-dallas-15333215230.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-tukwila-33119286643.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-dublin-41374.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-redmond-19369.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-citrus-park-138662.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-irvine-3712.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-tucson-210688.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-vienna-17874.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-orange-15192215216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-colorado-springs-210690.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-puyallup-161450.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-cincinnati-102699.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-mateo-2823.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-pasadena-7132.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-newark-8258.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-san-diego-16001.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-juneau-174522292845.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-peoria-39540.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-orlando-127554215231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-westlake-village-18951.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-burbank-6603215222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-miami-75095.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/BJRI/bj-s-restaurant-brewhouse-corona-81343.xlsx
# APPB
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-totowa-122383.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-rosedale-214658.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-east-islip-143832.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-union-152092.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-huntington-station-180025.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-garfield-122411.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-northvale-134345.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-lindenhurst-143817.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-staten-island-139988252145.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-brentwood-143809.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-staten-island-139988.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-staten-island-140002.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-brooklyn-14901.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-elmont-122664.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-new-hyde-park-122673.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-sunrise-88606.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-clark-151559.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-lake-grove-143805.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-farmingdale-180409.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-staten-island-139981.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-jersey-city-151671.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-new-york-14897.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-piscataway-township-180026.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-miller-place-180407.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-milltown-180411.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-east-hanover-122434.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-bridgewater-180408.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-staten-island-139981252149.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-clifton-151587.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-hackensack-122366.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-pembroke-pines-214588.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-butler-193687.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-doral-75080.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-commack-143840.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-parsippanytroy-hills-152129.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-woodbridge-township-151579.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-patchogue-180028.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-paramus-122398.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-staten-island-146033.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-farmingville-180029.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/APPB/applebee-s-neighborhood-grill-bar-new-york-14900.xlsx
# CAKE
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-rockaway-154759.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-overland-park-146619.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-fort-worth-46482.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-las-vegas-80214175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-chesterfield-146618.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-kendall-74846.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-tampa-139740.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-skokie-4665.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bay-shore-139817.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-pasadena-7123.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-scottsdale-13201.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-arlington-46481.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-boca-raton-215878.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-hanover-151530.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-antonio-47222176199.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-boulder-70515.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-hackensack-122813175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-los-angeles-3645.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-washington-3979.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-marina-del-rey-798.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-thousand-oaks-47037.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-mateo-1150.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-greenwood-64912.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-edison-139815.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-winter-park-120231.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-pleasanton-35284.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-wauwatosa-93942.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-phoenix-16690.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-brea-50298.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-sterling-88462.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-houston-12880.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-jose-2147.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-phoenix-16690175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-lincolnshire-23135.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bridgewater-139816.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-mesa-22307175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-white-plains-146507176214.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-buford-93006.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-arcadia-80237296648.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-dallas-6481.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bethesda-33289.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-st-louis-146621.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cherry-hill-146509181415.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-white-plains-146507.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cerritos-50299.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-denver-24650.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-escondido-86614.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bellevue-19331.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-sherman-oaks-5382.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-nashville-57150.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-diego-15323.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-natick-65731.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-columbia-151529.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-allen-41184.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-liberty-township-90091.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-arlington-12893175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-chandler-22306.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-orlando-120227.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-aventura-88495.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-danbury-151489.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cerritos-50299176216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-liberty-township-90091176196.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-tacoma-163568.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-redondo-beach-2169.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-tukwila-32960.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-riverside-80253.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-baltimore-151497.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-atlanta-24546.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-seattle-38013.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-aventura-88495176209.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-minneapolis-10606.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-antonio-47222.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-chula-vista-86452.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-carlsbad-154756.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-sunrise-88494.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-henderson-72262.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-short-hills-122777.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-jersey-city-139814.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-roseville-55479.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-santa-monica-32415176216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bellevue-19331296648.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-fairfax-88460.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-king-of-prussia-146511.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-huntington-station-139808.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-arlington-12893.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-charlotte-34802.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-kendall-74846296640.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-santa-clara-170.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-houston-23878.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-wayne-122812.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-mission-viejo-9711.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-pembroke-pines-88497.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-atlanta-35211.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-santa-monica-32415.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-atlanta-35210.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-fort-lauderdale-88498.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-alpharetta-45220.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-irvine-3692.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-chicago-2749.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-walnut-creek-17569.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-overland-park-146619176196.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bay-shore-139817176216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-chestnut-hill-1289.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-minnetonka-154747.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-las-vegas-72260.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-frisco-8739.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-willow-grove-146510.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-oak-brook-65389.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-oak-brook-65389176196.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-oklahoma-city-138655.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-seattle-38013296880.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-boston-1304.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-canoga-park-9503.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cambridge-1511.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-anaheim-21472.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-glendale-8322.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-lyndhurst-220222176863.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cincinnati-90090176196.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-mesa-22307.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-jose-2147176216.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-arcadia-80237.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-sterling-88462175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cincinnati-90090.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-brandon-137700.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-indianapolis-26389.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-austin-62014.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-yonkers-146506.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-newport-beach-2557.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-chicago-2749296630.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-braintree-10043.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-franklin-56857.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-hackensack-122813.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-queens-65714.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-miami-74851.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-the-woodlands-18604.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-boca-raton-215878176862.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-littleton-49005.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-sugar-land-22942.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-peoria-38733.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-palo-alto-107.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-columbus-41707.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-cherry-hill-146509175641.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-mclean-17467.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-corte-madera-67839.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-rancho-cucamonga-80254.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-sacramento-53560.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-bridgewater-139816175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-beverly-hills-2655.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-salt-lake-city-154760.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-lake-grove-139813.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-danbury-151489175646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CAKE/the-cheesecake-factory-san-francisco-101041.xlsx
# CHIL
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-wheaton-210203.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-bolingbrook-210199.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-blaine-210204.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-frisco-93738.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-vernon-hills-210198.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-burnsville-210207.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-noblesville-173420.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-bloomington-210206.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-florence-176122.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-chicago-ridge-210200.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-hamilton-176103.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-woodbury-210247.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-downey-111904.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-maplewood-210243.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-downers-grove-210201.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-florence-176098.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-weston-167262.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-roseville-210245.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-eagan-210234.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-lone-tree-52072.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-plymouth-210244.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CHIL/chili-s-grill-bar-san-antonio-99163.xlsx
# CPKI
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-studio-city-5666.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-deer-park-100494136633.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-newport-beach-2565.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-grapevine-41695.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-los-angeles-10365.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-richmond-heights-153207233287.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-creve-coeur-152640.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-seal-beach-18374.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-colorado-springs-214253.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-schaumburg-79827.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-arcadia-88287.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-san-jose-3838.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-tampa-139727233287.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-columbus-37503.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-scottsdale-15260.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-santa-ana-18376.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-norcross-102109.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-thousand-oaks-10366233292.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-riverside-79691.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-philadelphia-152637.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-glendale-8582.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-bridgewater-151162.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-salt-lake-city-153199.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-juneau-174522242407.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-juneau-174522281575.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-huntington-beach-48046233292.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-santa-monica-615.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-chandler-22305.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-laguna-hills-7321.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-chicago-4234.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-long-beach-6264233292.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-austin-62151.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-lakewood-48048.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-dallas-14040.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-juneau-174522290877.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-king-of-prussia-152642.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-mission-viejo-9646.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-phoenix-15264.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-mission-viejo-9646233292.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-murray-153166.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-juneau-174522288270.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-new-york-22246.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-broomfield-70517.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-palo-alto-3836.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-richmond-heights-153207.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-orlando-102854233287.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-oak-brook-65413.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-thousand-oaks-10366.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-houston-16404223366.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-arlington-13276.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-redondo-beach-2211.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-houston-14365.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-walnut-creek-17557.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-skokie-4550.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-the-woodlands-16405233292.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-seattle-37504.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-beverly-hills-2661.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-escondido-79695.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-short-hills-122860233287.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-brea-48047.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-burbank-32435.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-wayne-122862.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/CPKI/california-pizza-kitchen-atlanta-18475.xlsx
# ...
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-spring-59759.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-columbus-41592.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-whittier-126114.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-aurora-49014.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-algonquin-154476.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-chino-25378.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-noblesville-26821.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-oswego-135298.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-beavercreek-136913.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-santa-ana-14492.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-dardenne-prairie-164533.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-irvine-48386.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-deer-park-100710.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-bellevue-19358.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-brentwood-164527.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-lakewood-68240.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-lincolnshire-15046.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-escondido-126115.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-florence-173595.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-tacoma-164536.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-foothill-ranch-7314.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-falls-church-16657.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-oklahoma-city-139783.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-plainfield-154342.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-chicago-ridge-139781.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-cincinnati-90367.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-bothell-43863.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-auburn-164540.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-las-vegas-119934.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-milpitas-71798.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews--90368.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-ashburn-126043.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-puyallup-164541.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-thousand-oaks-19145.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-chandler-22383.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-issaquah-69045.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-woodinville-43862.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-bloomington-59752.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-west-babylon-139784.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-tukwila-32962.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-parker-126044.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-lone-tree-51810.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-citrus-heights-58093.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-peoria-39507.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-avondale-139790.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-miami-79302.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-san-jose-4022.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-bolingbrook-69822.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-westminster-71944.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-goodyear-139788.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-norridge-69128.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-everett-126113.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-des-peres-150286.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-pleasanton-35277.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-mason-90366.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-national-city-82372.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-skokie-12495.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-broomfield-71945.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-dayton-164535.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-dublin-41590.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-buford-92996.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-cumming-129411.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-longmont-126045.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-corona-82410.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-champaign-164594.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-south-plainfield-213436.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-tustin-4785.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-hurst-62118.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-braintree-57952.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-staten-island-188599.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-queen-creek-126112.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-gurnee-154489.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-greenfield-164526.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-roseville-58095.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-columbia-164528.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-henderson-73382.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-redmond-19360.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-orland-park-86422.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-fort-worth-46600.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-gilbert-22388.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-arcadia-69130.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-san-jose-34201.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-henderson-73383.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-paramus-122570.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-nashville-57025.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-bellevue-20284.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-pembroke-pines-126111.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-carle-place-122731?utm_campaign=gpa.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-sterling-102155.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-san-bruno-8934.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-arvada-40452.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-schererville-213435.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-tempe-16557.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-apple-valley-45340.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-brookfield-92961.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-oak-brook-66365.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/RRGB/red-robin-gourmet-burgers-and-brews-west-covina-82387.xlsx
# TGIF
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-denver-40471.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-scarsdale-152262.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-reynoldsburg-154284.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-princeton-151867.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-greenfield-92944.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-bay-shore-152393.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-saint-charles-172217.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-milwaukee-90668.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-massapequa-park-134380.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-towson-206536.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-oak-park-92819.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-yonkers-152309.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-manhasset-134371.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-long-beach-111885.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-west-chester-township-97957.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-longmont-92664.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-central-islip-151575.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-oswego-154433.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-joliet-156438.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-west-nyack-134374.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-islandia-151608.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-farmingville-151592.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-brookfield-92941.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-fairfax-94410.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-denver-52097.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-brookfield-95884.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-gurnee-156644.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-greenfield-95914.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-aurora-52098.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-levittown-135018.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-longmont-71983.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-westbury-134368.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-white-plains-152290.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-rockville-centre-134377.xlsx
# /Users/dereksnow/crc-status-dash/processing/../data/doordash/TGIF/tgi-fridays-lake-grove-151629.xlsx
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-86d239ff536c> in <module>()
#     280             kel["products"] = products
#     281             kel["prices"] = prices
# --> 282             kel["rating"] = v["rating"]
#     283             kel["number"] = v["number"]
#     284             kel["small"] = k
#
# KeyError: 'rating'

# %%
k
# Out:
# 'rating'

# %%
overall_dict[coy][g]
# Out:
# {'Appetizers': {'ingredients': ['Avocado',
#    'cream cheese',
#    'sun-dried tomatoes',
#    'red onions',
#    'cilantro',
#    'chipotle peppers',
#    'sweet tamarind dipping sauce (cal 1060)',
#    'Crispy flatbread chips',
#    'black beans',
#    'BJ’s signature five cheese blend',
#    'jack + cheddar cheese',
#    'sour cream',
#    'shredded lettuce',
#    'pico de gallo',
#    'jalapeños',
#    'avocado (cal 890)',
#    'Sashimi grade ahi tuna',
#    'green + yellow onions',
#    'poke sauce',
#    'diced avocados',
#    'crisp wonton chips (cal 320)',
#    'Sautéed chicken',
#    'mushrooms',
#    'water chestnuts',
#    'celery',
#    'green onions',
#    'garlic',
#    'crisp wonton strips',
#    'sesame soy sauce',
#    'hot Chinese mustard (cal 540)',
#    'Spinach',
#    'artichokes',
#    'cream cheese',
#    'parmesan cheese',
#    'crisp corn tortilla chips (cal 1050)',
#    'Lightly fried potato skins',
#    'jack + cheddar cheese',
#    'applewood smoked bacon',
#    'green onions',
#    'sour cream dip',
#    'ranch (cal 1190)',
#    'Garlic butter breading',
#    'parmesan cheese',
#    'San Marzano marinara (cal 810)',
#    'Lightly breaded artichoke hearts',
#    'parmesan cheese',
#    'lemon garlic aioli dip (cal 390)',
#    'Pan-seared dumplings',
#    'chicken',
#    'ginger',
#    'garlic',
#    'yellow chives',
#    'green onions',
#    'soy ginger sauce',
#    'toasted sesame seeds (cal 420)',
#    'Four beef patties',
#    'fluffy mini buns',
#    'grilled onions',
#    'lettuce',
#    'pickles',
#    'ketchup (cal 880)',
#    'Four beef patties',
#    'fluffy mini buns',
#    'grilled onions',
#    'lettuce',
#    'pickles',
#    'ketchup',
#    'served with fries (cal 880)',
#    'Plump, juicy mushrooms',
#    'BJ’s spinach and artichoke dip',
#    'feta cheese',
#    'red onions',
#    'herb bread crumbs',
#    'parmesan cheese',
#    'a drizzle of lemon pesto sauce (cal 280)',
#    'Crisp, lightly fried brussels sprouts',
#    'big poppa smokers’ desert gold seasoning',
#    'sweet sriracha crema (cal 160)',
#    'Spinach and artichoke dip',
#    'mozzarella sticks',
#    'avocado egg rolls',
#    'boneless wings (cal 2170-2300)',
#    'Lightly breaded calamari',
#    'big poppa smokers’ desert gold seasoning',
#    'San Marzano marinara',
#    'lemon garlic aioli (cal 590)'],
#   'prices': [12.75,
#    11.75,
#    12.95,
#    12.75,
#    11.75,
#    11.75,
#    10.95,
#    6.95,
#    11.95,
#    11.5,
#    12.75,
#    7.75,
#    7.75,
#    19.95,
#    12.95],
#   'products': ['Avocado Egg Rolls',
#    'Crispy Flatbread Nachos',
#    'Ahi Poke',
#    'Chicken Lettuce Wraps',
#    'Spinach and Artichoke Dip',
#    'Crisp Potato Skins Platter',
#    'Mozzarella Sticks',
#    'Crispy Fried Artichokes',
#    'Chicken Pot Stickers',
#    'Sliders',
#    'Sliders with Fries',
#    'Spinach Stuffed Mushrooms',
#    'Honey Sriracha Brussels Sprouts',
#    'Best Beginnings Appetizer Combo',
#    'Crispy Calamari']},
#  "BJ's Brewhouse Burgers": {'ingredients': ['Lettuce',
#    'tomatoes',
#    'grilled onions',
#    'pickles',
#    'parmesan-crusted bun',
#    'served with fries (cal 1000)',
#    'Chipotle',
#    'bleu cheese crumbles',
#    'applewood smoked bacon',
#    'grilled onions',
#    'tomatoes',
#    'Parmesan-crusted bun',
#    'roasted garlic aioli',
#    'served with fries (cal 1160)',
#    'Our diner-style beef burger, hand breaded and fried',
#    'pepper cream gravy',
#    'pepper jack cheese',
#    'sliced avocado',
#    'tomatoes',
#    'mayonnaise',
#    'fried egg',
#    'served with fries'],
#   'prices': [9.95, 11.25, 13.25],
#   'products': ["BJ's Brewhouse Burger",
#    'Black and Bleu-House',
#    'Chicken Fried Steak Burger']},
#  "BJ's Deep Dish Pizza": {'ingredients': ['4 slices Housemade meatballs',
#    'pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (180 calories per slice)',
#    '6 slices Housemade meatballs',
#    'pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (250 calories per slice)',
#    '8 slices Housemade meatballs',
#    'pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (310 calories per slice)',
#    '10 slices Housemade meatballs',
#    'pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (360 calories per slice)',
#    '4 slices Housemade meatballs',
#    'pepperoni',
#    'oven-roasted ham',
#    'applewood smoked bacon',
#    'Italian sausage',
#    'parmesan cheese (240 calories per slice)',
#    '6 slices Housemade meatballs',
#    'pepperoni',
#    'oven-roasted ham',
#    'applewood smoked bacon',
#    'Italian sausage',
#    'parmesan cheese (320 calories per slice)',
#    '8 slices Housemade meatballs',
#    'pepperoni',
#    'oven-roasted ham',
#    'applewood smoked bacon',
#    'Italian sausage',
#    'parmesan cheese (360 calories per slice)',
#    '10 slices Housemade meatballs',
#    'pepperoni',
#    'oven-roasted ham',
#    'applewood smoked bacon',
#    'Italian sausage',
#    'parmesan cheese (400 calories per slice)',
#    '4 slices Pepperoni sliced, diced + julienned',
#    'BJ’s signature five cheese blend (190 calories per slice)',
#    '6 slices Pepperoni sliced, diced + julienned',
#    'BJ’s signature five cheese blend (260 calories per slice)',
#    '8 slices Pepperoni sliced, diced + julienned',
#    'BJ’s signature five cheese blend (340 calories per slice)',
#    '10 slices Pepperoni sliced, diced + julienned',
#    'BJ’s signature five cheese blend (380 calories per slice)',
#    '4 slices Grilled chicken',
#    'spicy buffalo BBQ sauce',
#    'celery',
#    'red onions',
#    'a drizzle of ranch + buffalo sauce (170 calories per slice)',
#    '6 slices Grilled chicken',
#    'spicy buffalo BBQ sauce',
#    'celery',
#    'red onions',
#    'a drizzle of ranch + buffalo sauce (240 calories per slice)',
#    '8 slices Grilled chicken',
#    'spicy buffalo BBQ sauce',
#    'celery',
#    'red onions',
#    'a drizzle of ranch + buffalo sauce (310 calories per slice)',
#    '10 slices Grilled chicken',
#    'spicy buffalo BBQ sauce',
#    'celery',
#    'red onions',
#    'a drizzle of ranch + buffalo sauce (340 calories per slice)',
#    '4 slices Grilled chicken',
#    'applewood smoked bacon',
#    'jack + cheddar cheese',
#    'red onions',
#    'diced tomatoes',
#    'a drizzle of ranch (240 calories per slice)',
#    '6 slices Grilled chicken',
#    'applewood smoked bacon',
#    'jack + cheddar cheese',
#    'red onions',
#    'diced tomatoes',
#    'a drizzle of ranch (330 calories per slice)',
#    '8 slices Grilled chicken',
#    'applewood smoked bacon',
#    'jack + cheddar cheese',
#    'red onions',
#    'diced tomatoes',
#    'a drizzle of ranch (410 calories per slice)',
#    '10 slices Grilled chicken',
#    'applewood smoked bacon',
#    'jack + cheddar cheese',
#    'red onions',
#    'diced tomatoes',
#    'a drizzle of ranch (470 calories per slice)',
#    '4 slices Pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'seasoned tomatoes (190 calories per slice)',
#    '6 slices Pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'seasoned tomatoes (260 calories per slice)',
#    '8 slices Pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'seasoned tomatoes (330 calories per slice)',
#    '10 slices Pepperoni',
#    'Italian sausage',
#    'mushrooms',
#    'seasoned tomatoes (370 calories per slice)',
#    '4 slices Grilled chicken',
#    'basil pesto',
#    'roasted garlic',
#    'kalamata olives',
#    'sun-dried + seasoned tomatoes',
#    'crumbled feta cheese',
#    'peperoncinis (220 calories per slice)',
#    '6 slices Grilled chicken',
#    'basil pesto',
#    'roasted garlic',
#    'kalamata olives',
#    'sun-dried + seasoned tomatoes',
#    'crumbled feta cheese',
#    'peperoncinis (290 calories per slice)',
#    '8 slices Grilled chicken',
#    'basil pesto',
#    'roasted garlic',
#    'kalamata olives',
#    'sun-dried + seasoned tomatoes',
#    'crumbled feta cheese',
#    'peperoncinis (380 calories per slice)',
#    '10 slices Grilled chicken',
#    'basil pesto',
#    'roasted garlic',
#    'kalamata olives',
#    'sun-dried + seasoned tomatoes',
#    'crumbled feta cheese',
#    'peperoncinis (430 calories per slice)',
#    '4 slices Grilled chicken',
#    'applewood smoked bacon',
#    'sweet pineapple',
#    'jalapeños',
#    'tomatoes (200 calories per slice)',
#    '6 slices Grilled chicken',
#    'applewood smoked bacon',
#    'sweet pineapple',
#    'jalapeños',
#    'tomatoes (280 calories per slice)',
#    '8 slices Grilled chicken',
#    'applewood smoked bacon',
#    'sweet pineapple',
#    'jalapeños',
#    'tomatoes (350 calories per slice)',
#    '10 slices Grilled chicken',
#    'applewood smoked bacon',
#    'sweet pineapple',
#    'jalapeños',
#    'tomatoes (390 calories per slice)',
#    '4 slices Pepperoni',
#    'mushrooms',
#    'spinach',
#    'black olives',
#    'seasoned tomatoes (150 calories per slice)',
#    '6 slices Pepperoni',
#    'mushrooms',
#    'spinach',
#    'black olives',
#    'seasoned tomatoes (210 calories per slice)',
#    '8 slices Pepperoni',
#    'mushrooms',
#    'spinach',
#    'black olives',
#    'seasoned tomatoes (280 calories per slice)',
#    '10 slices Pepperoni',
#    'mushrooms',
#    'spinach',
#    'black olives',
#    'seasoned tomatoes (310 calories per slice)',
#    '4 slices Mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (140 calories per slice)',
#    '6 slices Mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (200 calories per slice)',
#    '8 slices Mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (260 calories per slice)',
#    '10 slices Mushrooms',
#    'green bell peppers',
#    'black olives',
#    'white onions',
#    'seasoned tomatoes (290 calories per slice)',
#    '4 slices Grilled chicken',
#    'creamy alfredo',
#    'mushrooms',
#    'roasted garlic',
#    'parmesan cheese',
#    'seasoned tomatoes (180 calories per slice)',
#    '6 slices Grilled chicken',
#    'creamy alfredo',
#    'mushrooms',
#    'roasted garlic',
#    'parmesan cheese',
#    'seasoned tomatoes (250 calories per slice)',
#    '8 slices Grilled chicken',
#    'creamy alfredo',
#    'mushrooms',
#    'roasted garlic',
#    'parmesan cheese',
#    'seasoned tomatoes (330 calories per slice)',
#    '10 slices Grilled chicken',
#    'creamy alfredo',
#    'mushrooms',
#    'roasted garlic',
#    'parmesan cheese',
#    'seasoned tomatoes (370 calories per slice)',
#    '4 slices Oven-roasted ham',
#    'sweet pineapple',
#    'seasoned tomatoes (150 calories per slice)',
#    '6 slices Oven-roasted ham',
#    'sweet pineapple',
#    'seasoned tomatoes (210 calories per slice)',
#    '8 slices Oven-roasted ham',
#    'sweet pineapple',
#    'seasoned tomatoes (270 calories per slice)',
#    '10 slices Oven-roasted ham',
#    'sweet pineapple',
#    'seasoned tomatoes (300 calories per slice)',
#    '4 slices Grilled chicken',
#    'hickory-smoked BBQ sauce',
#    'red onions',
#    'seasoned tomatoes',
#    'cilantro (170 calories per slice)',
#    '6 slices Grilled chicken',
#    'hickory-smoked BBQ sauce',
#    'red onions',
#    'seasoned tomatoes',
#    'cilantro (240 calories per slice)',
#    '8 slices Grilled chicken',
#    'hickory-smoked BBQ sauce',
#    'red onions',
#    'seasoned tomatoes',
#    'cilantro (310 calories per slice)',
#    '10 slices Grilled chicken',
#    'hickory-smoked BBQ sauce',
#    'red onions',
#    'seasoned tomatoes',
#    'cilantro (340 calories per slice)'],
#   'prices': [13.5,
#    17.95,
#    23.95,
#    28.5,
#    13.5,
#    17.95,
#    23.95,
#    28.5,
#    12.95,
#    16.95,
#    22.75,
#    26.95,
#    13.5,
#    17.95,
#    23.95,
#    28.5,
#    13.5,
#    17.95,
#    23.95,
#    28.5,
#    12.95,
#    16.95,
#    22.75,
#    26.95,
#    13.5,
#    17.95,
#    23.95,
#    28.5,
#    13.5,
#    17.95,
#    23.95,
#    28.5,
#    12.95,
#    16.95,
#    22.75,
#    26.95,
#    12.95,
#    16.95,
#    22.75,
#    26.95,
#    13.5,
#    17.95,
#    23.95,
#    28.5,
#    11.95,
#    15.5,
#    20.75,
#    23.95,
#    13.5,
#    17.95,
#    23.95,
#    28.5],
#   'products': ['BJ\'s Favorite (Mini 6")',
#    'BJ\'s Favorite (Small 9")',
#    'BJ\'s Favorite (Medium 12")',
#    'BJ\'s Favorite (Large 14")',
#    'Gourmet Five Meat (Mini 6")',
#    'Gourmet Five Meat (Small 9")',
#    'Gourmet Five Meat (Medium 12")',
#    'Gourmet Five Meat (Large 14")',
#    'Pepperoni Extreme (Mini 6")',
#    'Pepperoni Extreme (Small 9")',
#    'Pepperoni Extreme (Medium 12")',
#    'Pepperoni Extreme (Large 14")',
#    'Buffalo Chicken (Mini 6")',
#    'Buffalo Chicken (Small 9")',
#    'Buffalo Chicken (Medium 12")',
#    'Buffalo Chicken (Large 14")',
#    'Chicken Bacon Ranch (Mini 6")',
#    'Chicken Bacon Ranch (Small 9")',
#    'Chicken Bacon Ranch (Medium 12")',
#    'Chicken Bacon Ranch (Large 14")',
#    'BJ\'s Classic Combo (Mini 6")',
#    'BJ\'s Classic Combo (Small 9")',
#    'BJ\'s Classic Combo (Medium 12")',
#    'BJ\'s Classic Combo (Large 14")',
#    'Mediterranean (Mini 6")',
#    'Mediterranean (Small 9")',
#    'Mediterranean (Medium 12")',
#    'Mediterranean (Large 14")',
#    'Spicy Hawaiian Chicken (Mini 6")',
#    'Spicy Hawaiian Chicken (Small 9")',
#    'Spicy Hawaiian Chicken (Medium 12")',
#    'Spicy Hawaiian Chicken (Large 14")',
#    'California Supreme (Mini 6")',
#    'California Supreme (Small 9")',
#    'California Supreme (Medium 12")',
#    'California Supreme (Large 14")',
#    'Vegetarian (Mini 6")',
#    'Vegetarian (Small 9")',
#    'Vegetarian (Medium 12")',
#    'Vegetarian (Large 14")',
#    'Great White (Mini 6")',
#    'Great White (Small 9")',
#    'Great White (Medium 12")',
#    'Great White (Large 14")',
#    'Sweet Pig (Mini 6")',
#    'Sweet Pig (Small 9")',
#    'Sweet Pig (Medium 12")',
#    'Sweet Pig (Large 14")',
#    'Barbeque Chicken (Mini 6")',
#    'Barbeque Chicken (Small 9")',
#    'Barbeque Chicken (Medium 12")',
#    'Barbeque Chicken (Large 14")']},
#  "BJ's Enlightened Entrées": {'ingredients': ['Peruvian quinoa + brown rice',
#    'sautéed red onions',
#    'sliced mushrooms',
#    'sautéed spinach',
#    'seasoned tomatoes',
#    'a drizzle of extra virgin olive oil + lemon juice',
#    'choice of herb-roasted protein',
#    'Chicken breast',
#    'broccoli',
#    'carrots',
#    'spicy peanut sauce',
#    'almonds',
#    'sesame seeds',
#    'lime',
#    'cilantro',
#    'buckwheat soba noodles (cal 1040)',
#    'Seasoned, lean, all-natural ground buffalo',
#    'BJ’s Peppered BBQ sauce',
#    'seared Hatch chiles',
#    'pico de gallo',
#    'santa fe dressing',
#    'red onions',
#    'lettuce',
#    'toasted parker house bun',
#    'mixed green salad (cal 700)',
#    'All-white-meat patty',
#    'baby field greens',
#    'red wine vinaigrette',
#    'dried cranberries',
#    'tomatoes',
#    'chargrilled red onions',
#    'dijon mayonnaise',
#    'toasted parker house bun',
#    'mixed green salad (cal 780)',
#    'Barbacoa-spiced chicken',
#    'brown rice',
#    'black beans',
#    'feta cheese',
#    'cilantro',
#    'Greek yogurt crema',
#    'fire-roasted tomato salsa (cal 520)',
#    'Herb-roasted chicken breasts',
#    'big poppa smokers’ desert gold rub',
#    'brown rice',
#    'sautéed red onions',
#    'fire-roasted red peppers',
#    'tomatoes',
#    'roasted brussels sprouts',
#    'lemon thyme sauce (cal 650)',
#    '￼Oven-roasted Atlantic salmon',
#    'sweet, savory cherry chipotle glaze',
#    'roasted asparagus',
#    'fire-roasted red pepper, tomato + spinach couscous (cal 580)',
#    'All enlightened tacos are served with seasonal bistro grains Broiled shrimp',
#    'tomatoes',
#    'arugula',
#    'parmesan cheese',
#    'cilantro lime vinaigrette',
#    'chargrilled pita (cal 790)',
#    'Roasted barbacoa cauliflower',
#    'roasted red peppers',
#    'corn',
#    'jack + cheddar cheese',
#    'yellow onions',
#    'tomatoes',
#    'Greek yogurt crema',
#    'cilantro',
#    'chargrilled pita',
#    'seasonal bistro grains on the side (cal 650)',
#    'Seasoned grilled chicken',
#    'cucumber',
#    'tomatoes',
#    'red onions',
#    'feta cheese',
#    'cilantro',
#    'red\xa0wine\xa0vinaigrette',
#    'greek yogurt crema',
#    'chargrilled pita',
#    'seasonal\xa0bistro\xa0grains\xa0on\xa0the\xa0side (cal 670)'],
#   'prices': [10.95, 15.95, 13.5, 11.5, 14.5, 15.5, 16.95, 12.75, 10.75, 12.75],
#   'products': ['Peruvian Quinoa Bowl',
#    'Spicy Peanut Chicken with Soba Noodles',
#    'Barbeque Bison Burger',
#    'Turkey Burger',
#    'Fire-Roasted Barbacoa Chicken',
#    'Lemon Thyme Chicken',
#    'Cherry Chipotle Glazed Salmon',
#    'Shrimp and Arugula Pita Tacos',
#    'Barbacoa Cauliflower Pita Tacos',
#    'Mediterranean Chicken Pita Tacos']},
#  "BJ's Enlightened Salads": {'ingredients': ['Gluten-free item Baby kale',
#    'herb-roasted brussels sprouts',
#    'romaine',
#    'fresh blueberries',
#    'sweet red grapes',
#    'dried cranberries',
#    'goat cheese',
#    'cucumbers',
#    'candied pecans',
#    'toasted pepitas',
#    'red onions',
#    'strawberry vinaigrette (cal 440)',
#    'Grilled chicken',
#    'baby field greens',
#    'napa cabbage',
#    'romaine',
#    'red bell peppers',
#    'snap peas',
#    'green onions',
#    'shredded carrots',
#    'sesame seeds',
#    'crisp wonton strips',
#    'cilantro',
#    'mandarin oranges',
#    'honey ginger dressing (cal 540)',
#    'Sashimi grade ahi',
#    'baby field greens',
#    'napa cabbage',
#    'romaine',
#    'red bell peppers',
#    'tomatoes',
#    'avocado',
#    'pickled cucumber',
#    'cilantro',
#    'spicy wasabi',
#    'wonton strips',
#    'red + green onions',
#    'rice wine vinaigrette (cal 580)'],
#   'prices': [11.75, 13.25, 16.95],
#   'products': ['Kale and Roasted Brussels Sprouts Salad',
#    'Asian Chopped Salad',
#    'Seared Ahi Salad']},
#  "BJ's Flatbread - Appetizers": {'ingredients': ['Pepperoni sliced, diced + julienned',
#    'BJ’s signature five cheese blend',
#    'zesty pizza sauce (8 slices–cal 190/slice)',
#    'Fresh mozzarella',
#    'sweet tomato sauce',
#    'fresh basil',
#    'parmesan cheese (8 slices–cal 100/slice)',
#    'Grilled chicken',
#    'applewood smoked bacon',
#    'seasoned tomatoes',
#    'BJ’s signature five cheese blend',
#    'avocado',
#    'a drizzle of roasted garlic aioli (8 slices–cal 110/slice)'],
#   'prices': [12.25, 11.75, 12.25],
#   'products': ['Pepperoni Extreme', 'Margherita Fresca', 'California Club']},
#  "BJ's Garden Fresh Entrée Salads": {'ingredients': ['Crisp romaine',
#    'blackened chicken breast',
#    'red onions',
#    'fire-roasted red peppers',
#    'jack + cheddar cheese',
#    'avocado',
#    'sweet corn',
#    'tomatoes',
#    'crisp corn tortilla strips',
#    'santa fe dressing (cal 980)',
#    'Crisp romaine',
#    'slow-roasted herb Turkey breast',
#    'hard-boiled egg',
#    'applewood smoked bacon',
#    'avocado',
#    'jack + cheddar cheese',
#    'cucumbers',
#    'tomatoes',
#    'bleu cheese crumbles',
#    'housemade avocado ranch dressing (cal 1060)',
#    'Crisp romaine',
#    'iceberg lettuce',
#    'lightly fried chicken tenders',
#    'toasted almonds',
#    'cucumber',
#    'hard-boiled egg',
#    'sweet corn',
#    'tomatoes',
#    'honey mustard dressing (cal 1370)',
#    'Crisp romaine',
#    'iceberg lettuce',
#    'sweet corn',
#    'black beans',
#    'crunchy jicama',
#    'mozzarella',
#    'tomatoes',
#    'green onions',
#    'cilantro',
#    'BBQ ranch dressing',
#    'crispy onion strings (cal 930)',
#    'Crisp romaine',
#    'oven-baked croutons',
#    'parmesan cheese',
#    'creamy Caesar dressing (cal 810)',
#    'Gluten-free item Baby kale',
#    'herb-roasted brussels sprouts',
#    'romaine',
#    'fresh blueberries',
#    'sweet red grapes',
#    'dried cranberries',
#    'goat cheese',
#    'cucumbers',
#    'candied pecans',
#    'toasted pepitas',
#    'red onions',
#    'strawberry vinaigrette (cal 440)',
#    'Grilled chicken',
#    'baby field greens',
#    'napa cabbage',
#    'romaine',
#    'red bell peppers',
#    'snap peas',
#    'green onions',
#    'shredded carrots',
#    'sesame seeds',
#    'crisp wonton strips',
#    'cilantro',
#    'mandarin oranges',
#    'honey ginger dressing (cal 540)',
#    'Sashimi grade ahi',
#    'baby field greens',
#    'napa cabbage',
#    'romaine',
#    'red bell peppers',
#    'tomatoes',
#    'avocado',
#    'pickled cucumber',
#    'cilantro',
#    'spicy wasabi',
#    'wonton strips',
#    'red + green onions',
#    'rice wine vinaigrette (cal 580)'],
#   'prices': [14.95, 14.5, 14.95, 14.95, 11.95, 11.75, 13.25, 16.95],
#   'products': ['Santa Fe Salad',
#    'Derby-Style Chicken Cobb',
#    'Honey-Crisp Chicken Salad',
#    'Barbeque Chicken Chopped Salad',
#    'Caesar Salad',
#    'Enlightened Kale and Roasted Brussels Sprouts Salad',
#    'Enlightened Asian Chopped Salad',
#    'Enlightened Seared Ahi Salad']},
#  "BJ's Loaded Burgers": {'ingredients': ['Sweet, tangy BJ’s Peppered BBQ sauce',
#    'smoked brisket',
#    'applewood smoked bacon',
#    'jack + cheddar cheese',
#    'red onions',
#    'mayonnaise',
#    'served with fries (cal 1610)',
#    'Applewood smoked bacon',
#    'cheddar cheese',
#    'tomatoes',
#    'lettuce',
#    'pickles',
#    'mayonnaise',
#    'BJ’s signature burger sauce',
#    'served with fries (cal 1380)',
#    'Fire-grilled beef patty',
#    'tomatoes',
#    'lettuce',
#    'pickles',
#    'premium parker house bun',
#    'mayonnaise',
#    'BJ’s signature burger sauce',
#    'served with fries (cal 1210)',
#    'Fried jalapeños',
#    'pepper jack cheese',
#    'chipotle mayonnaise',
#    'red onions',
#    'tomatoes',
#    'lettuce',
#    'cilantro',
#    'served with fries (cal 1310)',
#    'Grilled portobello mushroom',
#    'Swiss cheese',
#    'basil pesto',
#    'arugula',
#    'balsamic vinaigrette',
#    'caramelized onions',
#    'tomatoes',
#    'roasted garlic aioli',
#    'served with fries (cal 1430)',
#    'Housemade guacamole',
#    'applewood smoked bacon',
#    'pepper jack cheese',
#    'chipotle mayonnaise',
#    'red onions',
#    'tomatoes',
#    'jalapeños',
#    'served with fries (cal\xa01590)'],
#   'prices': [14.5, 13.75, 12.75, 13.95, 14.5, 13.95],
#   'products': ['Hickory Brisket and Bacon Burger',
#    'Bacon Cheeseburger',
#    'Classic Burger',
#    'Crispy Jalapeño Burger',
#    'Portobello Swiss Burger',
#    'Bacon-Guacamole Deluxe Burger']},
#  "BJ's Premium Wings": {'ingredients': ['Crispy, bone-in wings',
#    'tossed in your choice of our signature sauces or dry rubs (cal 750)',
#    'A full pound (pre-cooked weight) of all-white-meat boneless wings',
#    'tossed in your choice of our signature sauces or dry rubs (cal 870)',
#    'Crispy, bone-in wings',
#    'drizzled with hot and spicy buffalo + ranch',
#    'celery sticks',
#    'extra sauce for dipping (cal 820)',
#    'Five slow-roasted baby back pork ribs',
#    'BJ’s handcrafted root beer glaze',
#    'spicy sriracha slaw',
#    'green onions (cal 490)'],
#   'prices': [12.95, 12.5, 12.95, 11.75],
#   'products': ['Bone-in Chicken Wings',
#    'Boneless Wings',
#    "BJ's Original Wings",
#    'Root Beer Glazed Ribs']},
#  "BJ's Small Plates & Snacks": {'ingredients': ['Turmeric-roasted cauliflower florets',
#    'lentils',
#    'green onions',
#    'toasted almonds (cal 280)',
#    'Israeli couscous',
#    'jack + cheddar cheese sauce',
#    'chopped bacon',
#    'tomatoes',
#    'green onions',
#    'parmesan bread crumbs',
#    'basil (cal 590)',
#    'Garlic bread knots',
#    'parmesan cheese',
#    'parsley',
#    'San Marzano marinara (cal 470)',
#    'Roasted golden beets',
#    'goat cheese',
#    'balsamic glaze',
#    'fresh basil (cal 160)',
#    'Crispy sweet potato fries (cal 330)',
#    'Fried cheese curds',
#    'parmesan cheese',
#    'ranch for dipping',
#    'Housemade meatballs',
#    'BJ’s pm porter® mushroom gravy',
#    'white cheddar mashed potatoes',
#    'Smoked sausage',
#    'dill pickles',
#    'pita bread',
#    'pickled red onion',
#    'honey Dijon mustard',
#    'Blistered shishito peppers',
#    'crispy pepperoni'],
#   'prices': [4.95, 4.95, 4.95, 4.95, 3.5, 4.95, 6.95, 6.95, 6.95, 6.95],
#   'products': ['Turmeric-Roasted Cauliflower',
#    'Creamy Couscous Mac & Cheese',
#    'Garlic Parmesan Knots',
#    'Roasted Golden Beets',
#    'Regular Cut Fries',
#    'Sweet Potato Fries',
#    'New Fried Wisconsin Cheese Curds',
#    'New Brewhouse Meatballs',
#    'New Hickory Smoked Sausage',
#    'New Blistered Shishitos & Crispy Pepperoni']},
#  "BJ's Tavern-Cut Pizza": {'ingredients': ['Pepperoni',
#    'mushrooms',
#    'Italian sausage',
#    'BJ’s signature five cheese blend (110 calories per slice)',
#    'Seasoned tomatoes',
#    'fresh basil',
#    'fresh mozzarella',
#    'BJ’s signature five cheese blend',
#    'parmesan cheese (70 calories per slice)',
#    'Oven-roasted ham',
#    'applewood smoked bacon',
#    'sweet pineapple',
#    'jalapeños',
#    'BJ’s signature five cheese blend (90 calories per slice)',
#    'Housemade meatballs',
#    'diced pepperoni',
#    'oven-roasted ham',
#    'spicy peperoncinis',
#    'BJ’s signature five cheese blend',
#    'crushed Italian herbs (110 calories per slice)',
#    'Grilled chicken',
#    'basil pesto',
#    'fire-roasted red peppers',
#    'seasoned artichoke hearts',
#    'tomatoes',
#    'BJ’s signature five cheese blend',
#    'parmesan cheese',
#    'goat cheese crumbles (100 calories per slice)'],
#   'prices': [16.5, 15.95, 16.25, 16.75, 16.95],
#   'products': ["BJ's Brewhouse Classic",
#    'Old Country Tomato Basil',
#    'The Spicy Pig',
#    'The Italian Market',
#    'Garlic Chicken Pesto']},
#  'Beverages': {'ingredients': ['Zero-calorie and caffeine-free',
#    'Zero-calorie and caffeine-free',
#    'Cal 0',
#    'Cal 160',
#    'Hot (cal 100)',
#    'Hot (cal 100)'],
#   'prices': [1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    1.95,
#    4.75,
#    1.95,
#    1.95,
#    3.25,
#    3.25,
#    3.95,
#    3.5,
#    3.5,
#    1.95,
#    1.95],
#   'products': ['Sunset Peach Iced Tea',
#    'Berry Hibiscus Iced Tea',
#    'Cucumber Mint Sparkling Water',
#    'Raspberry Sparkling Water',
#    'Peachberry Iced Tea',
#    'Iced Tea',
#    'Mandarin Orange Green Tea',
#    'Sparkling Raspberry Lemonade',
#    'Strawberry Lemonade',
#    'Lemonade',
#    "BJ's Handcrafted Draft Sodas",
#    "BJ's Handcrafted Floats",
#    'Soda',
#    'Hot Tea',
#    'San Pellegrino Sparkling Mineral Water',
#    'Cold Brew Coffee',
#    'Salted Caramel Cold Brew Coffee',
#    'Cappuccino',
#    'Café Latte',
#    'Coffee',
#    'Decaf Coffee']},
#  'Build Your Own Pizza': {'ingredients': ['4 slices 140 calories per slice',
#    '6 slices 210 calories per slice',
#    '8 slices 270 calories per slice',
#    '￼10 slices 300 calories per slice'],
#   'prices': [9.95, 12.5, 16.75, 19.5],
#   'products': ['Build Your Own Pizza (Mini 6")',
#    'Build Your Own Pizza (Small 9")',
#    'Build Your Own Pizza (Medium 12")',
#    'Build Your Own Pizza (Large 14")']},
#  'Chips and Dips': {'ingredients': ['Housemade sriracha queso',
#    'jack + cheddar cheese',
#    'green onions',
#    'crispy corn tortilla chips',
#    'choice of topping: seared hatch chiles',
#    'piranha® pale ale chili" (cal 880/960)',
#    'Housemade guacamole',
#    'fire roasted salsa',
#    'corn tortilla chips (cal 780)',
#    'Fire-roasted salsa',
#    'corn tortilla chips (cal 600)'],
#   'prices': [7.25, 6.75, 5.5],
#   'products': ['Sriracha Queso Dips',
#    'Housemade Guacamole and Chips',
#    'Chips and Fire-Roasted Salsa']},
#  'Crispy Chicken Sandwiches': {'ingredients': ['Crispy fried chicken',
#    'sliced ham',
#    'applewood smoked bacon',
#    'creamy alfredo',
#    'Swiss cheese',
#    'Dijon mayonnaise',
#    'toasted parker house bun',
#    'served with fries',
#    'Crispy fried chicken',
#    'Nashville hot sauce',
#    'dill pickles',
#    'ranch',
#    'toasted parker house bun',
#    'served with fries',
#    'Crispy fried chicken',
#    'honey mustard',
#    'lettuce',
#    'tomato',
#    'dill pickles',
#    'toasted parker house bun',
#    'served with fries'],
#   'prices': [13.75, 12.95, 12.75],
#   'products': ['Southern Comfort Crispy Chicken Sandwich',
#    'Nashville Hot Crispy Chicken Sandwich',
#    "BJ's Classic Chicken Sandwich"]},
#  'Disclaimer': {'ingredients': [],
#   'prices': [0.0],
#   'products': ['Disclaimer']},
#  'Gluten-Free Choices': {'ingredients': ['Crisp, herb-infused 10-inch crust',
#    'zesty pizza sauce',
#    'BJ’s signature five cheese blend (6 slices–cal 130/slice)',
#    'Fresh-baked chocolate chip cookie',
#    'rich vanilla bean ice cream (cal 1180)'],
#   'prices': [12.25, 7.95],
#   'products': ['Gluten-Free Thin Crust Cheese Pizza',
#    'Gluten-free Chocolate Chip Pizookie']},
#  'Housemade Soups': {'ingredients': ['Gluten-free item Bowl Hearty lentil soup (cal 300)',
#    'Bowl Creamy tomato soup',
#    'croutons',
#    'fresh parsley (cal 560)',
#    'Bowl Creamy broccoli cheddar soup',
#    'jack + cheddar cheese',
#    'parsley (cal 380)',
#    'Bowl Creamy clam chowder',
#    'fresh parsley',
#    'crackers (cal 440)',
#    'Bowl Piranha® pale ale chili',
#    'jack + cheddar cheese',
#    'sour cream',
#    'green onion (cal 560)',
#    'Bowl Chicken tortilla soup',
#    'jack + cheddar cheese',
#    'avocado',
#    'cilantro',
#    'tortilla strips (cal 280)',
#    'Bowl of housemade soup',
#    'house, Caesar, wedge or fresh mozzarella and tomato salad (cal 360-970)'],
#   'prices': [7.5, 7.5, 7.5, 7.5, 7.95, 7.5, 10.75],
#   'products': ['Vegan Lentil with Ancient\xa0Grains',
#    'Tuscan Tomato Bisque',
#    'Broccoli Cheddar',
#    'Clam Chowder',
#    'Piranha Pale Ale Chili',
#    'Chicken Tortilla',
#    'Soup and Salad Combo']},
#  "Kid's Menu": {'ingredients': ['Choice of 6" cheese or pepperoni pizza',
#    "choice of kids' drink",
#    'Fried chicken tenders',
#    'served with ranch',
#    'Hot and tasty kraft™ macaroni & cheese',
#    'Mini corn dogs',
#    'Grilled sourdough',
#    'melted cheddar cheese',
#    "Burger with lettuce, tomatoes, and pickles Served with your choice of kids' side and drink",
#    'Spaghetti',
#    'choice of sauce',
#    'Grilled chicken',
#    'rice pilaf',
#    'steamed veggies',
#    "choice of kids' drink",
#    'Herb-roasted, grilled chicken',
#    'fettuccini',
#    'creamy alfredo',
#    'steamed broccoli',
#    'parmesan cheese',
#    'garlic parmesan knot',
#    "choice of kids' drink",
#    'A warm cookie topped with ice cream Your choice of: chocolate chunk',
#    'white chocolate macadamia nut',
#    "cookies 'n' cream",
#    'peanut butter',
#    'salted caramel',
#    'triple chocolate',
#    'gluten - free chocolate chip',
#    'Scoop of rich vanilla bean ice cream',
#    'chocolate syrup',
#    'whipped cream',
#    'cherry on top'],
#   'prices': [5.95, 6.25, 6.25, 6.25, 6.25, 6.25, 6.25, 6.25, 6.25, 2.75, 1.95],
#   'products': ['6" Deep Dish Pizza',
#    'Chicken Tenders',
#    "Mac 'N' Cheese",
#    'Mini Corn Dogs',
#    'Grilled Cheese',
#    "Kids' Burger",
#    'Spaghetti',
#    "Big Kids' Grilled Chicken",
#    "Big Kids' Grilled Chicken Alfredo",
#    "Kid's Mini Pizookies",
#    "Kid's Sundae"]},
#  'More Great Desserts': {'ingredients': ['Fluffy dough baked golden brown',
#    'dusting of cinnamon + sugar',
#    'rich vanilla bean ice cream',
#    'fresh strawberries',
#    'a drizzle of strawberry purée',
#    'whipped cream (cal 630)',
#    'Rich vanilla bean',
#    'Ghirardelli® Double Chocolate Chip',
#    'Rich vanilla bean',
#    'Ghirardelli® Double Chocolate Chip'],
#   'prices': [7.95, 3.25, 4.25],
#   'products': ["BJ's Baked Beignet",
#    'Ice Cream - 1 Scoop',
#    'Ice Cream - 2 Scoops']},
#  'Most Loved': {'ingredients': ['Avocado',
#    'cream cheese',
#    'sun-dried tomatoes',
#    'red onions',
#    'cilantro',
#    'chipotle peppers',
#    'sweet tamarind dipping sauce (cal 1060)',
#    'Lettuce',
#    'tomatoes',
#    'grilled onions',
#    'pickles',
#    'parmesan-crusted bun',
#    'served with fries (cal 1000)',
#    'Housemade meatballs',
#    'San Marzano marinara',
#    'fresh garlic',
#    'red pepper flakes',
#    'fresh basil',
#    'parmesan cheese (cal 1460)',
#    'Your choice† of three mini pizookies ® each served with a scoop of ice cream (cal 1740-2160)',
#    '4 slices Grilled chicken',
#    'creamy alfredo',
#    'mushrooms',
#    'roasted garlic',
#    'parmesan cheese',
#    'seasoned tomatoes (180 calories per slice)'],
#   'prices': [12.75, 9.95, 16.95, 11.5, 13.5],
#   'products': ['Avocado Egg Rolls',
#    "BJ's Brewhouse Burger",
#    'Jumbo Spaghetti and Meatballs',
#    'Pizookie Trio',
#    'Great White (Mini 6")']},
#  'Most Popular': {'ingredients': ['A full pound (pre-cooked weight) of all-white-meat boneless wings',
#    'tossed in your choice of our signature sauces or dry rubs (cal 870)',
#    'Applewood smoked bacon',
#    'cheddar cheese',
#    'tomatoes',
#    'lettuce',
#    'pickles',
#    'mayonnaise',
#    'BJ’s signature burger sauce',
#    'served with fries (cal 1380)',
#    'Slow-roasted overnight baby back ribs',
#    'big poppa smokers’ sweet money championship rub',
#    'BJ’s peppered BBQ sauce',
#    'Juicy, well-marbled, fresh 14 oz (pre-cooked weight) rib-eye (cal 1080)',
#    'Fried chicken tenders',
#    'served with ranch',
#    'Crispy, bone-in wings',
#    'tossed in your choice of our signature sauces or dry rubs (cal 750)',
#    'Herb-roasted, grilled chicken',
#    'fettuccini',
#    'creamy alfredo',
#    'steamed broccoli',
#    'parmesan cheese (cal 1380)',
#    'Thick, tender house special sirloin (cal 500)'],
#   'prices': [1.95, 12.5, 13.75, 20.25, 24.95, 1.95, 6.25, 12.95, 17.25, 18.5],
#   'products': ['Soda',
#    'Boneless Wings',
#    'Bacon Cheeseburger',
#    'Baby Back Pork Ribs',
#    "BJ's Classic Rib‑Eye",
#    "BJ's Handcrafted Draft Sodas",
#    'Chicken Tenders',
#    'Bone-in Chicken Wings',
#    'Grilled Chicken Alfredo',
#    'House Top Sirloin']},
#  'Pasta Favorites': {'ingredients': ['Sautéed garlic shrimp',
#    'asparagus',
#    'San Marzano marinara',
#    'fresh basil',
#    'parmesan cheese',
#    'toasted bread crumbs (cal 730)',
#    'Sautéed bell peppers',
#    'onions',
#    'garlic',
#    'seasoned tomatoes',
#    'San Marzano marinara',
#    'parmesan cheese',
#    'fresh basil (cal 740)',
#    'Housemade meatballs',
#    'San Marzano marinara',
#    'fresh garlic',
#    'red pepper flakes',
#    'fresh basil',
#    'parmesan cheese (cal 1460)',
#    'Housemade meatballs',
#    'Italian sausage',
#    'diced pepperoni',
#    'San Marzano marinara',
#    'creamy alfredo',
#    'Italian herbs',
#    'BJ’s signature five cheese blend',
#    'parmesan cheese',
#    'fresh basil (cal 1400)',
#    'Sautéed jumbo shrimp',
#    'spaghetti',
#    'garlic butter sauce',
#    'diced tomatoes',
#    'garlic',
#    'fresh basil',
#    'parsley',
#    'parmesan cheese',
#    'Herb-roasted, grilled chicken',
#    'fettuccini',
#    'creamy alfredo',
#    'steamed broccoli',
#    'parmesan cheese (cal 1380)'],
#   'prices': [17.95, 12.95, 16.95, 16.75, 19.25, 17.25],
#   'products': ['Shrimp and Asparagus Penne',
#    'Italiano Vegetable Penne',
#    'Jumbo Spaghetti and Meatballs',
#    'Deep Dish Ziti',
#    'Shrimp Scampi Pasta',
#    'Grilled Chicken Alfredo']},
#  'Ribs and Steaks': {'ingredients': ['Slow-roasted overnight baby back ribs',
#    'big poppa smokers’ sweet money championship rub',
#    'BJ’s peppered BBQ sauce',
#    'Juicy, well-marbled, fresh 14 oz (pre-cooked weight) rib-eye (cal 1080)',
#    'Thick, tender house special sirloin (cal 500)'],
#   'prices': [20.25, 24.95, 18.5],
#   'products': ['Baby Back Pork Ribs',
#    "BJ's Classic Rib‑Eye",
#    'House Top Sirloin']},
#  'Sandwiches and Tacos': {'ingredients': ['Sliced, slow-roasted prime rib',
#    'hoagie roll',
#    'au jus',
#    'creamy horseradish served on the side',
#    'served with fries (cal 1270)',
#    'Slow-roasted herb Turkey breast',
#    'Swiss cheese',
#    'caramelized onions',
#    'hoagie roll',
#    'au jus',
#    'horseradish aioli',
#    'served with fries (cal 1330)',
#    'Seasoned grilled chicken',
#    'cucumber',
#    'tomatoes',
#    'red onions',
#    'feta cheese',
#    'cilantro',
#    'red\xa0wine\xa0vinaigrette',
#    'greek yogurt crema',
#    'chargrilled pita',
#    'seasonal\xa0bistro\xa0grains\xa0on\xa0the\xa0side (cal 670)',
#    'Broiled shrimp',
#    'tomatoes',
#    'arugula',
#    'parmesan cheese',
#    'cilantro lime vinaigrette',
#    'chargrilled pita',
#    'seasonal bistro grains on the side (cal 790)',
#    'Hand-pulled pork shoulder',
#    'BJ’s peppered BBQ sauce',
#    'crispy onion strings',
#    'creamy BBQ ranch dressing',
#    'toasted parker house bun',
#    'BJ’s signature coleslaw (cal 1420)',
#    'Chipotle mayonnaise',
#    'santa fe dressing',
#    'napa cabbage',
#    'carrots',
#    'red onions',
#    'cilantro',
#    'avocado\xa0ranch',
#    'fire-roasted tomato salsa',
#    'tortilla\xa0chips (cal 640-770)',
#    'Roasted barbacoa cauliflower',
#    'roasted red peppers',
#    'corn',
#    'jack + cheddar cheese',
#    'yellow onions',
#    'tomatoes',
#    'Greek yogurt crema',
#    'cilantro',
#    'chargrilled pita',
#    'seasonal bistro grains on the side (cal 650)',
#    'Grilled chicken',
#    'applewood smoked bacon',
#    'avocado',
#    'melted Swiss cheese',
#    'lettuce',
#    'tomatoes',
#    'roasted garlic aioli',
#    'grilled sourdough bread (cal 1280)'],
#   'prices': [15.95, 13.25, 12.75, 12.75, 12.95, 12.5, 10.75, 12.95],
#   'products': ['Classic Prime Rib Dip',
#    'Hand-Pulled Turkey Dip',
#    'Enlightened Mediterranean Chicken Pita Tacos',
#    'Enlightened Shrimp and Arugula Pita Tacos',
#    'Barbeque Pulled Pork',
#    'Mahi-Mahi or Shrimp Tacos',
#    'Enlightened Barbacoa Cauliflower Pita Tacos',
#    'California Chicken Club']},
#  'Specialty Entrées': {'ingredients': ['Chicken breast',
#    'broccoli',
#    'carrots',
#    'spicy peanut sauce',
#    'almonds',
#    'sesame seeds',
#    'lime',
#    'cilantro',
#    'buckwheat soba noodles (cal 1040)',
#    'Flame-broiled or blackened salmon fillet',
#    'lemon chardonnay butter sauce',
#    'rice pilaf',
#    'steamed broccoli (cal 840/870)',
#    'Blackened chicken breast',
#    'sautéed shrimp',
#    'chicken-andouille sausage',
#    'bell peppers',
#    'white onions',
#    'tomatoes',
#    'Cajun-spiced broth',
#    'rice pilaf (cal 1140)',
#    'Lightly fried cod fillets',
#    'BJ’s brewhouse blonde® batter',
#    'fries',
#    'housemade tartar sauce (cal 1110)',
#    'Chicken breast',
#    'lemon chardonnay butter sauce',
#    'sun-dried tomatoes',
#    'fresh basil',
#    'parmesan cheese',
#    'white cheddar mashed potatoes',
#    'steamed broccoli (cal 1140)'],
#   'prices': [15.95, 19.75, 19.5, 16.5, 17.95],
#   'products': ['Enlightened Spicy Peanut Chicken with Soba Noodles',
#    'Fresh Atlantic Salmon',
#    'New Orleans Jambalaya',
#    "BJ's Brewhouse Blonde Fish 'N' Chips",
#    'Parmesan-Crusted Chicken']},
#  'Starter Salads': {'ingredients': ['Baby spinach',
#    'diced tomatoes',
#    'bleu cheese crumbles',
#    'honey sriracha vinaigrette',
#    'applewood smoked bacon',
#    'chopped hard-boiled egg (cal 220)',
#    'Diced golden beets',
#    'arugula',
#    'red onions',
#    'strawberry vinaigrette',
#    'goat cheese',
#    'toasted almonds',
#    'dried cranberries (cal 120)',
#    'Sliced Portobello mushrooms',
#    'asparagus',
#    'baby field greens',
#    'balsamic vinaigrette',
#    'dried cranberries',
#    'goat cheese',
#    'toasted pepitas (cal 290)'],
#   'prices': [6.75, 6.75, 6.75],
#   'products': ['Twisted BLT',
#    'Golden Beet and Arugula',
#    'Roasted Portobello and Asparagus']},
#  'World-Famous Pizookies®': {'ingredients': ['Premium flavors Ghirardelli® triple chocolate cookie',
#    'peanut butter',
#    'marshmallow fluff',
#    'marshmallows',
#    'rich vanilla bean ice cream',
#    'available in regular size only (cal 1580)',
#    'Premium flavors Rich chocolate cookie with the taste of oreo® cookies',
#    'rich vanilla bean ice cream',
#    'a dollop of mousse (cal 1230)',
#    'Premium flavors Fresh-baked, pull-apart bread',
#    'butter',
#    'brown sugar',
#    'cinnamon',
#    'rich vanilla bean ice cream (cal 1260)',
#    'Caramel cookie dough',
#    'sweet almond toffee',
#    'crunchy pretzel bites',
#    'white + Ghirardelli ®  dark chocolate chips',
#    'rich vanilla bean ice cream',
#    'caramel sauce (cal 1360)',
#    'Premium flavors Rich chocolate cookie with chunks of ghirardelli® chocolate',
#    'ghirardelli® double chocolate chip ice cream',
#    'ghirardelli® dark chocolate chips (cal 1180)',
#    'Premium flavors Gluten-free item Fresh-baked chocolate chip cookie',
#    'rich vanilla bean ice cream (cal 1180)',
#    'Classic flavors Fresh-baked chocolate chip cookie',
#    'rich vanilla bean ice cream (cal 1150)',
#    'Classic flavors Buttery sugar cookie',
#    'white chocolate chunks',
#    'macadamia nuts',
#    'rich vanilla bean ice cream (cal 1220)',
#    'Classic flavors Fresh-baked peanut butter cookie',
#    'rich vanilla bean ice cream (cal 1220)',
#    'Your choice† of three mini pizookies ® each served with a scoop of ice cream (cal 1740-2160)'],
#   'prices': [7.95, 7.5, 7.95, 7.95, 7.95, 7.95, 7.5, 7.5, 7.5, 11.5, 4.5],
#   'products': ["BJ's Peanut Butter S'mores",
#    "Cookies 'N' Cream",
#    'Monkey Bread',
#    'Salted Caramel',
#    'Triple Chocolate Made with Ghirardelli',
#    'Gluten‑Free Chocolate Chip',
#    'Chocolate Chunk',
#    'White Chocolate Macadamia Nut',
#    'Peanut Butter',
#    'Pizookie Trio',
#    'Mini Pizookie']},
#  'number': '218',
#  'rating': '4.6'}

# %%
target = "BJRI"

bench = "CAKE"

d_target = "Henrico"

d_bench = "Jersey-City"

# %%
coy
# Out:
# 'BJRI'

# %%
bronc = ronc[ronc["small"]=="Denver"]

# %%
bronc.mean()

lonc = bronc[["products","prices"]]

lonc = lonc.append(pd.Series([str(bronc.mean()["rating"])+"/5","$"+str(round(bronc.mean()["prices"],2))], index=lonc.columns),ignore_index=True)

lonc.index = lonc.index + 1

lonc.reset_index(inplace=True)
lonc.columns = ["Ranking","Product","Prices"]
lonc.loc[5,"Ranking"] = "Rating"

lonc.loc[-1] = lonc.columns  # adding a row
lonc.index = lonc.index + 1  # shifting index
lonc = lonc.sort_index()

lonc
# Out:
# prices    11.578
# rating     4.000
# number    21.000
# dtype: float64

# %%
bronc.mean()["rating"]
# Out:
# 4.0

# %%
lonc = lonc.append(pd.Series([str(bronc.mean()["rating"])+"/5","$"+str(bronc.mean()["prices"])], index=lonc.columns),ignore_index=True)

# %%
for r, pe, pr in zip(rat,gat[per_col].sum().values,gat[pe_col].mean().values):
    new_row.append(str(round(r,2))+"/5")
    new_row.append(str(round(pe,2))+"%")
    new_row.append("$"+str(round(pr,2)))

# %%
ronc= conc[conc.index<5]

ronc = ronc.fillna(ronc.mean())
ronc["number"] = ronc["number"].astype(int)

ronc

# %%
import _pickle as pickle

for item, backup in zip(["Most Popular", "Most Loved"],["Most Loved","Most Popular"]):
    dict_doordash["local "+item] = {} 

    fat = pd.DataFrame()
    rat = [] 
    raty = []
    
    for coy in codes:

        bad = overall_dict[coy]

        conc = pd.DataFrame(columns=["products","prices","rating","number","small"])
        for k, v in bad.items():
            kel = pd.DataFrame()
            try:
                products = v[item]["products"]
                prices = v[item]["prices"]
            except:
                try:
                    products = v[backup]["products"]
                    prices = v[backup]["prices"]
                except:
                    continue

            kel["products"] = products
            kel["prices"] = prices
            kel["rating"] = v["rating"]
            kel["number"] = v["number"]
            kel["small"] = k 

            conc = pd.concat((conc, kel),axis=0)
            # This one should be saved for hte individual locations

        conc["rating"] = conc["rating"]
        conc["number"] = conc["number"].replace({"Newly":None})
        conc["rating"] = conc["rating"].astype(float)
        conc["number"] = conc["number"].astype(float)
        
        ronc= conc[conc.index<5]

        ronc = ronc.fillna(ronc.mean())
        ronc["number"] = ronc["number"].astype(int)

        dict_doordash["local "+item][coy] = ronc 

        rag = conc.drop_duplicates("small").groupby("small").mean()

        rag = rag[~rag["rating"].isnull()]

        rag["percentage"] = ((rag["number"]/rag["number"].sum())).round(2)

        fr = pd.DataFrame()
        fr["products"] = conc["products"].value_counts().index
        fr["count"] = conc["products"].value_counts().values
        fr["percentage"] = (fr["count"].div(fr["count"].sum(), axis=0).multiply(100)).round(2)
        pir = []
        for c in fr["products"]:
            pra = conc[conc["products"]==c].drop_duplicates("products").reset_index(drop=True)["prices"][0]
            pir.append(pra)

        fr["prices"] = pir
        drs = fr[["products","percentage", "prices"]]
        drs.columns = [s+"_"+coy for s in drs.columns]
        rat.append((rag["percentage"] * rag["rating"]).sum()) # I am weighting by amount of reviews.
        fat["Ranking"] = fat.index + 1
        fat = pd.concat((fat, drs), axis=1)

    gat = fat[fat.index<10]

    per_col = [col for col in gat.columns if 'percentage' in col]
    pe_col = [col for col in gat.columns if 'prices' in col]

    new_row = ["Rating/Avg"]

    for r, pe, pr in zip(rat,gat[per_col].sum().values,gat[pe_col].mean().values):
        new_row.append(str(round(r,2))+"/5")
        new_row.append(str(round(pe,2))+"%")
        new_row.append("$"+str(round(pr,2)))


    vat = gat.append(pd.Series(new_row, index=gat.columns),ignore_index=True)

    
    dict_doordash[item] = vat


my_path = os.path.abspath(os.path.dirname('__file__'))
path_out = my_path + "/../data/doordash/"
pickle.dump(dict_doordash,open(path_out +"dict_doordash.p", "wb"))

# %%
pickle.dump(dict_doordash,open(path_out +"dict_doordash.p", "wb"))

# %%
dict_doordash = {}

nerf = pd.DataFrame(columns=["category","products","prices","target"])

for coy in codes:
    for g in overall_dict[coy].keys():
        for k,v in overall_dict[coy][g].items():
            wilf = pd.DataFrame()
            prods = overall_dict[coy][g][k]["products"]
            prices = overall_dict[coy][g][k]["prices"]
            wilf["products"] = prods
            wilf["prices"] = prices
            wilf["category"] = str(k)
            wilf["target"] = coy
            
            nerf = pd.concat((nerf, wilf),axis=0)

verf = nerf.copy()

verf['category'] = verf['category'].replace(['Ribs and Steaks','Ribs', 'Fresh Steaks','Steaks & Ribs', 'Texas-Size Baby Back Ribs', 'Hand-Trimmed Steaks', 'From the Grill', 'Steak & Ribs', 'Steaks & Chops'], "Ribs, Steak and Chops")

verf['category'] = verf['category'].replace(['Guiltless Grill®','Fish & Seafood', 'Chicken' ,  'Chicken, Seafood & Pasta', 'Other Fun on a Bun', 'Fish & Seafood', "BJ's Premium Wings"], "Fish, Chicken and Other")

verf['category'] = verf['category'].replace(['Apps to Share', 'Build Your Appetizer Sampler', 'Entrées','Appetizers', 'Appetizer Salads','SkinnyLicious®: Small Plates & Appetizers','Appetizers', "BJ's Enlightened Entrées", 'Sizzling & Main Entrees', 'Specialty Entrees'], "Appetizers")

verf['category'] = verf['category'].replace(['Big Mouth® Burgers','Handcrafted Burgers', 'Fresh Mex', 'Full-On Fajitas','Burgers', 'Fire-Grilled Gourmet Burgers', "Red's Tavern Burgers", "Red Robin's Finest Gourmet Burgers",'Burger', 'Sandwich','Glamburgers® & Sandwiches', "BJ's Loaded Burgers", "BJ's Brewhouse Burgers", 'Crispy Chicken Sandwiches', 'Sandwiches and Tacos'], "Burgers and Sandwiches")

verf['category'] = verf['category'].replace(['Fresh Salads', 'Sandwiches & Soups','Soups', 'Fresh Salads','Soups', 'Salads','Soup', 'Salad',"BJ's Garden Fresh Entrée Salads", 'Starter Salads', 'Housemade Soups', 'SkinnyLicious®: Salads'], "Salads and Soup")

verf['category'] = verf['category'].replace(['Hey, Sweet Stuff','Ice Cream Delights', 'Sweet Things','Desserts','Dessert','Cheesecakes & Specialty Desserts', 'Ice Cream Delights','World-Famous Pizookies®', 'More Great Desserts'], "Desserts")

verf['category'] = verf['category'].replace(['Wraps & Sandwiches','Cajun Pasta','Chicken & Pastas','Pasta, Seafood More','Original Hand-Tossed Pizzas', 'Crispy Thin Crust Pizzas', 'Gluten-Free Pizzas', 'Pastas','Pastas','Pastas + Specialties', 'Pizzas', 'Pasta Favorites', 'Build Your Own Pizza', "BJ's Deep Dish Pizza", "BJ's Tavern-Cut Pizza"], "Pizza and Pastas")


cats = ["Ribs, Steak and Chops",
"Fish, Chicken and Other",
"Appetizers",
"Burgers and Sandwiches",
"Salads and Soup",
"Desserts",
"Pizza and Pastas"]


tgif = nerf[nerf["target"]=="RRGB"]

kerf = verf[verf["category"].isin(cats)].reset_index(drop=True)

len(kerf)

mens = kerf.groupby(["category","target"]).mean(); mens

sens = mens.reset_index()
goku = pd.DataFrame(columns=codes)
for cat in sens["category"].unique():
    rat = sens[sens["category"]==cat].set_index("target")
    rat = rat.T
    rat.index = ["category",cat]
    rat = rat.iloc[1:,:]
    goku = pd.concat((goku,rat),axis=0)

mean = goku.mean()
far = goku.T
far["mean"] = mean
goku = far.T
goku = goku.astype(float).round(2)

my_path = os.path.abspath(os.path.dirname('__file__'))

path_out = my_path + "/../data/doordash/"

goku = goku.reset_index()
goku = goku.rename(columns={"index": "Category"})
goku.loc[-1] = goku.columns  # adding a row
goku.index = goku.index + 1  # shifting index
goku = goku.sort_index()

dict_doordash["category"] = goku

goku.to_csv(path_out +"bench_cats.csv")

goku

loca_frame = {}

loca_frame["BJRI"] = list(overall_dict["BJRI"].keys())

loca_frame["CAKE"] = list(overall_dict["CAKE"].keys())

loca_frame["TGIF"] = list(overall_dict["TGIF"].keys())

loca_frame["CPKI"] = list(overall_dict["CPKI"].keys())

loca_frame["RRGB"] = list(overall_dict["RRGB"].keys())

loca_frame["APPB"] = list(overall_dict["APPB"].keys())

loca_frame["CHIL"] = list(overall_dict["CHIL"].keys())

dict_doordash["location"] = loca_frame

import _pickle as pickle

for item, backup in zip(["Most Popular", "Most Loved"],["Most Loved","Most Popular"]):
    dict_doordash["local "+item] = {} 

    fat = pd.DataFrame()
    rat = [] 
    raty = []
    
    for coy in codes:

        bad = overall_dict[coy]

        conc = pd.DataFrame(columns=["products","prices","rating","number","small"])
        for k, v in bad.items():
            kel = pd.DataFrame()
            try:
                products = v[item]["products"]
                prices = v[item]["prices"]
            except:
                try:
                    products = v[backup]["products"]
                    prices = v[backup]["prices"]
                except:
                    continue

            kel["products"] = products
            kel["prices"] = prices
            kel["rating"] = v["rating"]
            kel["number"] = v["number"]
            kel["small"] = k 

            conc = pd.concat((conc, kel),axis=0)
            # This one should be saved for hte individual locations

        conc["rating"] = conc["rating"]
        conc["number"] = conc["number"].replace({"Newly":None})
        conc["rating"] = conc["rating"].astype(float)
        conc["number"] = conc["number"].astype(float)
        
        ronc= conc[conc.index<5]

        ronc = ronc.fillna(ronc.mean())
        ronc["number"] = ronc["number"].astype(int)

        dict_doordash["local "+item][coy] = ronc 

        rag = conc.drop_duplicates("small").groupby("small").mean()

        rag = rag[~rag["rating"].isnull()]

        rag["percentage"] = ((rag["number"]/rag["number"].sum())).round(2)

        fr = pd.DataFrame()
        fr["products"] = conc["products"].value_counts().index
        fr["count"] = conc["products"].value_counts().values
        fr["percentage"] = (fr["count"].div(fr["count"].sum(), axis=0).multiply(100)).round(2)
        pir = []
        for c in fr["products"]:
            pra = conc[conc["products"]==c].drop_duplicates("products").reset_index(drop=True)["prices"][0]
            pir.append(pra)

        fr["prices"] = pir
        drs = fr[["products","percentage", "prices"]]
        drs.columns = [s+"_"+coy for s in drs.columns]
        rat.append((rag["percentage"] * rag["rating"]).sum()) # I am weighting by amount of reviews.
        fat["Ranking"] = fat.index + 1
        fat = pd.concat((fat, drs), axis=1)

    gat = fat[fat.index<10]

    per_col = [col for col in gat.columns if 'percentage' in col]
    pe_col = [col for col in gat.columns if 'prices' in col]

    new_row = ["Rating/Avg"]

    for r, pe, pr in zip(rat,gat[per_col].sum().values,gat[pe_col].mean().values):
        new_row.append(str(round(r,2))+"/5")
        new_row.append(str(round(pe,2))+"%")
        new_row.append("$"+str(round(pr,2)))


    vat = gat.append(pd.Series(new_row, index=gat.columns),ignore_index=True)

    
    dict_doordash[item] = vat


my_path = os.path.abspath(os.path.dirname('__file__'))
path_out = my_path + "/../data/doordash/"
pickle.dump(dict_doordash,open(path_out +"dict_doordash.p", "wb"))
